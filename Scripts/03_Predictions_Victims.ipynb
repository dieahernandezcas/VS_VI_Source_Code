# %% [markdown]
# # Notebook: Violence Dynamics Prediction (Mode-Based Sliding Window Approach)
# ## 1. Introduction
# This notebook implements a predictive model for the dynamics of Selective Violence (VS), Indiscriminate Violence (VI), and Collective Violence (VC) in Colombia. Leveraging the previously calculated historical Escalation, Intensity, and "Previous State" metrics, the objective is to predict the overall "State", "Intensity", and "Escalation" for the next month, based on the modal behavior observed within a sliding time window.
#
# The model is designed to be simple and interpretable, focusing on identifying dominant patterns in the recent past to infer the near-future behavior of violence at different geographical levels.
#
# ## 2. Prediction Methodology
# For each month to be predicted, the model follows these steps:
#
# Data Loading: The notebook will load the pre-processed collective violence (VC) data, which already contains the Escalation, Intensity, and "Previous State" metrics for each month.
#
# Observation Window: A sliding window of the last 18 months of historical data will be used for observation.
#
# "State" Prediction (A, B, C, etc.):
#
# Within the 18-month observation window, the mode (most frequent value) of the observed "Previous States" (e.g., 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I') will be calculated.
#
# The predicted "State" for the next month will be this modal value.
#
# "Intensity" Prediction (1, 0, -1):
#
# Once the modal "State" is identified, the data within the 18-month window will be filtered to include only those months whose "Previous State" matches the calculated modal state.
#
# Within this subset of months (which share the modal state), the "share" (proportion) of each Intensity value (1, 0, -1) will be calculated.
#
# The predicted "Intensity" value for the next month will be the value with the highest "share" (the mode) within this filtered subset.
#
# "Escalation" Prediction (1, 0, -1):
#
# Analogous to the Intensity calculation, the same subset of months (those with the modal "Previous State") will be used.
#
# The "share" of each Escalation value (1, 0, -1) will be calculated within this subset.
#
# The predicted "Escalation" value for the next month will be the value with the highest "share" (the mode) within this filtered subset.
#
# ## 3. Geographical Scope
# This prediction process will be applied, and results will be generated for the following geographical levels:
#
# Country: Colombia
#
# Departments: Each analyzed department.
#
# Regions: Each defined region in the study.
#
# ## 4. Data Input and Output
# Input: .tsv files containing collective violence data with Escalation, Intensity, and Previous State columns, generated by the previous notebook. These files are expected to be structured by geographical level (country, department, region).
#
# Output: The notebook will generate new .tsv or .csv files containing the predictions for "State", "Intensity", and "Escalation" for each future month, along with the corresponding dates.

# %% [markdown]
# ### 1. Initial Setup, Library Imports, and Path Configuration
# This block performs the initial setup for the notebook environment. It includes importing all necessary Python libraries required for data handling, file system operations, and numerical computations. It also defines the relative paths for the input directories where the pre-processed data (with Escalation, Intensity, and Previous State) is located, and the base output directory where the prediction results will be saved. These paths are configured assuming a standard project structure relative to the notebook's location.

# %%
# 1. Initial Setup, Library Imports, and Path Configuration

import pandas as pd
import os
import numpy as np

# Define the base input directory where processed data (with metrics) is stored.
# Assumes the notebook is in a 'notebooks' subfolder and data is one level up in 'Results/intensity & escalation/victims'.
# Example structure:
# Project_Root/
# ├── Results/
# │   └── intensity & escalation/
# │       └── victims/    # Input files are here (country, department, region subfolders)
# └── notebooks/        # This notebook is here
base_input_data_dir = os.path.join(os.getcwd(), '..', 'Results', 'intensity & escalation', 'victims')

# Define the base output directory for prediction results.
# Prediction results will be saved in subfolders within this directory.
prediction_results_base_dir = os.path.join(os.getcwd(), '..', 'Results', 'predictions', 'victims')

# Define the window size for the modal prediction.
# This specifies how many previous months to consider for finding the mode.
PREDICTION_WINDOW_SIZE = 18 # Months

# Define the mapping for [Intensity, Escalation] pairs to states (for reference, though not directly used for prediction input).
state_mapping = {
    (1, 1): 'A',
    (1, 0): 'B',
    (1, -1): 'C',
    (0, 1): 'D',
    (0, 0): 'E',
    (0, -1): 'F',
    (-1, 1): 'G',
    (-1, 0): 'H',
    (-1, -1): 'I'
}

print("Initial setup, library imports, and path configuration complete.")
print(f"Input data will be read from: {base_input_data_dir}")
print(f"Prediction results will be saved in: {prediction_results_base_dir}")
print(f"Prediction window size set to: {PREDICTION_WINDOW_SIZE} months.")
# Out:
# Initial setup, library imports, and path configuration complete.
# Input data will be read from: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/intensity & escalation/victims
# Prediction results will be saved in: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/predictions/victims
# Prediction window size set to: 18 months.
# /var/folders/6q/v6tkj0h970nd7vm3v0d4zvm80000gn/T/ipykernel_4570/4276046013.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ### 2. Define Prediction Logic Functions
# This block defines the core functions for the prediction model. These functions implement the logic of finding the mode of "Previous State" within a sliding window and then, based on that modal state, finding the modal "Intensity" and "Escalation" values.
#
# get_mode_or_default(series): A helper function to find the mode of a pandas Series. If there are multiple modes, it picks the first one. If the series is empty, it returns a default value (e.g., None or a string like 'NoMode').
#
# predict_next_state_and_dynamics(df_time_series, window_size): This is the main prediction function. It iterates through the time series, applies the sliding window logic for each prediction point, and generates predictions for 'Previous State', 'Intensity', and 'Escalation' for the next month.

# %%
# 2. Define Prediction Logic Functions

print("\n--- Defining Prediction Logic Functions ---")

def get_mode_or_default(series, default_value=None):
    """
    Calculates the mode of a pandas Series. If there are multiple modes,
    it returns the first one. If the series is empty, it returns a default value.

    Args:
        series (pd.Series): The input series.
        default_value: The value to return if the series is empty or has no mode.

    Returns:
        The mode of the series, or the default_value.
    """
    if series.empty:
        return default_value
    # value_counts() returns a Series with counts of unique values, sorted in descending order.
    # The index of the first element is the mode.
    modes = series.mode()
    if not modes.empty:
        return modes.iloc[0] # Return the first mode if multiple exist
    return default_value # Should not happen if series is not empty, but for safety

def predict_next_state_and_dynamics(df_time_series, window_size):
    """
    Predicts the 'Previous State', 'Intensity', and 'Escalation' for the next month
    based on the modal behavior within a sliding window.

    Args:
        df_time_series (pd.DataFrame): A DataFrame containing 'Año', 'Mes',
                                       'Previous State', 'Intensity', 'Escalation'
                                       for a specific violence type and geographical unit.
                                       Assumes it's sorted chronologically.
        window_size (int): The number of months in the sliding window to look back.

    Returns:
        pd.DataFrame: A DataFrame with 'Año', 'Mes', 'violence type',
                      'Predicted_State', 'Predicted_Intensity', 'Predicted_Escalation'.
    """
    predictions = []
    # Ensure the DataFrame is sorted by Year and Mes for correct window slicing
    df_time_series = df_time_series.sort_values(by=['Año', 'Mes']).reset_index(drop=True)

    # Iterate through the time series to make predictions for future months
    # We need at least 'window_size' months of historical data to make the first prediction.
    # The prediction for month 't+1' uses data from 't-window_size' to 't'.
    # In our case, the 'Previous State' at month 't' is based on (Intensity_t-1, Escalation_t-1).
    # So, to predict for month 't+1', we need the 'Previous State' of month 't'.
    # The window will be from (current_index - window_size) to (current_index - 1)
    # The prediction is for the month *after* the current_index.

    # Start making predictions from the month immediately following the window_size.
    # For example, if window_size is 18, the first prediction will be for the 19th month,
    # using data from months 1 to 18.
    for i in range(window_size, len(df_time_series)):
        # Define the historical window (last 'window_size' months *before* the current month 'i')
        # This window contains data from index (i - window_size) up to (i - 1)
        # The 'Previous State' column in df_time_series[i-window_size:i] refers to
        # the state of (Intensity, Escalation) for the month *prior* to that row's month.
        # So, if we want to predict for month 'i' (which is the next month after the window),
        # we look at the 'Previous State' column within the window.
        current_window = df_time_series.iloc[i - window_size : i]

        if current_window.empty or 'Previous State' not in current_window.columns:
            # This case should ideally not be hit if the input df_time_series is valid
            print(f"Warning: Empty or invalid window at index {i}. Skipping prediction.")
            continue

        # 1. Predict the 'Previous State' for the next month (i.e., the state of the *current* month 'i' based on its (I,E) pair)
        # Find the mode of 'Previous State' within the current historical window
        predicted_state_mode = get_mode_or_default(current_window['Previous State'], default_value='Unknown')

        # 2. Predict 'Intensity' and 'Escalation' for the next month
        # Filter the window to include only months whose 'Previous State' matches the modal state
        filtered_by_mode_state = current_window[current_window['Previous State'] == predicted_state_mode]

        predicted_intensity = get_mode_or_default(filtered_by_mode_state['Intensity'], default_value=0) # Default to 0 if no mode
        predicted_escalation = get_mode_or_default(filtered_by_mode_state['Escalation'], default_value=0) # Default to 0 if no mode

        # Get the month and year for which we are making the prediction (the month *after* the window)
        # This is the month 'i' in the original df_time_series
        predicted_year = df_time_series.loc[i, 'Año']
        predicted_month = df_time_series.loc[i, 'Mes']
        violence_type = df_time_series.loc[i, 'violence type'] # Keep the violence type consistent

        predictions.append({
            'Año': predicted_year,
            'Mes': predicted_month,
            'violence type': violence_type,
            'Predicted_State': predicted_state_mode,
            'Predicted_Intensity': predicted_intensity,
            'Predicted_Escalation': predicted_escalation
        })

    return pd.DataFrame(predictions)

print("Prediction logic functions defined.")
# Out:
# --- Defining Prediction Logic Functions ---
# Prediction logic functions defined.

# %% [markdown]
# ### 3. Execute Prediction and Save Results
# This block orchestrates the entire prediction process. It iterates through the pre-processed data files for each geographical level (Country, Department, Region). For each file, it loads the data, extracts the relevant time series for each violence type (VS, VI, VC), applies the predict_next_state_and_dynamics function (defined in Cell 2) to generate predictions, and finally saves these predictions into new TSV files in the designated output directory structure.
#
# This step assumes that the input data files (containing 'Escalation', 'Intensity', and 'Previous State' columns) have been successfully generated and saved by the previous data processing notebook.

# %%
# 3. Execute Prediction and Save Results

print("\n--- Executing Prediction and Saving Results ---")

# Ensure prediction window size is defined
if 'PREDICTION_WINDOW_SIZE' not in globals():
    print("Error: PREDICTION_WINDOW_SIZE not defined. Please run Cell 1.")
elif 'predict_next_state_and_dynamics' not in globals():
    print("Error: Prediction logic functions not found. Please run Cell 2.")
else:
    # Define the levels and their corresponding input/output directories
    levels_info = [
        {'name': 'Country', 'input_dir': os.path.join(base_input_data_dir, 'country'), 'output_subdir': 'country'},
        {'name': 'Department', 'input_dir': os.path.join(base_input_data_dir, 'department'), 'output_subdir': 'department'},
        {'name': 'Region', 'input_dir': os.path.join(base_input_data_dir, 'region'), 'output_subdir': 'region'}
    ]

    for level in levels_info:
        level_name = level['name']
        input_dir = level['input_dir']
        output_subdir = level['output_subdir']
        output_dir = os.path.join(prediction_results_base_dir, output_subdir)

        print(f"\n--- Processing {level_name} Level for Predictions ---")

        # Create the output directory for this level if it doesn't exist
        os.makedirs(output_dir, exist_ok=True)
        print(f"Ensured output directory exists: {output_dir}")

        # Check if the input directory exists
        if not os.path.exists(input_dir):
            print(f"Error: Input data directory not found for {level_name}: {input_dir}. Skipping this level.")
            continue # Skip to the next level

        # List all TSV files in the input directory for this level
        # Assuming filenames end with '_victims_metrics.tsv' from the previous notebook's output
        processed_files = [f for f in os.listdir(input_dir) if f.endswith('_victims_metrics.tsv')]

        if not processed_files:
            print(f"Warning: No processed metrics TSV files found in {input_dir}. Skipping {level_name} prediction.")
        else:
            print(f"Found {len(processed_files)} processed {level_name} files. Generating predictions for each...")
            for filename in processed_files:
                file_path = os.path.join(input_dir, filename)
                # Extract unit name from filename (e.g., 'colombia', 'antioquia', 'pacifica')
                unit_name = filename.replace("_victims_metrics.tsv", "")

                print(f"\nGenerating predictions for {level_name}: {unit_name} from file: {os.path.basename(file_path)}")

                try:
                    # Read the processed TSV file
                    df_unit_metrics = pd.read_csv(file_path, sep='\t')

                    # Ensure required columns are present for prediction
                    required_cols = ['Año', 'Mes', 'violence type', 'Intensity', 'Escalation', 'Previous State']
                    if not all(col in df_unit_metrics.columns for col in required_cols):
                        print(f"Error: Missing required columns in {os.path.basename(file_path)}: {required_cols}. Skipping prediction for this unit.")
                        continue # Skip to the next file

                    # Ensure data types are correct
                    df_unit_metrics['Año'] = pd.to_numeric(df_unit_metrics['Año'], errors='coerce').astype(int)
                    df_unit_metrics['Mes'] = pd.to_numeric(df_unit_metrics['Mes'], errors='coerce').astype(int)
                    df_unit_metrics['Intensity'] = pd.to_numeric(df_unit_metrics['Intensity'], errors='coerce').fillna(0).astype(int)
                    df_unit_metrics['Escalation'] = pd.to_numeric(df_unit_metrics['Escalation'], errors='coerce').fillna(0).astype(int)
                    df_unit_metrics = df_unit_metrics.dropna(subset=required_cols).copy()

                    # Get unique violence types (VS, VI, VC) from the loaded data
                    unique_violence_types_in_file = df_unit_metrics['violence type'].unique()

                    all_predictions_for_unit = []
                    for v_type in unique_violence_types_in_file:
                        df_type_series = df_unit_metrics[df_unit_metrics['violence type'] == v_type].copy()

                        if len(df_type_series) < PREDICTION_WINDOW_SIZE:
                            print(f"Warning: Not enough historical data for {v_type} in {unit_name} ({len(df_type_series)} months). Skipping prediction.")
                            continue # Skip if not enough data for the window

                        # Generate predictions for this violence type
                        predictions_df_type = predict_next_state_and_dynamics(df_type_series, PREDICTION_WINDOW_SIZE)
                        if not predictions_df_type.empty:
                            all_predictions_for_unit.append(predictions_df_type)

                    # Concatenate all predictions for the current unit (across VS, VI, VC)
                    if all_predictions_for_unit:
                        final_predictions_df = pd.concat(all_predictions_for_unit, ignore_index=True)
                        final_predictions_df = final_predictions_df.sort_values(by=['Año', 'Mes', 'violence type']).reset_index(drop=True)

                        # --- Save the predictions to TSV ---
                        # Generate the output filename: unit name (lowercase, no spaces) + "_cases_predictions.tsv"
                        output_filename = unit_name.lower().replace(" ", "") + "_victims_predictions.tsv"
                        output_path = os.path.join(output_dir, output_filename)

                        try:
                            final_predictions_df.to_csv(output_path, sep='\t', index=False)
                            print(f"Saved predictions for {level_name}: {unit_name} to {output_filename}")
                        except Exception as e:
                            print(f"Error saving predictions for {level_name}: {unit_name} to {output_filename}: {e}")
                    else:
                        print(f"No predictions generated for {level_name}: {unit_name}. Skipping save.")

                except Exception as e:
                    print(f"An unexpected error occurred during processing file {filename}: {e}")

            print(f"\n{level_name}-level prediction calculation and saving complete.")

    print("\n--- Overall Prediction Process Finished ---")
# Out:
# --- Executing Prediction and Saving Results ---
#
# --- Processing Country Level for Predictions ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/predictions/victims/country
# Found 1 processed Country files. Generating predictions for each...
#
# Generating predictions for Country: 1958_2022_victims_country.tsv from file: 1958_2022_victims_country.tsv_victims_metrics.tsv
# Saved predictions for Country: 1958_2022_victims_country.tsv to 1958_2022_victims_country.tsv_victims_predictions.tsv
#
# Country-level prediction calculation and saving complete.
#
# --- Processing Department Level for Predictions ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/predictions/victims/department
# Found 35 processed Department files. Generating predictions for each...
#
# Generating predictions for Department: nariño from file: nariño_victims_metrics.tsv
# Saved predictions for Department: nariño to nariño_victims_predictions.tsv
#
# Generating predictions for Department: vichada from file: vichada_victims_metrics.tsv
# Saved predictions for Department: vichada to vichada_victims_predictions.tsv
#
# Generating predictions for Department: caqueta from file: caqueta_victims_metrics.tsv
# Saved predictions for Department: caqueta to caqueta_victims_predictions.tsv
#
# Generating predictions for Department: cundinamarca from file: cundinamarca_victims_metrics.tsv
# Saved predictions for Department: cundinamarca to cundinamarca_victims_predictions.tsv
#
# Generating predictions for Department: boyaca from file: boyaca_victims_metrics.tsv
# Saved predictions for Department: boyaca to boyaca_victims_predictions.tsv
#
# Generating predictions for Department: archipielagodesanandres,providenciaysantacatalina from file: archipielagodesanandres,providenciaysantacatalina_victims_metrics.tsv
# Saved predictions for Department: archipielagodesanandres,providenciaysantacatalina to archipielagodesanandres,providenciaysantacatalina_victims_predictions.tsv
#
# Generating predictions for Department: risaralda from file: risaralda_victims_metrics.tsv
# Saved predictions for Department: risaralda to risaralda_victims_predictions.tsv
#
# Generating predictions for Department: magdalena from file: magdalena_victims_metrics.tsv
# Saved predictions for Department: magdalena to magdalena_victims_predictions.tsv
#
# Generating predictions for Department: casanare from file: casanare_victims_metrics.tsv
# Saved predictions for Department: casanare to casanare_victims_predictions.tsv
#
# Generating predictions for Department: amazonas from file: amazonas_victims_metrics.tsv
# Saved predictions for Department: amazonas to amazonas_victims_predictions.tsv
#
# Generating predictions for Department: huila from file: huila_victims_metrics.tsv
# Saved predictions for Department: huila to huila_victims_predictions.tsv
#
# Generating predictions for Department: antioquia from file: antioquia_victims_metrics.tsv
# Saved predictions for Department: antioquia to antioquia_victims_predictions.tsv
#
# Generating predictions for Department: vaupes from file: vaupes_victims_metrics.tsv
# Saved predictions for Department: vaupes to vaupes_victims_predictions.tsv
#
# Generating predictions for Department: caldas from file: caldas_victims_metrics.tsv
# Saved predictions for Department: caldas to caldas_victims_predictions.tsv
#
# Generating predictions for Department: tolima from file: tolima_victims_metrics.tsv
# Saved predictions for Department: tolima to tolima_victims_predictions.tsv
#
# Generating predictions for Department: cauca from file: cauca_victims_metrics.tsv
# Saved predictions for Department: cauca to cauca_victims_predictions.tsv
#
# Generating predictions for Department: sininformacion from file: sininformacion_victims_metrics.tsv
# Saved predictions for Department: sininformacion to sininformacion_victims_predictions.tsv
#
# Generating predictions for Department: valledelcauca from file: valledelcauca_victims_metrics.tsv
# Saved predictions for Department: valledelcauca to valledelcauca_victims_predictions.tsv
#
# Generating predictions for Department: guainia from file: guainia_victims_metrics.tsv
# Saved predictions for Department: guainia to guainia_victims_predictions.tsv
#
# Generating predictions for Department: cesar from file: cesar_victims_metrics.tsv
# Saved predictions for Department: cesar to cesar_victims_predictions.tsv
#
# Generating predictions for Department: laguajira from file: laguajira_victims_metrics.tsv
# Saved predictions for Department: laguajira to laguajira_victims_predictions.tsv
#
# Generating predictions for Department: choco from file: choco_victims_metrics.tsv
# Saved predictions for Department: choco to choco_victims_predictions.tsv
#
# Generating predictions for Department: sucre from file: sucre_victims_metrics.tsv
# Saved predictions for Department: sucre to sucre_victims_predictions.tsv
#
# Generating predictions for Department: guaviare from file: guaviare_victims_metrics.tsv
# Saved predictions for Department: guaviare to guaviare_victims_predictions.tsv
#
# Generating predictions for Department: putumayo from file: putumayo_victims_metrics.tsv
# Saved predictions for Department: putumayo to putumayo_victims_predictions.tsv
#
# Generating predictions for Department: nortedesantander from file: nortedesantander_victims_metrics.tsv
# Saved predictions for Department: nortedesantander to nortedesantander_victims_predictions.tsv
#
# Generating predictions for Department: santander from file: santander_victims_metrics.tsv
# Saved predictions for Department: santander to santander_victims_predictions.tsv
#
# Generating predictions for Department: atlantico from file: atlantico_victims_metrics.tsv
# Saved predictions for Department: atlantico to atlantico_victims_predictions.tsv
#
# Generating predictions for Department: exterior from file: exterior_victims_metrics.tsv
# Saved predictions for Department: exterior to exterior_victims_predictions.tsv
#
# Generating predictions for Department: meta from file: meta_victims_metrics.tsv
# Saved predictions for Department: meta to meta_victims_predictions.tsv
#
# Generating predictions for Department: arauca from file: arauca_victims_metrics.tsv
# Saved predictions for Department: arauca to arauca_victims_predictions.tsv
#
# Generating predictions for Department: quindio from file: quindio_victims_metrics.tsv
# Saved predictions for Department: quindio to quindio_victims_predictions.tsv
#
# Generating predictions for Department: bogota,d.c. from file: bogota,d.c._victims_metrics.tsv
# Saved predictions for Department: bogota,d.c. to bogota,d.c._victims_predictions.tsv
#
# Generating predictions for Department: bolivar from file: bolivar_victims_metrics.tsv
# Saved predictions for Department: bolivar to bolivar_victims_predictions.tsv
#
# Generating predictions for Department: cordoba from file: cordoba_victims_metrics.tsv
# Saved predictions for Department: cordoba to cordoba_victims_predictions.tsv
#
# Department-level prediction calculation and saving complete.
#
# --- Processing Region Level for Predictions ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/predictions/victims/region
# Found 78 processed Region files. Generating predictions for each...
#
# Generating predictions for Region: nortedeantioquia from file: nortedeantioquia_victims_metrics.tsv
# Saved predictions for Region: nortedeantioquia to nortedeantioquia_victims_predictions.tsv
#
# Generating predictions for Region: valledesanjuan from file: valledesanjuan_victims_metrics.tsv
# Saved predictions for Region: valledesanjuan to valledesanjuan_victims_predictions.tsv
#
# Generating predictions for Region: surdemagdalena from file: surdemagdalena_victims_metrics.tsv
# Saved predictions for Region: surdemagdalena to surdemagdalena_victims_predictions.tsv
#
# Generating predictions for Region: suroesteantioqueño from file: suroesteantioqueño_victims_metrics.tsv
# Saved predictions for Region: suroesteantioqueño to suroesteantioqueño_victims_predictions.tsv
#
# Generating predictions for Region: centrodelhuila from file: centrodelhuila_victims_metrics.tsv
# Saved predictions for Region: centrodelhuila to centrodelhuila_victims_predictions.tsv
#
# Generating predictions for Region: altoputumayo from file: altoputumayo_victims_metrics.tsv
# Saved predictions for Region: altoputumayo to altoputumayo_victims_predictions.tsv
#
# Generating predictions for Region: provinciacomunera from file: provinciacomunera_victims_metrics.tsv
# Saved predictions for Region: provinciacomunera to provinciacomunera_victims_predictions.tsv
#
# Generating predictions for Region: uraba from file: uraba_victims_metrics.tsv
# Saved predictions for Region: uraba to uraba_victims_predictions.tsv
#
# Generating predictions for Region: cienagagrandedesantamarta from file: cienagagrandedesantamarta_victims_metrics.tsv
# Saved predictions for Region: cienagagrandedesantamarta to cienagagrandedesantamarta_victims_predictions.tsv
#
# Generating predictions for Region: llanosorientales from file: llanosorientales_victims_metrics.tsv
# Saved predictions for Region: llanosorientales to llanosorientales_victims_predictions.tsv
#
# Generating predictions for Region: amazoniasur-oriental from file: amazoniasur-oriental_victims_metrics.tsv
# Saved predictions for Region: amazoniasur-oriental to amazoniasur-oriental_victims_predictions.tsv
#
# Generating predictions for Region: catatumbo from file: catatumbo_victims_metrics.tsv
# Saved predictions for Region: catatumbo to catatumbo_victims_predictions.tsv
#
# Generating predictions for Region: nortedenariño from file: nortedenariño_victims_metrics.tsv
# Saved predictions for Region: nortedenariño to nortedenariño_victims_predictions.tsv
#
# Generating predictions for Region: archipielagodesanandres,providenciaysantacatalina from file: archipielagodesanandres,providenciaysantacatalina_victims_metrics.tsv
# Saved predictions for Region: archipielagodesanandres,providenciaysantacatalina to archipielagodesanandres,providenciaysantacatalina_victims_predictions.tsv
#
# Generating predictions for Region: orienteantioqueño from file: orienteantioqueño_victims_metrics.tsv
# Saved predictions for Region: orienteantioqueño to orienteantioqueño_victims_predictions.tsv
#
# Generating predictions for Region: altillanura from file: altillanura_victims_metrics.tsv
# Saved predictions for Region: altillanura to altillanura_victims_predictions.tsv
#
# Generating predictions for Region: magdalenamedio from file: magdalenamedio_victims_metrics.tsv
# Saved predictions for Region: magdalenamedio to magdalenamedio_victims_predictions.tsv
#
# Generating predictions for Region: provinciadericaurte from file: provinciadericaurte_victims_metrics.tsv
# Saved predictions for Region: provinciadericaurte to provinciadericaurte_victims_predictions.tsv
#
# Generating predictions for Region: patia from file: patia_victims_metrics.tsv
# Saved predictions for Region: patia to patia_victims_predictions.tsv
#
# Generating predictions for Region: montesdemaria from file: montesdemaria_victims_metrics.tsv
# Saved predictions for Region: montesdemaria to montesdemaria_victims_predictions.tsv
#
# Generating predictions for Region: nortedeltolima from file: nortedeltolima_victims_metrics.tsv
# Saved predictions for Region: nortedeltolima to nortedeltolima_victims_predictions.tsv
#
# Generating predictions for Region: areametropolitanadebogota from file: areametropolitanadebogota_victims_metrics.tsv
# Saved predictions for Region: areametropolitanadebogota to areametropolitanadebogota_victims_predictions.tsv
#
# Generating predictions for Region: provinciadegarciarovira from file: provinciadegarciarovira_victims_metrics.tsv
# Saved predictions for Region: provinciadegarciarovira to provinciadegarciarovira_victims_predictions.tsv
#
# Generating predictions for Region: caguan from file: caguan_victims_metrics.tsv
# Saved predictions for Region: caguan to caguan_victims_predictions.tsv
#
# Generating predictions for Region: lamojana from file: lamojana_victims_metrics.tsv
# Saved predictions for Region: lamojana to lamojana_victims_predictions.tsv
#
# Generating predictions for Region: surdebolivar from file: surdebolivar_victims_metrics.tsv
# Saved predictions for Region: surdebolivar to surdebolivar_victims_predictions.tsv
#
# Generating predictions for Region: ariariguayabero from file: ariariguayabero_victims_metrics.tsv
# Saved predictions for Region: ariariguayabero to ariariguayabero_victims_predictions.tsv
#
# Generating predictions for Region: nordesteantioqueño from file: nordesteantioqueño_victims_metrics.tsv
# Saved predictions for Region: nordesteantioqueño to nordesteantioqueño_victims_predictions.tsv
#
# Generating predictions for Region: centrodelvalle from file: centrodelvalle_victims_metrics.tsv
# Saved predictions for Region: centrodelvalle to centrodelvalle_victims_predictions.tsv
#
# Generating predictions for Region: suroccidentedenortedesantander from file: suroccidentedenortedesantander_victims_metrics.tsv
# Saved predictions for Region: suroccidentedenortedesantander to suroccidentedenortedesantander_victims_predictions.tsv
#
# Generating predictions for Region: occidenteantioqueño from file: occidenteantioqueño_victims_metrics.tsv
# Saved predictions for Region: occidenteantioqueño to occidenteantioqueño_victims_predictions.tsv
#
# Generating predictions for Region: surorientedenortedesantander from file: surorientedenortedesantander_victims_metrics.tsv
# Saved predictions for Region: surorientedenortedesantander to surorientedenortedesantander_victims_predictions.tsv
#
# Generating predictions for Region: centroorientedeatlantico from file: centroorientedeatlantico_victims_metrics.tsv
# Saved predictions for Region: centroorientedeatlantico to centroorientedeatlantico_victims_predictions.tsv
#
# Generating predictions for Region: suroccidentedecundinamarca from file: suroccidentedecundinamarca_victims_metrics.tsv
# Saved predictions for Region: suroccidentedecundinamarca to suroccidentedecundinamarca_victims_predictions.tsv
#
# Generating predictions for Region: occidentedenariño from file: occidentedenariño_victims_metrics.tsv
# Saved predictions for Region: occidentedenariño to occidentedenariño_victims_predictions.tsv
#
# Generating predictions for Region: andenpacificosur from file: andenpacificosur_victims_metrics.tsv
# Saved predictions for Region: andenpacificosur to andenpacificosur_victims_predictions.tsv
#
# Generating predictions for Region: sininformacion from file: sininformacion_victims_metrics.tsv
# Saved predictions for Region: sininformacion to sininformacion_victims_predictions.tsv
#
# Generating predictions for Region: altosinuysanjorge from file: altosinuysanjorge_victims_metrics.tsv
# Saved predictions for Region: altosinuysanjorge to altosinuysanjorge_victims_predictions.tsv
#
# Generating predictions for Region: centrodenariño from file: centrodenariño_victims_metrics.tsv
# Saved predictions for Region: centrodenariño to centrodenariño_victims_predictions.tsv
#
# Generating predictions for Region: provinciadeguanenta from file: provinciadeguanenta_victims_metrics.tsv
# Saved predictions for Region: provinciadeguanenta to provinciadeguanenta_victims_predictions.tsv
#
# Generating predictions for Region: medioputumayo from file: medioputumayo_victims_metrics.tsv
# Saved predictions for Region: medioputumayo to medioputumayo_victims_predictions.tsv
#
# Generating predictions for Region: surdecesar from file: surdecesar_victims_metrics.tsv
# Saved predictions for Region: surdecesar to surdecesar_victims_predictions.tsv
#
# Generating predictions for Region: serraniadelosyariguies from file: serraniadelosyariguies_victims_metrics.tsv
# Saved predictions for Region: serraniadelosyariguies to serraniadelosyariguies_victims_predictions.tsv
#
# Generating predictions for Region: sierranevadadesantamarta from file: sierranevadadesantamarta_victims_metrics.tsv
# Saved predictions for Region: sierranevadadesantamarta to sierranevadadesantamarta_victims_predictions.tsv
#
# Generating predictions for Region: surdelhuila from file: surdelhuila_victims_metrics.tsv
# Saved predictions for Region: surdelhuila to surdelhuila_victims_predictions.tsv
#
# Generating predictions for Region: litoralpacifico from file: litoralpacifico_victims_metrics.tsv
# Saved predictions for Region: litoralpacifico to litoralpacifico_victims_predictions.tsv
#
# Generating predictions for Region: magdalenamedioantioqueño from file: magdalenamedioantioqueño_victims_metrics.tsv
# Saved predictions for Region: magdalenamedioantioqueño to magdalenamedioantioqueño_victims_predictions.tsv
#
# Generating predictions for Region: nortedeatlantico from file: nortedeatlantico_victims_metrics.tsv
# Saved predictions for Region: nortedeatlantico to nortedeatlantico_victims_predictions.tsv
#
# Generating predictions for Region: canaldeldique from file: canaldeldique_victims_metrics.tsv
# Saved predictions for Region: canaldeldique to canaldeldique_victims_predictions.tsv
#
# Generating predictions for Region: altiplanocundiboyacense from file: altiplanocundiboyacense_victims_metrics.tsv
# Saved predictions for Region: altiplanocundiboyacense to altiplanocundiboyacense_victims_predictions.tsv
#
# Generating predictions for Region: provinciadevelez from file: provinciadevelez_victims_metrics.tsv
# Saved predictions for Region: provinciadevelez to provinciadevelez_victims_predictions.tsv
#
# Generating predictions for Region: occidentedeatlantico from file: occidentedeatlantico_victims_metrics.tsv
# Saved predictions for Region: occidentedeatlantico to occidentedeatlantico_victims_predictions.tsv
#
# Generating predictions for Region: sumapaz from file: sumapaz_victims_metrics.tsv
# Saved predictions for Region: sumapaz to sumapaz_victims_predictions.tsv
#
# Generating predictions for Region: areametropolitanadecucuta from file: areametropolitanadecucuta_victims_metrics.tsv
# Saved predictions for Region: areametropolitanadecucuta to areametropolitanadecucuta_victims_predictions.tsv
#
# Generating predictions for Region: morrosquilloysabanasdesucre from file: morrosquilloysabanasdesucre_victims_metrics.tsv
# Saved predictions for Region: morrosquilloysabanasdesucre to morrosquilloysabanasdesucre_victims_predictions.tsv
#
# Generating predictions for Region: sarare from file: sarare_victims_metrics.tsv
# Saved predictions for Region: sarare to sarare_victims_predictions.tsv
#
# Generating predictions for Region: provinciadesoto from file: provinciadesoto_victims_metrics.tsv
# Saved predictions for Region: provinciadesoto to provinciadesoto_victims_predictions.tsv
#
# Generating predictions for Region: nortedelcauca from file: nortedelcauca_victims_metrics.tsv
# Saved predictions for Region: nortedelcauca to nortedelcauca_victims_predictions.tsv
#
# Generating predictions for Region: surdeltolima from file: surdeltolima_victims_metrics.tsv
# Saved predictions for Region: surdeltolima to surdeltolima_victims_predictions.tsv
#
# Generating predictions for Region: altaguajira from file: altaguajira_victims_metrics.tsv
# Saved predictions for Region: altaguajira to altaguajira_victims_predictions.tsv
#
# Generating predictions for Region: surdenariño from file: surdenariño_victims_metrics.tsv
# Saved predictions for Region: surdenariño to surdenariño_victims_predictions.tsv
#
# Generating predictions for Region: nortedelvalle from file: nortedelvalle_victims_metrics.tsv
# Saved predictions for Region: nortedelvalle to nortedelvalle_victims_predictions.tsv
#
# Generating predictions for Region: piedemontellanero from file: piedemontellanero_victims_metrics.tsv
# Saved predictions for Region: piedemontellanero to piedemontellanero_victims_predictions.tsv
#
# Generating predictions for Region: bajoputumayo from file: bajoputumayo_victims_metrics.tsv
# Saved predictions for Region: bajoputumayo to bajoputumayo_victims_predictions.tsv
#
# Generating predictions for Region: orientedeboyaca from file: orientedeboyaca_victims_metrics.tsv
# Saved predictions for Region: orientedeboyaca to orientedeboyaca_victims_predictions.tsv
#
# Generating predictions for Region: centrodenortedesantander from file: centrodenortedesantander_victims_metrics.tsv
# Saved predictions for Region: centrodenortedesantander to centrodenortedesantander_victims_predictions.tsv
#
# Generating predictions for Region: surdelvalle from file: surdelvalle_victims_metrics.tsv
# Saved predictions for Region: surdelvalle to surdelvalle_victims_predictions.tsv
#
# Generating predictions for Region: nortedecordoba from file: nortedecordoba_victims_metrics.tsv
# Saved predictions for Region: nortedecordoba to nortedecordoba_victims_predictions.tsv
#
# Generating predictions for Region: valledeaburra from file: valledeaburra_victims_metrics.tsv
# Saved predictions for Region: valledeaburra to valledeaburra_victims_predictions.tsv
#
# Generating predictions for Region: ejecafetero from file: ejecafetero_victims_metrics.tsv
# Saved predictions for Region: ejecafetero to ejecafetero_victims_predictions.tsv
#
# Generating predictions for Region: bajocaucaantioqueño from file: bajocaucaantioqueño_victims_metrics.tsv
# Saved predictions for Region: bajocaucaantioqueño to bajocaucaantioqueño_victims_predictions.tsv
#
# Generating predictions for Region: atrato from file: atrato_victims_metrics.tsv
# Saved predictions for Region: atrato to atrato_victims_predictions.tsv
#
# Generating predictions for Region: noroccidentedecundinamarca from file: noroccidentedecundinamarca_victims_metrics.tsv
# Saved predictions for Region: noroccidentedecundinamarca to noroccidentedecundinamarca_victims_predictions.tsv
#
# Generating predictions for Region: macizocolombiano from file: macizocolombiano_victims_metrics.tsv
# Saved predictions for Region: macizocolombiano to macizocolombiano_victims_predictions.tsv
#
# Generating predictions for Region: serraniadelperija from file: serraniadelperija_victims_metrics.tsv
# Saved predictions for Region: serraniadelperija to serraniadelperija_victims_predictions.tsv
#
# Generating predictions for Region: centrooccidentedenariño from file: centrooccidentedenariño_victims_metrics.tsv
# Saved predictions for Region: centrooccidentedenariño to centrooccidentedenariño_victims_predictions.tsv
#
# Generating predictions for Region: nortedelhuila from file: nortedelhuila_victims_metrics.tsv
# Saved predictions for Region: nortedelhuila to nortedelhuila_victims_predictions.tsv
#
# Generating predictions for Region: florenciayareadeinfluencia from file: florenciayareadeinfluencia_victims_metrics.tsv
# Saved predictions for Region: florenciayareadeinfluencia to florenciayareadeinfluencia_victims_predictions.tsv
#
# Region-level prediction calculation and saving complete.
#
# --- Overall Prediction Process Finished ---
