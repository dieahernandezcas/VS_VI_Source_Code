# %% [markdown]
# # Code Description: Data Cleaning and Preprocessing Script | Victims
#
# ## Purpose
# This script is designed to perform initial data cleaning and preprocessing steps on the raw violence data for the project on Selective and Indiscriminate Violence (VS/VI) in Colombia. Its main goal is to prepare the data for subsequent analysis, metric calculation (Escalation, Intensity), and potential modeling.
#
# ## Workflow Stage
# This script is in the Data Cleaning / Preprocessing stage. It takes the raw data, likely loaded from the combined DataFrame generated in the previous step, and transforms it into a clean, structured format suitable for further use in the analytical pipeline.
#
# ## About
# This script will handle common data issues such as missing values, incorrect data types, and inconsistencies. It will standardize column names if necessary and potentially aggregate data by relevant temporal (e.g., month) and geographical (Country, Department, or Región) units, depending on the specific analysis level being targeted. The output will be a cleaned dataset ready for calculating metrics and generating features.

# %%
import pandas as pd
import numpy as np
import os
from itertools import product

# %% [markdown]
# ### 1. Initial Setup, Library Imports, and Path Configuration
# This block performs the initial setup, including importing necessary libraries (pandas, os), defining the path to the raw data folder (one level up in 'Data/raw'), and listing the specific filenames expected for VI and VS violence types. It also defines the list of columns to be extracted from each file.

# %%
# Define the path to the folder containing the Excel files.
# Assumes the notebook is in a subfolder and the data is one level up.
# Adjust '../' if your folder structure is different.
data_folder_path = os.path.join(os.getcwd(), '..', 'Data', 'raw','victims') # Example path based on the proposed structure

# Define the base columns to select from each Excel file (excluding actor columns for now).
columns_to_select = [
    "Año",
    "Mes",
    "Día",
    "ID Persona",
    "ID Caso",
    "Municipio",
    "Departamento",
]

columns_to_select_base = [
    "Año",
    "Mes",
    "Día",
    "ID Caso",
    "Municipio",
    "Departamento",
    "Región"
]

# Define the list of potential actor columns, in order of preference.
actor_column_candidates = ["Presunto Responsable", "Grupo Armado 1"]

# Define the lists of filenames corresponding to each violence type (VI and VS).
# These filenames are used to classify the data.
vi_files = [
    "Victimas_Acciones_Belicas_202503.xlsx",
    "Victimas_Ataques_a_Poblaciones_202503.xlsx",
    "Victimas_Atentados_Terroristas_202503.xlsx",
    "Victimas_MInas_202503.xlsx",
    "Victimas_Reclutamiento_ninas_ninos_202503.xlsx"
]

vs_files = [
    "Victimas_Danos_a_Bienes_Civiles_202503.xlsx", # Note: Check for potential extra space in filename "Caso_ Danos..."
    "Victimas_Asesinatos_Selectivo_202503.xlsx",
    "Victimas_Desaparicion_Forzada_202503.xlsx", # Note: Check for potential extra space in filename "Desaparicion_Forzada _"
    "Victimas_Masacre_202503.xlsx",
    "Victimas_Secuestro_202503.xlsx",
    "Victimas_Violencia_Sexual_202503.xlsx"
]

# --- Define lists for State and Non-State Actors based on 'Presunto Responsable' / 'Grupo Armado 1' values ---
# These lists classify the responsible party into two broad categories.
# Values not in these lists will be categorized as 'UNKNOWN_ACTOR_TYPE'.

STATE_ACTORS_RESPONSIBLE = [
    'AGENTE DEL ESTADO'
]

NON_STATE_ACTORS_RESPONSIBLE = [
    'GUERRILLA',
    'GRUPO PARAMILITAR',
    'GRUPO ARMADO NO IDENTIFICADO',
    'BANDOLERISMO',
    'GRUPO POSDESMOVILIZACIÓN',
    'CRIMEN ORGANIZADO',
    'AGENTE EXTRANJERO',
    'GRUPO PARAMILITAR - GUERRILLA',
    'GRUPO POSDESMOVILIZACIÓN - GUERRILLA',
    'AGENTE DEL ESTADO - GRUPO PARAMILITAR',
    'AGENTE DEL ESTADO - GRUPO POSDESMOVILIZACIÓN',
    'AGENTE DEL ESTADO - GUERRILLA',
    'DESCONOCIDO',
    'OTRO ¿CUÁL?'
]

# Helper function to classify the actor type
def classify_actor(responsible_party):
    """
    Classifies a responsible party string into 'STATE_ACTOR', 'NON_STATE_ACTOR',
    or 'UNKNOWN_ACTOR_TYPE'. Handles NaN/None values and standardizes input.
    """
    if pd.isna(responsible_party):
        return 'UNKNOWN_ACTOR_TYPE'
    responsible_party_upper = str(responsible_party).strip().upper()

    if responsible_party_upper in [s.upper() for s in STATE_ACTORS_RESPONSIBLE]:
        return 'STATE_ACTOR'
    elif responsible_party_upper in [ns.upper() for ns in NON_STATE_ACTORS_RESPONSIBLE]:
        return 'NON_STATE_ACTOR'
    else:
        return 'UNKNOWN_ACTOR_TYPE' # Default for unlisted or unknown parties

# Initialize an empty list to store the processed dataframes from each file.
all_dataframes = []

# Iterate through all files in the specified data folder.
for filename in os.listdir(data_folder_path):
    # Construct the full file path.
    file_path = os.path.join(data_folder_path, filename)

    # Check if the current item is a file and if it's an Excel file.
    if os.path.isfile(file_path) and filename.endswith('.xlsx'):
        print(f"Processing file: {filename}") # Print the filename being processed

        try:
            # Read the Excel file into a pandas DataFrame.
            df = pd.read_excel(file_path)

            df_victims = pd.read_excel( os.path.join(os.getcwd(), '..', 'Data', 'raw','victims',filename.replace('Victimas','Casos')) )

            # Determine which actor column is available in the current file
            current_actor_column = None
            for col_candidate in actor_column_candidates:
                if col_candidate in df_victims.columns:
                    current_actor_column = col_candidate
                    break # Found the column, use it and exit loop

            if current_actor_column is None:
                print(f"Warning: Neither '{actor_column_candidates[0]}' nor '{actor_column_candidates[1]}' found in file '{filename}'. Skipping this file.")
                continue # Skip this file if no relevant actor column is found

            # Construct the list of columns to select for THIS specific DataFrame
            # This includes the base columns and the identified actor column
            cols_to_load_for_this_df = columns_to_select_base + [current_actor_column]

            df_victims = df_victims[cols_to_load_for_this_df]
            df_victims.rename(columns={"Grupo Armado 1":"Presunto Responsable"},inplace=True)
            # Rename the found actor column to a standardized name for classification
            df_victims['ResponsiblePartyRaw'] = df_victims[current_actor_column]

            # Apply the actor classification to create the 'ActorType' column
            df_victims['ActorType'] = df_victims['ResponsiblePartyRaw'].apply(classify_actor)

            # Drop the temporary raw column used for classification
            df_victims.drop(columns=['ResponsiblePartyRaw'], inplace=True)

            # Select only the required columns.
            # Use .copy() to avoid SettingWithCopyWarning later.
            df_selected = df[columns_to_select].copy()

            # Determine the violence type based on the filename and add the 'violence type' column.
            if filename in vi_files:
                df_selected['violence type'] = 'VI'

                df_selected = df_selected.merge(df_victims[['ID Caso','Región','ActorType']], on='ID Caso', how='left')
                
            elif filename in vs_files:
                df_selected['violence type'] = 'VS'
                df_victims = pd.read_excel( os.path.join(os.getcwd(), '..', 'Data', 'raw','victims',filename.replace('Victimas','Casos')) )
                df_victims = df_victims[cols_to_load_for_this_df]
                df_victims.rename(columns={"Grupo Armado 1":"Presunto Responsable"},inplace=True)
                # Rename the found actor column to a standardized name for classification
                df_victims['ResponsiblePartyRaw'] = df_victims[current_actor_column]

                # Apply the actor classification to create the 'ActorType' column
                df_victims['ActorType'] = df_victims['ResponsiblePartyRaw'].apply(classify_actor)

                # Drop the temporary raw column used for classification
                df_victims.drop(columns=['ResponsiblePartyRaw'], inplace=True)

                df_selected = df_selected.merge(df_victims[['ID Caso','Región','ActorType']], on='ID Caso', how='left')
            else:
                # If the file is not in either list, you might want to skip it
                # or assign a different type, depending on your needs.
                print(f"Warning: File '{filename}' not classified as VI or VS. Skipping.")
                continue # Skip this file

            # Append the processed DataFrame to the list.
            all_dataframes.append(df_selected)

        except Exception as e:
            # Print an error message if reading or processing a file fails.
            print(f"Error processing file {filename}: {e}")
# Out:
# Processing file: Victimas_Masacre_202503.xlsx
# /Users/diegohernandez/Documents/Virtual_Enviroment/Python_Colab/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Error processing file Victimas_Masacre_202503.xlsx: [Errno 2] No such file or directory: '/Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/raw/victims/Casos_Masacre_202503.xlsx'
# Processing file: Victimas_Secuestro_202503.xlsx
# /Users/diegohernandez/Documents/Virtual_Enviroment/Python_Colab/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Error processing file Victimas_Secuestro_202503.xlsx: [Errno 2] No such file or directory: '/Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/raw/victims/Casos_Secuestro_202503.xlsx'
# Processing file: Victimas_Acciones_Belicas_202503.xlsx
# /Users/diegohernandez/Documents/Virtual_Enviroment/Python_Colab/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Error processing file Victimas_Acciones_Belicas_202503.xlsx: [Errno 2] No such file or directory: '/Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/raw/victims/Casos_Acciones_Belicas_202503.xlsx'
# Processing file: Victimas_Atentados_Terroristas_202503.xlsx
# Error processing file Victimas_Atentados_Terroristas_202503.xlsx: [Errno 2] No such file or directory: '/Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/raw/victims/Casos_Atentados_Terroristas_202503.xlsx'
# Processing file: Victimas_Danos_a_Bienes_Civiles_202503.xlsx
# Error processing file Victimas_Danos_a_Bienes_Civiles_202503.xlsx: [Errno 2] No such file or directory: '/Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/raw/victims/Casos_Danos_a_Bienes_Civiles_202503.xlsx'
# Processing file: Victimas_Ataques_a_Poblaciones_202503.xlsx
# /Users/diegohernandez/Documents/Virtual_Enviroment/Python_Colab/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/diegohernandez/Documents/Virtual_Enviroment/Python_Colab/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/diegohernandez/Documents/Virtual_Enviroment/Python_Colab/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Error processing file Victimas_Ataques_a_Poblaciones_202503.xlsx: [Errno 2] No such file or directory: '/Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/raw/victims/Casos_Ataques_a_Poblaciones_202503.xlsx'
# Processing file: Victimas_MInas_202503.xlsx
# /Users/diegohernandez/Documents/Virtual_Enviroment/Python_Colab/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Error processing file Victimas_MInas_202503.xlsx: [Errno 2] No such file or directory: '/Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/raw/victims/Casos_MInas_202503.xlsx'
# Processing file: Victimas_Violencia_Sexual_202503.xlsx
# /Users/diegohernandez/Documents/Virtual_Enviroment/Python_Colab/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Error processing file Victimas_Violencia_Sexual_202503.xlsx: [Errno 2] No such file or directory: '/Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/raw/victims/Casos_Violencia_Sexual_202503.xlsx'
# Processing file: Victimas_Asesinatos_Selectivo_202503.xlsx
# /Users/diegohernandez/Documents/Virtual_Enviroment/Python_Colab/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Error processing file Victimas_Asesinatos_Selectivo_202503.xlsx: [Errno 2] No such file or directory: '/Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/raw/victims/Casos_Asesinatos_Selectivo_202503.xlsx'
# Processing file: Victimas_Desaparicion_Forzada_202503.xlsx
# /Users/diegohernandez/Documents/Virtual_Enviroment/Python_Colab/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Error processing file Victimas_Desaparicion_Forzada_202503.xlsx: [Errno 2] No such file or directory: '/Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/raw/victims/Casos_Desaparicion_Forzada_202503.xlsx'
# Processing file: Victimas_Reclutamiento_ninas_ninos_202503.xlsx
# /Users/diegohernandez/Documents/Virtual_Enviroment/Python_Colab/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Error processing file Victimas_Reclutamiento_ninas_ninos_202503.xlsx: [Errno 2] No such file or directory: '/Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/raw/victims/Casos_Reclutamiento_ninas_ninos_202503.xlsx'

# %% [markdown]
# ### 2. Concatenate DataFrames and Display Summary
# This block consolidates all individual DataFrames processed from the Excel files into a single combined_df. It includes a check to ensure data was processed before concatenation. Finally, it displays the head, info, and violence type counts of the combined DataFrame for initial verification.

# %%
# Concatenate all dataframes in the list into a single DataFrame.
if all_dataframes:
    combined_df = pd.concat(all_dataframes, ignore_index=True)

    # In case some files were skipped and 'ActorType' was not added to all, ensure it exists
    if 'ActorType' not in combined_df.columns:
        combined_df['ActorType'] = 'UNKNOWN_ACTOR_TYPE' # Fallback if no actor types were classified

    # Display basic info
    print("\nCombined DataFrame Head:")
    print(combined_df.head())
    print("\nCombined DataFrame Info:")
    combined_df.info()
    print("\nViolence Type Counts:")
    print(combined_df['violence type'].value_counts())
    print("\nActor Type Counts:")
    print(combined_df['ActorType'].value_counts())

    # Save the combined DataFrame as a raw processed file with ActorType.
    # This acts as a single source of truth for the combined raw data with violence/actor types.
    output_processed_base_dir = os.path.join(os.getcwd(), '..', 'Data', 'processed', 'victims')
    os.makedirs(output_processed_base_dir, exist_ok=True)
    combined_df.to_csv(os.path.join(output_processed_base_dir, 'raw_combined_victims_with_actors.tsv'), sep='\t', index=False)
    print(f"\nSaved raw combined victims with actor types to: {os.path.join(output_processed_base_dir, 'raw_combined_victims_with_actors.tsv')}")

else:
    print("\nNo Excel files were processed or found. 'combined_df' is not created.")
# Out:
# No Excel files were processed or found. 'combined_df' is not created.

# %%
combined_df.to_csv('../Data/processed/victims/real_total_victims.tsv',sep='\t')
combined_df.head()
# Out:
#    Unnamed: 0   Año  Mes  Día  ID Persona  ID Caso    Municipio  Departamento  \
# 0           0  1998    1   25       49528   100649  PARATEBUENO  CUNDINAMARCA
# 1           1  1998    1   25       49529   100649  PARATEBUENO  CUNDINAMARCA
# 2           2  1998    1   25      762576   100649  PARATEBUENO  CUNDINAMARCA
# 3           3  1998    1   25      762650   100649  PARATEBUENO  CUNDINAMARCA
# 4           4  1998    1   25      763007   100649  PARATEBUENO  CUNDINAMARCA
#
#   violence type              Región        ActorType
# 0            VS  PIEDEMONTE LLANERO  NON_STATE_ACTOR
# 1            VS  PIEDEMONTE LLANERO  NON_STATE_ACTOR
# 2            VS  PIEDEMONTE LLANERO  NON_STATE_ACTOR
# 3            VS  PIEDEMONTE LLANERO  NON_STATE_ACTOR
# 4            VS  PIEDEMONTE LLANERO  NON_STATE_ACTOR

# %% [markdown]
# ### 3. Group Victims Data by Year, Month, Violence Type, and Actor Type (1958-2022) for Country Level
# This block processes the combined_df to filter and group victimc data for the entire country (Colombia). It specifically groups by Año (Year), Mes (Month), violence type (VI/VS), and the created ActorType (STATE_ACTOR, NON_STATE_ACTOR).
#
# The purpose is to count the total number of victims for each combination of these dimensions, creating complete monthly time series. It ensures all possible Year-Month-Violence Type-Actor Type combinations within the specified range (1958-2022) are present by imputing missing entries with a count of 0. The resulting time series DataFrames for each ActorType are then saved as separate TSV files in their respective output directories (country/state_actors and country/non_state_actors).

# %%
# 3. Group victims Data by Year, Month, Violence Type, and Actor Type (1958-2022) for Country Level
combined_df = pd.read_csv('../Data/processed/victims/real_total_victims.tsv',sep='\t')
print("\n--- Grouping victims data by Year, Month, Violence Type, and Actor Type for Country (1958-2022) ---")

# Ensure combined_df exists from the previous step (Cell 1)
if 'combined_df' not in locals() or combined_df.empty:
    print("Error: 'combined_df' not found or is empty. Please run the initial data loading and actor classification code block (Cell 1).")
else:
    # Define the output directory for country-level case data, now segmented by ActorType
    output_dir_country_base = os.path.join(os.getcwd(), '..', 'Data', 'processed', 'victims', 'country')

    # Define the year range for filtering and imputation
    min_year = 1958
    max_year = 2022

    # Ensure 'Año', 'Mes', 'violence type', and 'ActorType' columns are valid
    required_cols_for_grouping = ['Año', 'Mes', 'violence type', 'ActorType']
    df_filtered_victims = combined_df.copy()

    try:
        # Convert to numeric and drop NaNs for 'Año' and 'Mes'
        df_filtered_victims['Año'] = pd.to_numeric(df_filtered_victims['Año'], errors='coerce')
        df_filtered_victims['Mes'] = pd.to_numeric(df_filtered_victims['Mes'], errors='coerce')
        df_filtered_victims = df_filtered_victims.dropna(subset=['Año', 'Mes']).copy()

        # Filter by the specified year range
        df_filtered_victims = df_filtered_victims[
            (df_filtered_victims['Año'] >= min_year) & (df_filtered_victims['Año'] <= max_year)
        ].copy()

        # Drop rows where 'violence type' or 'ActorType' are missing/null
        df_filtered_victims = df_filtered_victims.dropna(subset=['violence type', 'ActorType']).copy()

        # Get unique violence types and actor types present in the filtered data
        unique_violence_types = df_filtered_victims['violence type'].unique()
        unique_actor_types = df_filtered_victims['ActorType'].unique()

        if len(unique_actor_types) == 0:
            print("Warning: No valid ActorTypes found after filtering. Skipping country-level grouping by actor.")
        else:
            print(f"Filtered victims data for years {min_year}-{max_year}. Shape: {df_filtered_victims.shape}")
            print(f"Unique Violence Types found: {unique_violence_types}")
            print(f"Unique Actor Types found: {unique_actor_types}")

            # Create a complete list of all expected Year-Month combinations for imputation
            full_date_range = pd.date_range(start=f'{min_year}-01-01', end=f'{max_year}-12-01', freq='MS')

            # Loop through each unique ActorType to process and save data separately
            for actor_type in unique_actor_types:
                actor_type_clean_name = actor_type.replace(" ", "_").lower() # e.g., 'state_actor', 'non_state_actor'
                output_dir_actor_type = os.path.join(output_dir_country_base, actor_type_clean_name)
                os.makedirs(output_dir_actor_type, exist_ok=True)
                print(f"\nEnsured output directory exists for {actor_type}: {output_dir_actor_type}")

                # Filter data for the current ActorType
                df_actor_type = df_filtered_victims[df_filtered_victims['ActorType'] == actor_type].copy()

                if df_actor_type.empty:
                    print(f"No data for ActorType: {actor_type}. Skipping processing for this actor type.")
                    continue

                # Group by 'Año', 'Mes', and 'violence type' and count the occurrences
                grouping_cols = ['Año', 'Mes', 'violence type']
                victims_by_month_year_type_actor = df_actor_type.groupby(grouping_cols).size()

                # Create a complete multi-index for this ActorType, including all Year-Month-Violence Type combinations
                all_combinations_actor = list(product(full_date_range.year, full_date_range.month, unique_violence_types))
                full_index_actor = pd.MultiIndex.from_tuples(
                    all_combinations_actor,
                    names=grouping_cols
                )

                # Reindex the monthly case counts using the complete index
                victims_by_month_year_complete_actor = victims_by_month_year_type_actor.reindex(full_index_actor)

                # Fill NaN values with 0 and convert to integer
                victims_by_month_year_complete_actor = victims_by_month_year_complete_actor.fillna(0).astype(int)

                # Convert Series back to a DataFrame with 'VictimsCount'
                grouped_victims_country_monthly_actor = victims_by_month_year_complete_actor.reset_index(name='VictimsCount')

                # Sort the DataFrame chronologically and by violence type
                grouped_victims_country_monthly_actor = grouped_victims_country_monthly_actor.sort_values(by=['Año', 'Mes', 'violence type']).reset_index(drop=True)

                # --- Deduplication (Crucial Step) ---
                initial_rows = len(grouped_victims_country_monthly_actor)
                grouped_victims_country_monthly_actor.drop_duplicates(subset=['Año', 'Mes', 'violence type'], inplace=True)
                if len(grouped_victims_country_monthly_actor) < initial_rows:
                    print(f"Warning: Removed {initial_rows - len(grouped_victims_country_monthly_actor)} duplicate rows for (Año, Mes, violence type) within {actor_type} data before saving.")
                else:
                    print(f"No duplicates found for (Año, Mes, violence type) within {actor_type} data before saving.")

                # --- Save the results to TSV ---
                # Filename: 'colombia_victims_actor_type.tsv'
                output_filename = f"colombia_victims_{actor_type_clean_name}.tsv"
                output_path = os.path.join(output_dir_actor_type, output_filename)

                try:
                    grouped_victims_country_monthly_actor.to_csv(output_path, sep='\t', index=False)
                    print(f"Saved data for Country ({actor_type}) to {output_filename}")
                except Exception as e:
                    print(f"Error saving data for Country ({actor_type}) to {output_filename}: {e}")

            print("\nCountry-level victims data processing and saving by ActorType complete.")

    except KeyError as e:
        print(f"Error: Required column not found - {e}. Please check column names in the combined_df or input Excel files.")
    except Exception as e:
        print(f"An unexpected error occurred during grouping: {e}")
# Out:
# --- Grouping victims data by Year, Month, Violence Type, and Actor Type for Country (1958-2022) ---
# Filtered victims data for years 1958-2022. Shape: (272781, 12)
# Unique Violence Types found: ['VS' 'VI']
# Unique Actor Types found: ['NON_STATE_ACTOR' 'STATE_ACTOR']
#
# Ensured output directory exists for NON_STATE_ACTOR: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/processed/victims/country/non_state_actor
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NON_STATE_ACTOR data before saving.
# Saved data for Country (NON_STATE_ACTOR) to colombia_victims_non_state_actor.tsv
#
# Ensured output directory exists for STATE_ACTOR: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/processed/victims/country/state_actor
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within STATE_ACTOR data before saving.
# Saved data for Country (STATE_ACTOR) to colombia_victims_state_actor.tsv
#
# Country-level victims data processing and saving by ActorType complete.

# %%
#grouped_victims_country_monthly_type.to_csv('../Data/processed/victims/country/1958_2022_victims_country.tsv',sep='\t')
grouped_victims_country_monthly_actor.head()
# Out:
#        Año  Mes violence type  VictimsCount
# 0     1958    1            VI             0
# 780   1958    1            VS             3
# 1560  1958    2            VI             0
# 2340  1958    2            VS             3
# 3120  1958    3            VI             0

# %% [markdown]
# ### 4. Generate Animated Line Plot of VI vs VS victims (1958-2022)
# This block creates an animated line plot visualizing the yearly trend of Selective Violence (VS) and Indiscriminate Violence (VI) victims in Colombia from 1958 to 2022. The animation shows how the cumulative victims counts for each violence type evolve over time, providing a dynamic view of their historical trajectories. The output is saved as an MP4 video file.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import os
import seaborn as sns # Import seaborn for aesthetics
from itertools import product # Import product for generating combinations (if needed for re-running previous cells)
import numpy as np # Import numpy for numerical operations, specifically arange

grouped_victims_country_monthly_type = pd.read_csv('../Data/processed/victims/country/1958_2022_victims_country.tsv',sep='\t')

# Ensure the grouped_victims_country_monthly_type DataFrame exists
if 'grouped_victims_country_monthly_type' not in locals():
    print("Error: 'grouped_victims_country_monthly_type' not found. Please run the previous code block to create it.")
else:
    # --- 4. Generate Animated Line Plot of VI vs VS victims (1958-2022) ---

    print("\n--- Generating Animated Line Plot ---")

    # Prepare data: Group by Year and Violence Type and sum the monthly counts
    # This gives the total victims per year for each violence type
    yearly_victims_by_type = grouped_victims_country_monthly_type.groupby(['Año', 'violence type'])['VictimsCount'].sum().reset_index()

    # Pivot the data for easier plotting
    # Years will be the index, violence types will be columns, and values will be VictimsCount
    yearly_victims_pivot = yearly_victims_by_type.pivot(index='Año', columns='violence type', values='VictimsCount').fillna(0)

    # Ensure both 'VI' and 'VS' columns exist, even if one had 0 victims for all years
    for v_type in ['VI', 'VS']:
        if v_type not in yearly_victims_pivot.columns:
            yearly_victims_pivot[v_type] = 0

    # Sort the pivot table by year
    yearly_victims_pivot = yearly_victims_pivot.sort_index()

    # Calculate cumulative sum for the animation
    # This shows the total victims up to a given year
    yearly_victims_cumulative = yearly_victims_pivot.cumsum()

    # Set up the figure and axes for the plot
    plt.style.use('seaborn-v0_8-darkgrid') # Use a nice seaborn style
    fig, ax = plt.subplots(figsize=(10, 4))

    # Set initial plot limits (adjust as needed)
    ax.set_xlim(yearly_victims_cumulative.index.min(), yearly_victims_cumulative.index.max())
    ax.set_ylim(0, yearly_victims_cumulative.values.max() * 1.1) # Add 10% padding to y-axis

    # Set titles and labels
    ax.set_title('Cumulative victims of Selective (VS) and Indiscriminate (VI) Violence in Colombia (1958-2022)', fontsize=14)
    ax.set_xlabel('Year', fontsize=12)
    ax.set_ylabel('Cumulative Number of victims', fontsize=12)
    ax.grid(True, linestyle='--', alpha=0.6)

    # --- X-axis Tick Adjustment ---
    # Determine the range of years
    min_year = yearly_victims_cumulative.index.min()
    max_year = yearly_victims_cumulative.index.max()

    # Set ticks at intervals (e.g., every 10 years)
    # Use numpy.arange for consistent spacing
    tick_years = np.arange(min_year, max_year + 1, 10) # Adjust the step (10) as needed

    # Ensure the last year is included if it's not exactly on an interval
    if max_year not in tick_years:
         tick_years = np.append(tick_years, max_year)

    ax.set_xticks(tick_years)
    ax.tick_params(axis='x', rotation=45) # Rotate labels slightly if needed for clarity

    # Initialize the lines for the plot
    line_vi, = ax.plot([], [], label='VI victims', color='red', linewidth=2)
    line_vs, = ax.plot([], [], label='VS victims', color='blue', linewidth=2)
    # --- ADJUSTMENT HERE: Change loc to 'lower right' ---
    ax.legend(loc='lower right')

    # Add a text annotation for the current year (will be updated in animation)
    year_text = ax.text(0.02, 0.95, '', transform=ax.transAxes, fontsize=15, color='gray')

    # Define the animation update function
    def update(frame):
        """
        Updates the plot data for each frame of the animation.
        frame: The current frame number (index of the year).
        """
        current_year_index = frame
        current_year = yearly_victims_cumulative.index[current_year_index]

        # Update data for VI line up to the current year
        line_vi.set_data(yearly_victims_cumulative.index[:current_year_index+1],
                         yearly_victims_cumulative['VI'].iloc[:current_year_index+1])

        # Update data for VS line up to the current year
        line_vs.set_data(yearly_victims_cumulative.index[:current_year_index+1],
                         yearly_victims_cumulative['VS'].iloc[:current_year_index+1])

        # Update the year text annotation
        year_text.set_text(f'Year: {current_year}')

        # Need to return all artists that were modified
        return line_vi, line_vs, year_text, ax.legend_

    # Create the animation
    # frames: number of frames (equal to the number of years)
    # interval: delay between frames in milliseconds
    # blit: True means only re-draw the parts that have changed (can be faster)
    ani = animation.FuncAnimation(fig, update, frames=len(yearly_victims_cumulative.index),
                                  interval=200, blit=True) # Adjust interval for speed

    # Define the output path for the video
    output_dir = os.path.join(os.getcwd(), '..', 'Images')
    output_filename = 'VI_VS_Colombia_Victims.mp4'
    output_path = os.path.join(output_dir, output_filename)

    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Save the animation
    # Requires ffmpeg. If you don't have it, you might need to install it
    # (e.g., using conda install -c conda-forge ffmpeg or through a system package manager)
    try:
        print(f"\nSaving animation to {output_path}...")
        # Fix for Matplotlib Deprecation Warning: close figure before switching backend
        plt.close(fig) # Close the figure before switching
        plt.switch_backend('agg') # Switch backend for saving

        # Re-create the writer after closing and switching
        writer = animation.FFMpegWriter(fps=10) # frames per second
        # Re-create the animation object, or ensure the writer can handle the original fig
        # It's often better to just pass the fig directly to save if possible,
        # or ensure the backend is set correctly BEFORE figure creation if saving without displaying.
        # However, since the figure is needed for FuncAnimation, closing *before* saving
        # is the fix for the specific warning. Let's try saving the *original* animation object.
        ani.save(output_path, writer=writer)

        print("Animation saved successfully!")
    except Exception as e:
        print(f"\nError saving animation: {e}")
        print("Please ensure you have ffmpeg installed and accessible in your environment.")
        print("You might need to install it using: conda install -c conda-forge ffmpeg")
        print("Or using your system's package manager (e.g., sudo apt-get install ffmpeg on Ubuntu or brew install ffmpeg on macOS).")
# Out:
# --- Generating Animated Line Plot ---
#
# Saving animation to /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Images/VI_VS_Colombia_Victims.mp4...
# Animation saved successfully!

# %% [markdown]
# ### 5. Group Victims Data by Year, Month, Violence Type, Department, and Actor Type (1958-2022)
# This block processes the combined_df to filter and group victims data for each individual department in Colombia. For each department, it calculates the monthly case count for each violence type (VI/VS) and ActorType (STATE_ACTOR, NON_STATE_ACTOR).
#
# The purpose is to create complete monthly time series for each combination of department, violence type, and actor type within the specified year range (1958-2022), ensuring all possible Year-Month-Violence Type-Actor Type combinations are present by imputing missing entries with a count of 0. The resulting time series DataFrames for each ActorType within each department are then saved as separate TSV files in their respective output directories (departments/state_actors and departments/non_state_actors).

# %%
combined_df.head()
# Out:
#    Unnamed: 0   Año  Mes  Día  ID Persona  ID Caso    Municipio  Departamento  \
# 0           0  1998    1   25       49528   100649  PARATEBUENO  CUNDINAMARCA
# 1           1  1998    1   25       49529   100649  PARATEBUENO  CUNDINAMARCA
# 2           2  1998    1   25      762576   100649  PARATEBUENO  CUNDINAMARCA
# 3           3  1998    1   25      762650   100649  PARATEBUENO  CUNDINAMARCA
# 4           4  1998    1   25      763007   100649  PARATEBUENO  CUNDINAMARCA
#
#   violence type              Región
# 0            VS  PIEDEMONTE LLANERO
# 1            VS  PIEDEMONTE LLANERO
# 2            VS  PIEDEMONTE LLANERO
# 3            VS  PIEDEMONTE LLANERO
# 4            VS  PIEDEMONTE LLANERO

# %%
combined_df = pd.read_csv('../Data/processed/victims/real_total_victims.tsv',sep='\t')

# 5. Group victims Data by Year, Month, Violence Type, Department, and Actor Type (1958-2022)

print("\n--- Grouping victims data by Department, Month, Violence Type, and Actor Type (1958-2022) ---")

# Ensure combined_df exists from the initial loading step (Cell 1)
if 'combined_df' not in locals() or combined_df.empty:
    print("Error: 'combined_df' not found or is empty. Please run the initial data loading and actor classification code block (Cell 1).")
else:
    # Define the base output directory for department-level case data, segmented by ActorType
    output_dir_departments_base = os.path.join(os.getcwd(), '..', 'Data', 'processed', 'victims', 'departments')

    # Define the year range for filtering and imputation
    min_year = 1958
    max_year = 2022

    # Ensure 'Año', 'Mes', 'violence type', 'Department', and 'ActorType' columns are valid
    required_cols_for_grouping = ['Año', 'Mes', 'violence type', 'Departamento', 'ActorType']
    df_filtered_victims_dept = combined_df.copy()

    try:
        # Convert to numeric and drop NaNs for 'Año' and 'Mes'
        df_filtered_victims_dept['Año'] = pd.to_numeric(df_filtered_victims_dept['Año'], errors='coerce')
        df_filtered_victims_dept['Mes'] = pd.to_numeric(df_filtered_victims_dept['Mes'], errors='coerce')
        df_filtered_victims_dept = df_filtered_victims_dept.dropna(subset=['Año', 'Mes']).copy()

        # Filter by the specified year range
        df_filtered_victims_dept = df_filtered_victims_dept[
            (df_filtered_victims_dept['Año'] >= min_year) & (df_filtered_victims_dept['Año'] <= max_year)
        ].copy()

        # Drop rows where 'violence type', 'Departamento' or 'ActorType' are missing/null
        df_filtered_victims_dept = df_filtered_victims_dept.dropna(subset=['violence type', 'Departamento', 'ActorType']).copy()

        # Get unique violence types and actor types present in the filtered data
        unique_violence_types = df_filtered_victims_dept['violence type'].unique()
        unique_actor_types = df_filtered_victims_dept['ActorType'].unique()
        unique_departments = df_filtered_victims_dept['Departamento'].unique()

        if len(unique_actor_types) == 0:
            print("Warning: No valid ActorTypes found after filtering. Skipping department-level grouping by actor.")
        elif len(unique_departments) == 0:
            print("Warning: No valid Departments found after filtering. Skipping department-level grouping.")
        else:
            print(f"Filtered victims data for years {min_year}-{max_year}. Shape: {df_filtered_victims_dept.shape}")
            print(f"Unique Violence Types found: {unique_violence_types}")
            print(f"Unique Actor Types found: {unique_actor_types}")
            print(f"Found {len(unique_departments)} unique departments. Processing each department...")

            # Create a complete list of all expected Year-Month combinations for imputation
            full_date_range = pd.date_range(start=f'{min_year}-01-01', end=f'{max_year}-12-01', freq='MS')

            # Loop through each unique ActorType to create separate output subdirectories
            for actor_type in unique_actor_types:
                actor_type_clean_name = actor_type.replace(" ", "_").lower() # e.g., 'state_actor', 'non_state_actor'
                output_dir_actor_type = os.path.join(output_dir_departments_base, actor_type_clean_name)
                os.makedirs(output_dir_actor_type, exist_ok=True)
                print(f"\nEnsured output directory exists for {actor_type} in departments: {output_dir_actor_type}")

                # Loop through each unique department
                for department in unique_departments:
                    department_str = str(department) # Ensure department name is string
                    print(f"\nProcessing department: {department_str} for ActorType: {actor_type}")

                    # Filter data for the current department and ActorType
                    df_dept_actor_type = df_filtered_victims_dept[
                        (df_filtered_victims_dept['Departamento'] == department) &
                        (df_filtered_victims_dept['ActorType'] == actor_type)
                    ].copy()

                    if df_dept_actor_type.empty:
                        print(f"No data for Department: {department_str} and ActorType: {actor_type}. Skipping processing.")
                        continue

                    # Group by 'Año', 'Mes', and 'violence type' and count the occurrences
                    grouping_cols = ['Año', 'Mes', 'violence type']
                    victims_by_month_year_type_dept_actor = df_dept_actor_type.groupby(grouping_cols).size()

                    # Create a complete multi-index for this Department-ActorType combination
                    # It includes all Year-Month-Violence Type combinations
                    all_combinations_dept_actor = list(product(full_date_range.year, full_date_range.month, unique_violence_types))
                    full_index_dept_actor = pd.MultiIndex.from_tuples(
                        all_combinations_dept_actor,
                        names=grouping_cols
                    )

                    # Reindex the monthly case counts using the complete index
                    victims_by_month_year_complete_dept_actor = victims_by_month_year_type_dept_actor.reindex(full_index_dept_actor)

                    # Fill NaN values with 0 and convert to integer
                    victims_by_month_year_complete_dept_actor = victims_by_month_year_complete_dept_actor.fillna(0).astype(int)

                    # Convert Series back to a DataFrame with 'VictimsCount'
                    grouped_victims_dept_monthly_actor = victims_by_month_year_complete_dept_actor.reset_index(name='VictimsCount')

                    # Sort the DataFrame chronologically and by violence type
                    grouped_victims_dept_monthly_actor = grouped_victims_dept_monthly_actor.sort_values(by=['Año', 'Mes', 'violence type']).reset_index(drop=True)

                    # --- Deduplication (Crucial Step) ---
                    initial_rows = len(grouped_victims_dept_monthly_actor)
                    grouped_victims_dept_monthly_actor.drop_duplicates(subset=['Año', 'Mes', 'violence type'], inplace=True)
                    if len(grouped_victims_dept_monthly_actor) < initial_rows:
                        print(f"Warning: Removed {initial_rows - len(grouped_victims_dept_monthly_actor)} duplicate rows for (Año, Mes, violence type) within {department_str} - {actor_type} data before saving.")
                    else:
                        print(f"No duplicates found for (Año, Mes, violence type) within {department_str} - {actor_type} data before saving.")

                    # --- Save the results to TSV ---
                    # Filename: 'departmentname_victims_actor_type.tsv'
                    filename_dept = department_str.replace(" ", "").lower() + f"_victims_{actor_type_clean_name}.tsv"
                    output_path_dept = os.path.join(output_dir_actor_type, filename_dept)

                    try:
                        grouped_victims_dept_monthly_actor.to_csv(output_path_dept, sep='\t', index=False)
                        print(f"Saved data for Department ({department_str}, {actor_type}) to {filename_dept}")
                    except Exception as e:
                        print(f"Error saving data for Department ({department_str}, {actor_type}) to {filename_dept}: {e}")

            print("\nDepartment-level victims data processing and saving by ActorType complete.")

    except KeyError as e:
        print(f"Error: Required column not found - {e}. Please check column names in the combined_df or input Excel files.")
    except Exception as e:
        print(f"An unexpected error occurred during processing: {e}")
# Out:
# --- Grouping victims data by Department, Month, Violence Type, and Actor Type (1958-2022) ---
# Filtered victims data for years 1958-2022. Shape: (272781, 12)
# Unique Violence Types found: ['VS' 'VI']
# Unique Actor Types found: ['NON_STATE_ACTOR' 'STATE_ACTOR']
# Found 35 unique departments. Processing each department...
#
# Ensured output directory exists for NON_STATE_ACTOR in departments: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/processed/victims/departments/non_state_actor
#
# Processing department: CUNDINAMARCA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CUNDINAMARCA - NON_STATE_ACTOR data before saving.
# Saved data for Department (CUNDINAMARCA, NON_STATE_ACTOR) to cundinamarca_victims_non_state_actor.tsv
#
# Processing department: CHOCO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CHOCO - NON_STATE_ACTOR data before saving.
# Saved data for Department (CHOCO, NON_STATE_ACTOR) to choco_victims_non_state_actor.tsv
#
# Processing department: LA GUAJIRA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within LA GUAJIRA - NON_STATE_ACTOR data before saving.
# Saved data for Department (LA GUAJIRA, NON_STATE_ACTOR) to laguajira_victims_non_state_actor.tsv
#
# Processing department: MAGDALENA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within MAGDALENA - NON_STATE_ACTOR data before saving.
# Saved data for Department (MAGDALENA, NON_STATE_ACTOR) to magdalena_victims_non_state_actor.tsv
#
# Processing department: META for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within META - NON_STATE_ACTOR data before saving.
# Saved data for Department (META, NON_STATE_ACTOR) to meta_victims_non_state_actor.tsv
#
# Processing department: NARIÑO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NARIÑO - NON_STATE_ACTOR data before saving.
# Saved data for Department (NARIÑO, NON_STATE_ACTOR) to nariño_victims_non_state_actor.tsv
#
# Processing department: NORTE DE SANTANDER for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NORTE DE SANTANDER - NON_STATE_ACTOR data before saving.
# Saved data for Department (NORTE DE SANTANDER, NON_STATE_ACTOR) to nortedesantander_victims_non_state_actor.tsv
#
# Processing department: RISARALDA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within RISARALDA - NON_STATE_ACTOR data before saving.
# Saved data for Department (RISARALDA, NON_STATE_ACTOR) to risaralda_victims_non_state_actor.tsv
#
# Processing department: SANTANDER for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SANTANDER - NON_STATE_ACTOR data before saving.
# Saved data for Department (SANTANDER, NON_STATE_ACTOR) to santander_victims_non_state_actor.tsv
#
# Processing department: PUTUMAYO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within PUTUMAYO - NON_STATE_ACTOR data before saving.
# Saved data for Department (PUTUMAYO, NON_STATE_ACTOR) to putumayo_victims_non_state_actor.tsv
#
# Processing department: SUCRE for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUCRE - NON_STATE_ACTOR data before saving.
# Saved data for Department (SUCRE, NON_STATE_ACTOR) to sucre_victims_non_state_actor.tsv
#
# Processing department: TOLIMA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within TOLIMA - NON_STATE_ACTOR data before saving.
# Saved data for Department (TOLIMA, NON_STATE_ACTOR) to tolima_victims_non_state_actor.tsv
#
# Processing department: VALLE DEL CAUCA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within VALLE DEL CAUCA - NON_STATE_ACTOR data before saving.
# Saved data for Department (VALLE DEL CAUCA, NON_STATE_ACTOR) to valledelcauca_victims_non_state_actor.tsv
#
# Processing department: ARAUCA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ARAUCA - NON_STATE_ACTOR data before saving.
# Saved data for Department (ARAUCA, NON_STATE_ACTOR) to arauca_victims_non_state_actor.tsv
#
# Processing department: ANTIOQUIA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ANTIOQUIA - NON_STATE_ACTOR data before saving.
# Saved data for Department (ANTIOQUIA, NON_STATE_ACTOR) to antioquia_victims_non_state_actor.tsv
#
# Processing department: BOLIVAR for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within BOLIVAR - NON_STATE_ACTOR data before saving.
# Saved data for Department (BOLIVAR, NON_STATE_ACTOR) to bolivar_victims_non_state_actor.tsv
#
# Processing department: CAQUETA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CAQUETA - NON_STATE_ACTOR data before saving.
# Saved data for Department (CAQUETA, NON_STATE_ACTOR) to caqueta_victims_non_state_actor.tsv
#
# Processing department: CESAR for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CESAR - NON_STATE_ACTOR data before saving.
# Saved data for Department (CESAR, NON_STATE_ACTOR) to cesar_victims_non_state_actor.tsv
#
# Processing department: CORDOBA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CORDOBA - NON_STATE_ACTOR data before saving.
# Saved data for Department (CORDOBA, NON_STATE_ACTOR) to cordoba_victims_non_state_actor.tsv
#
# Processing department: CALDAS for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CALDAS - NON_STATE_ACTOR data before saving.
# Saved data for Department (CALDAS, NON_STATE_ACTOR) to caldas_victims_non_state_actor.tsv
#
# Processing department: CASANARE for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CASANARE - NON_STATE_ACTOR data before saving.
# Saved data for Department (CASANARE, NON_STATE_ACTOR) to casanare_victims_non_state_actor.tsv
#
# Processing department: CAUCA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CAUCA - NON_STATE_ACTOR data before saving.
# Saved data for Department (CAUCA, NON_STATE_ACTOR) to cauca_victims_non_state_actor.tsv
#
# Processing department: QUINDIO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within QUINDIO - NON_STATE_ACTOR data before saving.
# Saved data for Department (QUINDIO, NON_STATE_ACTOR) to quindio_victims_non_state_actor.tsv
#
# Processing department: HUILA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within HUILA - NON_STATE_ACTOR data before saving.
# Saved data for Department (HUILA, NON_STATE_ACTOR) to huila_victims_non_state_actor.tsv
#
# Processing department: SIN INFORMACION for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SIN INFORMACION - NON_STATE_ACTOR data before saving.
# Saved data for Department (SIN INFORMACION, NON_STATE_ACTOR) to sininformacion_victims_non_state_actor.tsv
#
# Processing department: BOYACA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within BOYACA - NON_STATE_ACTOR data before saving.
# Saved data for Department (BOYACA, NON_STATE_ACTOR) to boyaca_victims_non_state_actor.tsv
#
# Processing department: GUAVIARE for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within GUAVIARE - NON_STATE_ACTOR data before saving.
# Saved data for Department (GUAVIARE, NON_STATE_ACTOR) to guaviare_victims_non_state_actor.tsv
#
# Processing department: BOGOTA, D. C. for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within BOGOTA, D. C. - NON_STATE_ACTOR data before saving.
# Saved data for Department (BOGOTA, D. C., NON_STATE_ACTOR) to bogota,d.c._victims_non_state_actor.tsv
#
# Processing department: VICHADA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within VICHADA - NON_STATE_ACTOR data before saving.
# Saved data for Department (VICHADA, NON_STATE_ACTOR) to vichada_victims_non_state_actor.tsv
#
# Processing department: GUAINIA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within GUAINIA - NON_STATE_ACTOR data before saving.
# Saved data for Department (GUAINIA, NON_STATE_ACTOR) to guainia_victims_non_state_actor.tsv
#
# Processing department: EXTERIOR for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within EXTERIOR - NON_STATE_ACTOR data before saving.
# Saved data for Department (EXTERIOR, NON_STATE_ACTOR) to exterior_victims_non_state_actor.tsv
#
# Processing department: ATLANTICO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ATLANTICO - NON_STATE_ACTOR data before saving.
# Saved data for Department (ATLANTICO, NON_STATE_ACTOR) to atlantico_victims_non_state_actor.tsv
#
# Processing department: AMAZONAS for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within AMAZONAS - NON_STATE_ACTOR data before saving.
# Saved data for Department (AMAZONAS, NON_STATE_ACTOR) to amazonas_victims_non_state_actor.tsv
#
# Processing department: VAUPES for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within VAUPES - NON_STATE_ACTOR data before saving.
# Saved data for Department (VAUPES, NON_STATE_ACTOR) to vaupes_victims_non_state_actor.tsv
#
# Processing department: ARCHIPIELAGO DE SAN ANDRES, PROVIDENCIA Y SANTA CATALINA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ARCHIPIELAGO DE SAN ANDRES, PROVIDENCIA Y SANTA CATALINA - NON_STATE_ACTOR data before saving.
# Saved data for Department (ARCHIPIELAGO DE SAN ANDRES, PROVIDENCIA Y SANTA CATALINA, NON_STATE_ACTOR) to archipielagodesanandres,providenciaysantacatalina_victims_non_state_actor.tsv
#
# Ensured output directory exists for STATE_ACTOR in departments: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/processed/victims/departments/state_actor
#
# Processing department: CUNDINAMARCA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CUNDINAMARCA - STATE_ACTOR data before saving.
# Saved data for Department (CUNDINAMARCA, STATE_ACTOR) to cundinamarca_victims_state_actor.tsv
#
# Processing department: CHOCO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CHOCO - STATE_ACTOR data before saving.
# Saved data for Department (CHOCO, STATE_ACTOR) to choco_victims_state_actor.tsv
#
# Processing department: LA GUAJIRA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within LA GUAJIRA - STATE_ACTOR data before saving.
# Saved data for Department (LA GUAJIRA, STATE_ACTOR) to laguajira_victims_state_actor.tsv
#
# Processing department: MAGDALENA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within MAGDALENA - STATE_ACTOR data before saving.
# Saved data for Department (MAGDALENA, STATE_ACTOR) to magdalena_victims_state_actor.tsv
#
# Processing department: META for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within META - STATE_ACTOR data before saving.
# Saved data for Department (META, STATE_ACTOR) to meta_victims_state_actor.tsv
#
# Processing department: NARIÑO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NARIÑO - STATE_ACTOR data before saving.
# Saved data for Department (NARIÑO, STATE_ACTOR) to nariño_victims_state_actor.tsv
#
# Processing department: NORTE DE SANTANDER for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NORTE DE SANTANDER - STATE_ACTOR data before saving.
# Saved data for Department (NORTE DE SANTANDER, STATE_ACTOR) to nortedesantander_victims_state_actor.tsv
#
# Processing department: RISARALDA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within RISARALDA - STATE_ACTOR data before saving.
# Saved data for Department (RISARALDA, STATE_ACTOR) to risaralda_victims_state_actor.tsv
#
# Processing department: SANTANDER for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SANTANDER - STATE_ACTOR data before saving.
# Saved data for Department (SANTANDER, STATE_ACTOR) to santander_victims_state_actor.tsv
#
# Processing department: PUTUMAYO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within PUTUMAYO - STATE_ACTOR data before saving.
# Saved data for Department (PUTUMAYO, STATE_ACTOR) to putumayo_victims_state_actor.tsv
#
# Processing department: SUCRE for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUCRE - STATE_ACTOR data before saving.
# Saved data for Department (SUCRE, STATE_ACTOR) to sucre_victims_state_actor.tsv
#
# Processing department: TOLIMA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within TOLIMA - STATE_ACTOR data before saving.
# Saved data for Department (TOLIMA, STATE_ACTOR) to tolima_victims_state_actor.tsv
#
# Processing department: VALLE DEL CAUCA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within VALLE DEL CAUCA - STATE_ACTOR data before saving.
# Saved data for Department (VALLE DEL CAUCA, STATE_ACTOR) to valledelcauca_victims_state_actor.tsv
#
# Processing department: ARAUCA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ARAUCA - STATE_ACTOR data before saving.
# Saved data for Department (ARAUCA, STATE_ACTOR) to arauca_victims_state_actor.tsv
#
# Processing department: ANTIOQUIA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ANTIOQUIA - STATE_ACTOR data before saving.
# Saved data for Department (ANTIOQUIA, STATE_ACTOR) to antioquia_victims_state_actor.tsv
#
# Processing department: BOLIVAR for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within BOLIVAR - STATE_ACTOR data before saving.
# Saved data for Department (BOLIVAR, STATE_ACTOR) to bolivar_victims_state_actor.tsv
#
# Processing department: CAQUETA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CAQUETA - STATE_ACTOR data before saving.
# Saved data for Department (CAQUETA, STATE_ACTOR) to caqueta_victims_state_actor.tsv
#
# Processing department: CESAR for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CESAR - STATE_ACTOR data before saving.
# Saved data for Department (CESAR, STATE_ACTOR) to cesar_victims_state_actor.tsv
#
# Processing department: CORDOBA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CORDOBA - STATE_ACTOR data before saving.
# Saved data for Department (CORDOBA, STATE_ACTOR) to cordoba_victims_state_actor.tsv
#
# Processing department: CALDAS for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CALDAS - STATE_ACTOR data before saving.
# Saved data for Department (CALDAS, STATE_ACTOR) to caldas_victims_state_actor.tsv
#
# Processing department: CASANARE for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CASANARE - STATE_ACTOR data before saving.
# Saved data for Department (CASANARE, STATE_ACTOR) to casanare_victims_state_actor.tsv
#
# Processing department: CAUCA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CAUCA - STATE_ACTOR data before saving.
# Saved data for Department (CAUCA, STATE_ACTOR) to cauca_victims_state_actor.tsv
#
# Processing department: QUINDIO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within QUINDIO - STATE_ACTOR data before saving.
# Saved data for Department (QUINDIO, STATE_ACTOR) to quindio_victims_state_actor.tsv
#
# Processing department: HUILA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within HUILA - STATE_ACTOR data before saving.
# Saved data for Department (HUILA, STATE_ACTOR) to huila_victims_state_actor.tsv
#
# Processing department: SIN INFORMACION for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SIN INFORMACION - STATE_ACTOR data before saving.
# Saved data for Department (SIN INFORMACION, STATE_ACTOR) to sininformacion_victims_state_actor.tsv
#
# Processing department: BOYACA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within BOYACA - STATE_ACTOR data before saving.
# Saved data for Department (BOYACA, STATE_ACTOR) to boyaca_victims_state_actor.tsv
#
# Processing department: GUAVIARE for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within GUAVIARE - STATE_ACTOR data before saving.
# Saved data for Department (GUAVIARE, STATE_ACTOR) to guaviare_victims_state_actor.tsv
#
# Processing department: BOGOTA, D. C. for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within BOGOTA, D. C. - STATE_ACTOR data before saving.
# Saved data for Department (BOGOTA, D. C., STATE_ACTOR) to bogota,d.c._victims_state_actor.tsv
#
# Processing department: VICHADA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within VICHADA - STATE_ACTOR data before saving.
# Saved data for Department (VICHADA, STATE_ACTOR) to vichada_victims_state_actor.tsv
#
# Processing department: GUAINIA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within GUAINIA - STATE_ACTOR data before saving.
# Saved data for Department (GUAINIA, STATE_ACTOR) to guainia_victims_state_actor.tsv
#
# Processing department: EXTERIOR for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within EXTERIOR - STATE_ACTOR data before saving.
# Saved data for Department (EXTERIOR, STATE_ACTOR) to exterior_victims_state_actor.tsv
#
# Processing department: ATLANTICO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ATLANTICO - STATE_ACTOR data before saving.
# Saved data for Department (ATLANTICO, STATE_ACTOR) to atlantico_victims_state_actor.tsv
#
# Processing department: AMAZONAS for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within AMAZONAS - STATE_ACTOR data before saving.
# Saved data for Department (AMAZONAS, STATE_ACTOR) to amazonas_victims_state_actor.tsv
#
# Processing department: VAUPES for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within VAUPES - STATE_ACTOR data before saving.
# Saved data for Department (VAUPES, STATE_ACTOR) to vaupes_victims_state_actor.tsv
#
# Processing department: ARCHIPIELAGO DE SAN ANDRES, PROVIDENCIA Y SANTA CATALINA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ARCHIPIELAGO DE SAN ANDRES, PROVIDENCIA Y SANTA CATALINA - STATE_ACTOR data before saving.
# Saved data for Department (ARCHIPIELAGO DE SAN ANDRES, PROVIDENCIA Y SANTA CATALINA, STATE_ACTOR) to archipielagodesanandres,providenciaysantacatalina_victims_state_actor.tsv
#
# Department-level victims data processing and saving by ActorType complete.

# %% [markdown]
# ### 6. Group Victims Data by Year, Month, Violence Type, Region, and Actor Type (1958-2022)
# This block processes the combined_df to filter and group victims data for each individual region in Colombia. For each region, it calculates the monthly case count for each violence type (VI/VS) and ActorType (STATE_ACTOR, NON_STATE_ACTOR).
#
# The purpose is to create complete monthly time series for each combination of region, violence type, and actor type within the specified year range (1958-2022), ensuring all possible Year-Month-Violence Type-Actor Type combinations are present by imputing missing entries with a count of 0. The resulting time series DataFrames for each ActorType within each region are then saved as separate TSV files in their respective output directories (regions/state_actors and regions/non_state_actors).

# %%
combined_df = pd.read_csv('../Data/processed/victims/real_total_victims.tsv',sep='\t')

# 6. Group victims Data by Year, Month, Violence Type, Region, and Actor Type (1958-2022)

print("\n--- Grouping victims data by Region, Month, Violence Type, and Actor Type (1958-2022) ---")

# Ensure combined_df exists from the initial loading step (Cell 1)
if 'combined_df' not in locals() or combined_df.empty:
    print("Error: 'combined_df' not found or is empty. Please run the initial data loading and actor classification code block (Cell 1).")
else:
    # Define the base output directory for region-level case data, segmented by ActorType
    output_dir_regions_base = os.path.join(os.getcwd(), '..', 'Data', 'processed', 'victims', 'regions')

    # Define the year range for filtering and imputation
    min_year = 1958
    max_year = 2022

    # Ensure 'Año', 'Mes', 'violence type', 'Región', and 'ActorType' columns are valid
    required_cols_for_grouping = ['Año', 'Mes', 'violence type', 'Región', 'ActorType']
    df_filtered_victims_region = combined_df.copy()

    try:
        # Convert to numeric and drop NaNs for 'Año' and 'Mes'
        df_filtered_victims_region['Año'] = pd.to_numeric(df_filtered_victims_region['Año'], errors='coerce')
        df_filtered_victims_region['Mes'] = pd.to_numeric(df_filtered_victims_region['Mes'], errors='coerce')
        df_filtered_victims_region = df_filtered_victims_region.dropna(subset=['Año', 'Mes']).copy()

        # Filter by the specified year range
        df_filtered_victims_region = df_filtered_victims_region[
            (df_filtered_victims_region['Año'] >= min_year) & (df_filtered_victims_region['Año'] <= max_year)
        ].copy()

        # Drop rows where 'violence type', 'Región' or 'ActorType' are missing/null
        df_filtered_victims_region = df_filtered_victims_region.dropna(subset=['violence type', 'Región', 'ActorType']).copy()

        # Get unique violence types and actor types present in the filtered data
        unique_violence_types = df_filtered_victims_region['violence type'].unique()
        unique_actor_types = df_filtered_victims_region['ActorType'].unique()
        unique_regions = df_filtered_victims_region['Región'].unique()

        if len(unique_actor_types) == 0:
            print("Warning: No valid ActorTypes found after filtering. Skipping region-level grouping by actor.")
        elif len(unique_regions) == 0:
            print("Warning: No valid Regions found after filtering. Skipping region-level grouping.")
        else:
            print(f"Filtered victims data for years {min_year}-{max_year}. Shape: {df_filtered_victims_region.shape}")
            print(f"Unique Violence Types found: {unique_violence_types}")
            print(f"Unique Actor Types found: {unique_actor_types}")
            print(f"Found {len(unique_regions)} unique regions. Processing each region...")

            # Create a complete list of all expected Year-Month combinations for imputation
            full_date_range = pd.date_range(start=f'{min_year}-01-01', end=f'{max_year}-12-01', freq='MS')

            # Loop through each unique ActorType to create separate output subdirectories
            for actor_type in unique_actor_types:
                actor_type_clean_name = actor_type.replace(" ", "_").lower() # e.g., 'state_actor', 'non_state_actor'
                output_dir_actor_type = os.path.join(output_dir_regions_base, actor_type_clean_name)
                os.makedirs(output_dir_actor_type, exist_ok=True)
                print(f"\nEnsured output directory exists for {actor_type} in regions: {output_dir_actor_type}")

                # Loop through each unique region
                for region in unique_regions:
                    region_str = str(region) # Ensure region name is string
                    print(f"\nProcessing region: {region_str} for ActorType: {actor_type}")

                    # Filter data for the current region and ActorType
                    df_region_actor_type = df_filtered_victims_region[
                        (df_filtered_victims_region['Región'] == region) &
                        (df_filtered_victims_region['ActorType'] == actor_type)
                    ].copy()

                    if df_region_actor_type.empty:
                        print(f"No data for Region: {region_str} and ActorType: {actor_type}. Skipping processing.")
                        continue

                    # Group by 'Año', 'Mes', and 'violence type' and count the occurrences
                    grouping_cols = ['Año', 'Mes', 'violence type']
                    victims_by_month_year_type_region_actor = df_region_actor_type.groupby(grouping_cols).size()

                    # Create a complete multi-index for this Region-ActorType combination
                    # It includes all Year-Month-Violence Type combinations
                    all_combinations_region_actor = list(product(full_date_range.year, full_date_range.month, unique_violence_types))
                    full_index_region_actor = pd.MultiIndex.from_tuples(
                        all_combinations_region_actor,
                        names=grouping_cols
                    )

                    # Reindex the monthly case counts using the complete index
                    victims_by_month_year_complete_region_actor = victims_by_month_year_type_region_actor.reindex(full_index_region_actor)

                    # Fill NaN values with 0 and convert to integer
                    victims_by_month_year_complete_region_actor = victims_by_month_year_complete_region_actor.fillna(0).astype(int)

                    # Convert Series back to a DataFrame with 'VictimsCount'
                    grouped_victims_region_monthly_actor = victims_by_month_year_complete_region_actor.reset_index(name='VictimsCount')

                    # Sort the DataFrame chronologically and by violence type
                    grouped_victims_region_monthly_actor = grouped_victims_region_monthly_actor.sort_values(by=['Año', 'Mes', 'violence type']).reset_index(drop=True)

                    # --- Deduplication (Crucial Step) ---
                    initial_rows = len(grouped_victims_region_monthly_actor)
                    grouped_victims_region_monthly_actor.drop_duplicates(subset=['Año', 'Mes', 'violence type'], inplace=True)
                    if len(grouped_victims_region_monthly_actor) < initial_rows:
                        print(f"Warning: Removed {initial_rows - len(grouped_victims_region_monthly_actor)} duplicate rows for (Año, Mes, violence type) within {region_str} - {actor_type} data before saving.")
                    else:
                        print(f"No duplicates found for (Año, Mes, violence type) within {region_str} - {actor_type} data before saving.")

                    # --- Save the results to TSV ---
                    # Filename: 'regionname_victims_actor_type.tsv'
                    filename_region = region_str.replace(" ", "").lower() + f"_victims_{actor_type_clean_name}.tsv"
                    output_path_region = os.path.join(output_dir_actor_type, filename_region)

                    try:
                        grouped_victims_region_monthly_actor.to_csv(output_path_region, sep='\t', index=False)
                        print(f"Saved data for Region ({region_str}, {actor_type}) to {filename_region}")
                    except Exception as e:
                        print(f"Error saving data for Region ({region_str}, {actor_type}) to {filename_region}: {e}")

            print("\nRegion-level victims data processing and saving by ActorType complete.")

    except KeyError as e:
        print(f"Error: Required column not found - {e}. Please check column names in the combined_df or input Excel files.")
    except Exception as e:
        print(f"An unexpected error occurred during processing: {e}")
# Out:
# --- Grouping victims data by Region, Month, Violence Type, and Actor Type (1958-2022) ---
# Filtered victims data for years 1958-2022. Shape: (271382, 12)
# Unique Violence Types found: ['VS' 'VI']
# Unique Actor Types found: ['NON_STATE_ACTOR' 'STATE_ACTOR']
# Found 78 unique regions. Processing each region...
#
# Ensured output directory exists for NON_STATE_ACTOR in regions: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/processed/victims/regions/non_state_actor
#
# Processing region: PIEDEMONTE LLANERO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within PIEDEMONTE LLANERO - NON_STATE_ACTOR data before saving.
# Saved data for Region (PIEDEMONTE LLANERO, NON_STATE_ACTOR) to piedemontellanero_victims_non_state_actor.tsv
#
# Processing region: VALLE DE SAN JUAN for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within VALLE DE SAN JUAN - NON_STATE_ACTOR data before saving.
# Saved data for Region (VALLE DE SAN JUAN, NON_STATE_ACTOR) to valledesanjuan_victims_non_state_actor.tsv
#
# Processing region: ALTA GUAJIRA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ALTA GUAJIRA - NON_STATE_ACTOR data before saving.
# Saved data for Region (ALTA GUAJIRA, NON_STATE_ACTOR) to altaguajira_victims_non_state_actor.tsv
#
# Processing region: SIERRA NEVADA DE SANTA MARTA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SIERRA NEVADA DE SANTA MARTA - NON_STATE_ACTOR data before saving.
# Saved data for Region (SIERRA NEVADA DE SANTA MARTA, NON_STATE_ACTOR) to sierranevadadesantamarta_victims_non_state_actor.tsv
#
# Processing region: CIENAGA GRANDE DE SANTA MARTA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CIENAGA GRANDE DE SANTA MARTA - NON_STATE_ACTOR data before saving.
# Saved data for Region (CIENAGA GRANDE DE SANTA MARTA, NON_STATE_ACTOR) to cienagagrandedesantamarta_victims_non_state_actor.tsv
#
# Processing region: SUR DE MAGDALENA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUR DE MAGDALENA - NON_STATE_ACTOR data before saving.
# Saved data for Region (SUR DE MAGDALENA, NON_STATE_ACTOR) to surdemagdalena_victims_non_state_actor.tsv
#
# Processing region: ARIARI GUAYABERO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ARIARI GUAYABERO - NON_STATE_ACTOR data before saving.
# Saved data for Region (ARIARI GUAYABERO, NON_STATE_ACTOR) to ariariguayabero_victims_non_state_actor.tsv
#
# Processing region: ANDEN PACIFICO SUR for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ANDEN PACIFICO SUR - NON_STATE_ACTOR data before saving.
# Saved data for Region (ANDEN PACIFICO SUR, NON_STATE_ACTOR) to andenpacificosur_victims_non_state_actor.tsv
#
# Processing region: AREA METROPOLITANA DE CUCUTA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within AREA METROPOLITANA DE CUCUTA - NON_STATE_ACTOR data before saving.
# Saved data for Region (AREA METROPOLITANA DE CUCUTA, NON_STATE_ACTOR) to areametropolitanadecucuta_victims_non_state_actor.tsv
#
# Processing region: EJE CAFETERO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within EJE CAFETERO - NON_STATE_ACTOR data before saving.
# Saved data for Region (EJE CAFETERO, NON_STATE_ACTOR) to ejecafetero_victims_non_state_actor.tsv
#
# Processing region: PROVINCIA DE SOTO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within PROVINCIA DE SOTO - NON_STATE_ACTOR data before saving.
# Saved data for Region (PROVINCIA DE SOTO, NON_STATE_ACTOR) to provinciadesoto_victims_non_state_actor.tsv
#
# Processing region: MAGDALENA MEDIO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within MAGDALENA MEDIO - NON_STATE_ACTOR data before saving.
# Saved data for Region (MAGDALENA MEDIO, NON_STATE_ACTOR) to magdalenamedio_victims_non_state_actor.tsv
#
# Processing region: BAJO PUTUMAYO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within BAJO PUTUMAYO - NON_STATE_ACTOR data before saving.
# Saved data for Region (BAJO PUTUMAYO, NON_STATE_ACTOR) to bajoputumayo_victims_non_state_actor.tsv
#
# Processing region: MORROSQUILLO Y SABANAS DE SUCRE for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within MORROSQUILLO Y SABANAS DE SUCRE - NON_STATE_ACTOR data before saving.
# Saved data for Region (MORROSQUILLO Y SABANAS DE SUCRE, NON_STATE_ACTOR) to morrosquilloysabanasdesucre_victims_non_state_actor.tsv
#
# Processing region: MONTES DE MARIA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within MONTES DE MARIA - NON_STATE_ACTOR data before saving.
# Saved data for Region (MONTES DE MARIA, NON_STATE_ACTOR) to montesdemaria_victims_non_state_actor.tsv
#
# Processing region: NORTE DEL TOLIMA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NORTE DEL TOLIMA - NON_STATE_ACTOR data before saving.
# Saved data for Region (NORTE DEL TOLIMA, NON_STATE_ACTOR) to nortedeltolima_victims_non_state_actor.tsv
#
# Processing region: SUR DEL VALLE for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUR DEL VALLE - NON_STATE_ACTOR data before saving.
# Saved data for Region (SUR DEL VALLE, NON_STATE_ACTOR) to surdelvalle_victims_non_state_actor.tsv
#
# Processing region: LLANOS ORIENTALES for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within LLANOS ORIENTALES - NON_STATE_ACTOR data before saving.
# Saved data for Region (LLANOS ORIENTALES, NON_STATE_ACTOR) to llanosorientales_victims_non_state_actor.tsv
#
# Processing region: SARARE for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SARARE - NON_STATE_ACTOR data before saving.
# Saved data for Region (SARARE, NON_STATE_ACTOR) to sarare_victims_non_state_actor.tsv
#
# Processing region: VALLE DE ABURRA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within VALLE DE ABURRA - NON_STATE_ACTOR data before saving.
# Saved data for Region (VALLE DE ABURRA, NON_STATE_ACTOR) to valledeaburra_victims_non_state_actor.tsv
#
# Processing region: URABA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within URABA - NON_STATE_ACTOR data before saving.
# Saved data for Region (URABA, NON_STATE_ACTOR) to uraba_victims_non_state_actor.tsv
#
# Processing region: OCCIDENTE ANTIOQUEÑO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within OCCIDENTE ANTIOQUEÑO - NON_STATE_ACTOR data before saving.
# Saved data for Region (OCCIDENTE ANTIOQUEÑO, NON_STATE_ACTOR) to occidenteantioqueño_victims_non_state_actor.tsv
#
# Processing region: BAJO CAUCA ANTIOQUEÑO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within BAJO CAUCA ANTIOQUEÑO - NON_STATE_ACTOR data before saving.
# Saved data for Region (BAJO CAUCA ANTIOQUEÑO, NON_STATE_ACTOR) to bajocaucaantioqueño_victims_non_state_actor.tsv
#
# Processing region: SUROESTE ANTIOQUEÑO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUROESTE ANTIOQUEÑO - NON_STATE_ACTOR data before saving.
# Saved data for Region (SUROESTE ANTIOQUEÑO, NON_STATE_ACTOR) to suroesteantioqueño_victims_non_state_actor.tsv
#
# Processing region: CANAL DEL DIQUE for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CANAL DEL DIQUE - NON_STATE_ACTOR data before saving.
# Saved data for Region (CANAL DEL DIQUE, NON_STATE_ACTOR) to canaldeldique_victims_non_state_actor.tsv
#
# Processing region: FLORENCIA Y AREA DE INFLUENCIA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within FLORENCIA Y AREA DE INFLUENCIA - NON_STATE_ACTOR data before saving.
# Saved data for Region (FLORENCIA Y AREA DE INFLUENCIA, NON_STATE_ACTOR) to florenciayareadeinfluencia_victims_non_state_actor.tsv
#
# Processing region: ALTO SINU Y SAN JORGE for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ALTO SINU Y SAN JORGE - NON_STATE_ACTOR data before saving.
# Saved data for Region (ALTO SINU Y SAN JORGE, NON_STATE_ACTOR) to altosinuysanjorge_victims_non_state_actor.tsv
#
# Processing region: LA MOJANA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within LA MOJANA - NON_STATE_ACTOR data before saving.
# Saved data for Region (LA MOJANA, NON_STATE_ACTOR) to lamojana_victims_non_state_actor.tsv
#
# Processing region: SUR DEL TOLIMA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUR DEL TOLIMA - NON_STATE_ACTOR data before saving.
# Saved data for Region (SUR DEL TOLIMA, NON_STATE_ACTOR) to surdeltolima_victims_non_state_actor.tsv
#
# Processing region: PROVINCIA DE VELEZ for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within PROVINCIA DE VELEZ - NON_STATE_ACTOR data before saving.
# Saved data for Region (PROVINCIA DE VELEZ, NON_STATE_ACTOR) to provinciadevelez_victims_non_state_actor.tsv
#
# Processing region: NORDESTE ANTIOQUEÑO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NORDESTE ANTIOQUEÑO - NON_STATE_ACTOR data before saving.
# Saved data for Region (NORDESTE ANTIOQUEÑO, NON_STATE_ACTOR) to nordesteantioqueño_victims_non_state_actor.tsv
#
# Processing region: ALTILLANURA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ALTILLANURA - NON_STATE_ACTOR data before saving.
# Saved data for Region (ALTILLANURA, NON_STATE_ACTOR) to altillanura_victims_non_state_actor.tsv
#
# Processing region: CATATUMBO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CATATUMBO - NON_STATE_ACTOR data before saving.
# Saved data for Region (CATATUMBO, NON_STATE_ACTOR) to catatumbo_victims_non_state_actor.tsv
#
# Processing region: SERRANIA DEL PERIJA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SERRANIA DEL PERIJA - NON_STATE_ACTOR data before saving.
# Saved data for Region (SERRANIA DEL PERIJA, NON_STATE_ACTOR) to serraniadelperija_victims_non_state_actor.tsv
#
# Processing region: ORIENTE ANTIOQUEÑO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ORIENTE ANTIOQUEÑO - NON_STATE_ACTOR data before saving.
# Saved data for Region (ORIENTE ANTIOQUEÑO, NON_STATE_ACTOR) to orienteantioqueño_victims_non_state_actor.tsv
#
# Processing region: NORTE DEL CAUCA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NORTE DEL CAUCA - NON_STATE_ACTOR data before saving.
# Saved data for Region (NORTE DEL CAUCA, NON_STATE_ACTOR) to nortedelcauca_victims_non_state_actor.tsv
#
# Processing region: NORTE DEL VALLE for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NORTE DEL VALLE - NON_STATE_ACTOR data before saving.
# Saved data for Region (NORTE DEL VALLE, NON_STATE_ACTOR) to nortedelvalle_victims_non_state_actor.tsv
#
# Processing region: CENTRO DEL VALLE for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CENTRO DEL VALLE - NON_STATE_ACTOR data before saving.
# Saved data for Region (CENTRO DEL VALLE, NON_STATE_ACTOR) to centrodelvalle_victims_non_state_actor.tsv
#
# Processing region: SUMAPAZ for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUMAPAZ - NON_STATE_ACTOR data before saving.
# Saved data for Region (SUMAPAZ, NON_STATE_ACTOR) to sumapaz_victims_non_state_actor.tsv
#
# Processing region: SUR DEL HUILA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUR DEL HUILA - NON_STATE_ACTOR data before saving.
# Saved data for Region (SUR DEL HUILA, NON_STATE_ACTOR) to surdelhuila_victims_non_state_actor.tsv
#
# Processing region: PATIA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within PATIA - NON_STATE_ACTOR data before saving.
# Saved data for Region (PATIA, NON_STATE_ACTOR) to patia_victims_non_state_actor.tsv
#
# Processing region: NORTE DEL HUILA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NORTE DEL HUILA - NON_STATE_ACTOR data before saving.
# Saved data for Region (NORTE DEL HUILA, NON_STATE_ACTOR) to nortedelhuila_victims_non_state_actor.tsv
#
# Processing region: ALTIPLANO CUNDIBOYACENSE for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ALTIPLANO CUNDIBOYACENSE - NON_STATE_ACTOR data before saving.
# Saved data for Region (ALTIPLANO CUNDIBOYACENSE, NON_STATE_ACTOR) to altiplanocundiboyacense_victims_non_state_actor.tsv
#
# Processing region: CENTRO DEL HUILA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CENTRO DEL HUILA - NON_STATE_ACTOR data before saving.
# Saved data for Region (CENTRO DEL HUILA, NON_STATE_ACTOR) to centrodelhuila_victims_non_state_actor.tsv
#
# Processing region: SIN INFORMACION for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SIN INFORMACION - NON_STATE_ACTOR data before saving.
# Saved data for Region (SIN INFORMACION, NON_STATE_ACTOR) to sininformacion_victims_non_state_actor.tsv
#
# Processing region: CENTRO DE NARIÑO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CENTRO DE NARIÑO - NON_STATE_ACTOR data before saving.
# Saved data for Region (CENTRO DE NARIÑO, NON_STATE_ACTOR) to centrodenariño_victims_non_state_actor.tsv
#
# Processing region: CAGUAN for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CAGUAN - NON_STATE_ACTOR data before saving.
# Saved data for Region (CAGUAN, NON_STATE_ACTOR) to caguan_victims_non_state_actor.tsv
#
# Processing region: NOROCCIDENTE DE CUNDINAMARCA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NOROCCIDENTE DE CUNDINAMARCA - NON_STATE_ACTOR data before saving.
# Saved data for Region (NOROCCIDENTE DE CUNDINAMARCA, NON_STATE_ACTOR) to noroccidentedecundinamarca_victims_non_state_actor.tsv
#
# Processing region: SUR DE CESAR for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUR DE CESAR - NON_STATE_ACTOR data before saving.
# Saved data for Region (SUR DE CESAR, NON_STATE_ACTOR) to surdecesar_victims_non_state_actor.tsv
#
# Processing region: LITORAL PACIFICO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within LITORAL PACIFICO - NON_STATE_ACTOR data before saving.
# Saved data for Region (LITORAL PACIFICO, NON_STATE_ACTOR) to litoralpacifico_victims_non_state_actor.tsv
#
# Processing region: PROVINCIA DE RICAURTE for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within PROVINCIA DE RICAURTE - NON_STATE_ACTOR data before saving.
# Saved data for Region (PROVINCIA DE RICAURTE, NON_STATE_ACTOR) to provinciadericaurte_victims_non_state_actor.tsv
#
# Processing region: ATRATO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ATRATO - NON_STATE_ACTOR data before saving.
# Saved data for Region (ATRATO, NON_STATE_ACTOR) to atrato_victims_non_state_actor.tsv
#
# Processing region: PROVINCIA COMUNERA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within PROVINCIA COMUNERA - NON_STATE_ACTOR data before saving.
# Saved data for Region (PROVINCIA COMUNERA, NON_STATE_ACTOR) to provinciacomunera_victims_non_state_actor.tsv
#
# Processing region: AMAZONIA SUR-ORIENTAL for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within AMAZONIA SUR-ORIENTAL - NON_STATE_ACTOR data before saving.
# Saved data for Region (AMAZONIA SUR-ORIENTAL, NON_STATE_ACTOR) to amazoniasur-oriental_victims_non_state_actor.tsv
#
# Processing region: NORTE DE ANTIOQUIA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NORTE DE ANTIOQUIA - NON_STATE_ACTOR data before saving.
# Saved data for Region (NORTE DE ANTIOQUIA, NON_STATE_ACTOR) to nortedeantioquia_victims_non_state_actor.tsv
#
# Processing region: NORTE DE CORDOBA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NORTE DE CORDOBA - NON_STATE_ACTOR data before saving.
# Saved data for Region (NORTE DE CORDOBA, NON_STATE_ACTOR) to nortedecordoba_victims_non_state_actor.tsv
#
# Processing region: SUR DE BOLIVAR for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUR DE BOLIVAR - NON_STATE_ACTOR data before saving.
# Saved data for Region (SUR DE BOLIVAR, NON_STATE_ACTOR) to surdebolivar_victims_non_state_actor.tsv
#
# Processing region: AREA METROPOLITANA DE BOGOTA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within AREA METROPOLITANA DE BOGOTA - NON_STATE_ACTOR data before saving.
# Saved data for Region (AREA METROPOLITANA DE BOGOTA, NON_STATE_ACTOR) to areametropolitanadebogota_victims_non_state_actor.tsv
#
# Processing region: MACIZO COLOMBIANO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within MACIZO COLOMBIANO - NON_STATE_ACTOR data before saving.
# Saved data for Region (MACIZO COLOMBIANO, NON_STATE_ACTOR) to macizocolombiano_victims_non_state_actor.tsv
#
# Processing region: PROVINCIA DE GARCIA ROVIRA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within PROVINCIA DE GARCIA ROVIRA - NON_STATE_ACTOR data before saving.
# Saved data for Region (PROVINCIA DE GARCIA ROVIRA, NON_STATE_ACTOR) to provinciadegarciarovira_victims_non_state_actor.tsv
#
# Processing region: SUROCCIDENTE DE NORTE DE SANTANDER for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUROCCIDENTE DE NORTE DE SANTANDER - NON_STATE_ACTOR data before saving.
# Saved data for Region (SUROCCIDENTE DE NORTE DE SANTANDER, NON_STATE_ACTOR) to suroccidentedenortedesantander_victims_non_state_actor.tsv
#
# Processing region: OCCIDENTE DE NARIÑO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within OCCIDENTE DE NARIÑO - NON_STATE_ACTOR data before saving.
# Saved data for Region (OCCIDENTE DE NARIÑO, NON_STATE_ACTOR) to occidentedenariño_victims_non_state_actor.tsv
#
# Processing region: PROVINCIA DE GUANENTA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within PROVINCIA DE GUANENTA - NON_STATE_ACTOR data before saving.
# Saved data for Region (PROVINCIA DE GUANENTA, NON_STATE_ACTOR) to provinciadeguanenta_victims_non_state_actor.tsv
#
# Processing region: ORIENTE DE BOYACA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ORIENTE DE BOYACA - NON_STATE_ACTOR data before saving.
# Saved data for Region (ORIENTE DE BOYACA, NON_STATE_ACTOR) to orientedeboyaca_victims_non_state_actor.tsv
#
# Processing region: CENTRO DE NORTE DE SANTANDER for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CENTRO DE NORTE DE SANTANDER - NON_STATE_ACTOR data before saving.
# Saved data for Region (CENTRO DE NORTE DE SANTANDER, NON_STATE_ACTOR) to centrodenortedesantander_victims_non_state_actor.tsv
#
# Processing region: MEDIO PUTUMAYO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within MEDIO PUTUMAYO - NON_STATE_ACTOR data before saving.
# Saved data for Region (MEDIO PUTUMAYO, NON_STATE_ACTOR) to medioputumayo_victims_non_state_actor.tsv
#
# Processing region: CENTRO ORIENTE DE ATLANTICO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CENTRO ORIENTE DE ATLANTICO - NON_STATE_ACTOR data before saving.
# Saved data for Region (CENTRO ORIENTE DE ATLANTICO, NON_STATE_ACTOR) to centroorientedeatlantico_victims_non_state_actor.tsv
#
# Processing region: NORTE DE ATLANTICO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NORTE DE ATLANTICO - NON_STATE_ACTOR data before saving.
# Saved data for Region (NORTE DE ATLANTICO, NON_STATE_ACTOR) to nortedeatlantico_victims_non_state_actor.tsv
#
# Processing region: OCCIDENTE DE ATLANTICO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within OCCIDENTE DE ATLANTICO - NON_STATE_ACTOR data before saving.
# Saved data for Region (OCCIDENTE DE ATLANTICO, NON_STATE_ACTOR) to occidentedeatlantico_victims_non_state_actor.tsv
#
# Processing region: SUR DE NARIÑO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUR DE NARIÑO - NON_STATE_ACTOR data before saving.
# Saved data for Region (SUR DE NARIÑO, NON_STATE_ACTOR) to surdenariño_victims_non_state_actor.tsv
#
# Processing region: MAGDALENA MEDIO ANTIOQUEÑO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within MAGDALENA MEDIO ANTIOQUEÑO - NON_STATE_ACTOR data before saving.
# Saved data for Region (MAGDALENA MEDIO ANTIOQUEÑO, NON_STATE_ACTOR) to magdalenamedioantioqueño_victims_non_state_actor.tsv
#
# Processing region: SUROCCIDENTE DE CUNDINAMARCA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUROCCIDENTE DE CUNDINAMARCA - NON_STATE_ACTOR data before saving.
# Saved data for Region (SUROCCIDENTE DE CUNDINAMARCA, NON_STATE_ACTOR) to suroccidentedecundinamarca_victims_non_state_actor.tsv
#
# Processing region: ALTO PUTUMAYO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ALTO PUTUMAYO - NON_STATE_ACTOR data before saving.
# Saved data for Region (ALTO PUTUMAYO, NON_STATE_ACTOR) to altoputumayo_victims_non_state_actor.tsv
#
# Processing region: NORTE DE NARIÑO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NORTE DE NARIÑO - NON_STATE_ACTOR data before saving.
# Saved data for Region (NORTE DE NARIÑO, NON_STATE_ACTOR) to nortedenariño_victims_non_state_actor.tsv
#
# Processing region: SERRANIA DE LOS YARIGUIES for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SERRANIA DE LOS YARIGUIES - NON_STATE_ACTOR data before saving.
# Saved data for Region (SERRANIA DE LOS YARIGUIES, NON_STATE_ACTOR) to serraniadelosyariguies_victims_non_state_actor.tsv
#
# Processing region: SURORIENTE DE NORTE DE SANTANDER for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SURORIENTE DE NORTE DE SANTANDER - NON_STATE_ACTOR data before saving.
# Saved data for Region (SURORIENTE DE NORTE DE SANTANDER, NON_STATE_ACTOR) to surorientedenortedesantander_victims_non_state_actor.tsv
#
# Processing region: CENTRO OCCIDENTE DE NARIÑO for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CENTRO OCCIDENTE DE NARIÑO - NON_STATE_ACTOR data before saving.
# Saved data for Region (CENTRO OCCIDENTE DE NARIÑO, NON_STATE_ACTOR) to centrooccidentedenariño_victims_non_state_actor.tsv
#
# Processing region: ARCHIPIELAGO DE SAN ANDRES, PROVIDENCIA Y SANTA CATALINA for ActorType: NON_STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ARCHIPIELAGO DE SAN ANDRES, PROVIDENCIA Y SANTA CATALINA - NON_STATE_ACTOR data before saving.
# Saved data for Region (ARCHIPIELAGO DE SAN ANDRES, PROVIDENCIA Y SANTA CATALINA, NON_STATE_ACTOR) to archipielagodesanandres,providenciaysantacatalina_victims_non_state_actor.tsv
#
# Ensured output directory exists for STATE_ACTOR in regions: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/processed/victims/regions/state_actor
#
# Processing region: PIEDEMONTE LLANERO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within PIEDEMONTE LLANERO - STATE_ACTOR data before saving.
# Saved data for Region (PIEDEMONTE LLANERO, STATE_ACTOR) to piedemontellanero_victims_state_actor.tsv
#
# Processing region: VALLE DE SAN JUAN for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within VALLE DE SAN JUAN - STATE_ACTOR data before saving.
# Saved data for Region (VALLE DE SAN JUAN, STATE_ACTOR) to valledesanjuan_victims_state_actor.tsv
#
# Processing region: ALTA GUAJIRA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ALTA GUAJIRA - STATE_ACTOR data before saving.
# Saved data for Region (ALTA GUAJIRA, STATE_ACTOR) to altaguajira_victims_state_actor.tsv
#
# Processing region: SIERRA NEVADA DE SANTA MARTA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SIERRA NEVADA DE SANTA MARTA - STATE_ACTOR data before saving.
# Saved data for Region (SIERRA NEVADA DE SANTA MARTA, STATE_ACTOR) to sierranevadadesantamarta_victims_state_actor.tsv
#
# Processing region: CIENAGA GRANDE DE SANTA MARTA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CIENAGA GRANDE DE SANTA MARTA - STATE_ACTOR data before saving.
# Saved data for Region (CIENAGA GRANDE DE SANTA MARTA, STATE_ACTOR) to cienagagrandedesantamarta_victims_state_actor.tsv
#
# Processing region: SUR DE MAGDALENA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUR DE MAGDALENA - STATE_ACTOR data before saving.
# Saved data for Region (SUR DE MAGDALENA, STATE_ACTOR) to surdemagdalena_victims_state_actor.tsv
#
# Processing region: ARIARI GUAYABERO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ARIARI GUAYABERO - STATE_ACTOR data before saving.
# Saved data for Region (ARIARI GUAYABERO, STATE_ACTOR) to ariariguayabero_victims_state_actor.tsv
#
# Processing region: ANDEN PACIFICO SUR for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ANDEN PACIFICO SUR - STATE_ACTOR data before saving.
# Saved data for Region (ANDEN PACIFICO SUR, STATE_ACTOR) to andenpacificosur_victims_state_actor.tsv
#
# Processing region: AREA METROPOLITANA DE CUCUTA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within AREA METROPOLITANA DE CUCUTA - STATE_ACTOR data before saving.
# Saved data for Region (AREA METROPOLITANA DE CUCUTA, STATE_ACTOR) to areametropolitanadecucuta_victims_state_actor.tsv
#
# Processing region: EJE CAFETERO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within EJE CAFETERO - STATE_ACTOR data before saving.
# Saved data for Region (EJE CAFETERO, STATE_ACTOR) to ejecafetero_victims_state_actor.tsv
#
# Processing region: PROVINCIA DE SOTO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within PROVINCIA DE SOTO - STATE_ACTOR data before saving.
# Saved data for Region (PROVINCIA DE SOTO, STATE_ACTOR) to provinciadesoto_victims_state_actor.tsv
#
# Processing region: MAGDALENA MEDIO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within MAGDALENA MEDIO - STATE_ACTOR data before saving.
# Saved data for Region (MAGDALENA MEDIO, STATE_ACTOR) to magdalenamedio_victims_state_actor.tsv
#
# Processing region: BAJO PUTUMAYO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within BAJO PUTUMAYO - STATE_ACTOR data before saving.
# Saved data for Region (BAJO PUTUMAYO, STATE_ACTOR) to bajoputumayo_victims_state_actor.tsv
#
# Processing region: MORROSQUILLO Y SABANAS DE SUCRE for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within MORROSQUILLO Y SABANAS DE SUCRE - STATE_ACTOR data before saving.
# Saved data for Region (MORROSQUILLO Y SABANAS DE SUCRE, STATE_ACTOR) to morrosquilloysabanasdesucre_victims_state_actor.tsv
#
# Processing region: MONTES DE MARIA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within MONTES DE MARIA - STATE_ACTOR data before saving.
# Saved data for Region (MONTES DE MARIA, STATE_ACTOR) to montesdemaria_victims_state_actor.tsv
#
# Processing region: NORTE DEL TOLIMA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NORTE DEL TOLIMA - STATE_ACTOR data before saving.
# Saved data for Region (NORTE DEL TOLIMA, STATE_ACTOR) to nortedeltolima_victims_state_actor.tsv
#
# Processing region: SUR DEL VALLE for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUR DEL VALLE - STATE_ACTOR data before saving.
# Saved data for Region (SUR DEL VALLE, STATE_ACTOR) to surdelvalle_victims_state_actor.tsv
#
# Processing region: LLANOS ORIENTALES for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within LLANOS ORIENTALES - STATE_ACTOR data before saving.
# Saved data for Region (LLANOS ORIENTALES, STATE_ACTOR) to llanosorientales_victims_state_actor.tsv
#
# Processing region: SARARE for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SARARE - STATE_ACTOR data before saving.
# Saved data for Region (SARARE, STATE_ACTOR) to sarare_victims_state_actor.tsv
#
# Processing region: VALLE DE ABURRA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within VALLE DE ABURRA - STATE_ACTOR data before saving.
# Saved data for Region (VALLE DE ABURRA, STATE_ACTOR) to valledeaburra_victims_state_actor.tsv
#
# Processing region: URABA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within URABA - STATE_ACTOR data before saving.
# Saved data for Region (URABA, STATE_ACTOR) to uraba_victims_state_actor.tsv
#
# Processing region: OCCIDENTE ANTIOQUEÑO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within OCCIDENTE ANTIOQUEÑO - STATE_ACTOR data before saving.
# Saved data for Region (OCCIDENTE ANTIOQUEÑO, STATE_ACTOR) to occidenteantioqueño_victims_state_actor.tsv
#
# Processing region: BAJO CAUCA ANTIOQUEÑO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within BAJO CAUCA ANTIOQUEÑO - STATE_ACTOR data before saving.
# Saved data for Region (BAJO CAUCA ANTIOQUEÑO, STATE_ACTOR) to bajocaucaantioqueño_victims_state_actor.tsv
#
# Processing region: SUROESTE ANTIOQUEÑO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUROESTE ANTIOQUEÑO - STATE_ACTOR data before saving.
# Saved data for Region (SUROESTE ANTIOQUEÑO, STATE_ACTOR) to suroesteantioqueño_victims_state_actor.tsv
#
# Processing region: CANAL DEL DIQUE for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CANAL DEL DIQUE - STATE_ACTOR data before saving.
# Saved data for Region (CANAL DEL DIQUE, STATE_ACTOR) to canaldeldique_victims_state_actor.tsv
#
# Processing region: FLORENCIA Y AREA DE INFLUENCIA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within FLORENCIA Y AREA DE INFLUENCIA - STATE_ACTOR data before saving.
# Saved data for Region (FLORENCIA Y AREA DE INFLUENCIA, STATE_ACTOR) to florenciayareadeinfluencia_victims_state_actor.tsv
#
# Processing region: ALTO SINU Y SAN JORGE for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ALTO SINU Y SAN JORGE - STATE_ACTOR data before saving.
# Saved data for Region (ALTO SINU Y SAN JORGE, STATE_ACTOR) to altosinuysanjorge_victims_state_actor.tsv
#
# Processing region: LA MOJANA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within LA MOJANA - STATE_ACTOR data before saving.
# Saved data for Region (LA MOJANA, STATE_ACTOR) to lamojana_victims_state_actor.tsv
#
# Processing region: SUR DEL TOLIMA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUR DEL TOLIMA - STATE_ACTOR data before saving.
# Saved data for Region (SUR DEL TOLIMA, STATE_ACTOR) to surdeltolima_victims_state_actor.tsv
#
# Processing region: PROVINCIA DE VELEZ for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within PROVINCIA DE VELEZ - STATE_ACTOR data before saving.
# Saved data for Region (PROVINCIA DE VELEZ, STATE_ACTOR) to provinciadevelez_victims_state_actor.tsv
#
# Processing region: NORDESTE ANTIOQUEÑO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NORDESTE ANTIOQUEÑO - STATE_ACTOR data before saving.
# Saved data for Region (NORDESTE ANTIOQUEÑO, STATE_ACTOR) to nordesteantioqueño_victims_state_actor.tsv
#
# Processing region: ALTILLANURA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ALTILLANURA - STATE_ACTOR data before saving.
# Saved data for Region (ALTILLANURA, STATE_ACTOR) to altillanura_victims_state_actor.tsv
#
# Processing region: CATATUMBO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CATATUMBO - STATE_ACTOR data before saving.
# Saved data for Region (CATATUMBO, STATE_ACTOR) to catatumbo_victims_state_actor.tsv
#
# Processing region: SERRANIA DEL PERIJA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SERRANIA DEL PERIJA - STATE_ACTOR data before saving.
# Saved data for Region (SERRANIA DEL PERIJA, STATE_ACTOR) to serraniadelperija_victims_state_actor.tsv
#
# Processing region: ORIENTE ANTIOQUEÑO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ORIENTE ANTIOQUEÑO - STATE_ACTOR data before saving.
# Saved data for Region (ORIENTE ANTIOQUEÑO, STATE_ACTOR) to orienteantioqueño_victims_state_actor.tsv
#
# Processing region: NORTE DEL CAUCA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NORTE DEL CAUCA - STATE_ACTOR data before saving.
# Saved data for Region (NORTE DEL CAUCA, STATE_ACTOR) to nortedelcauca_victims_state_actor.tsv
#
# Processing region: NORTE DEL VALLE for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NORTE DEL VALLE - STATE_ACTOR data before saving.
# Saved data for Region (NORTE DEL VALLE, STATE_ACTOR) to nortedelvalle_victims_state_actor.tsv
#
# Processing region: CENTRO DEL VALLE for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CENTRO DEL VALLE - STATE_ACTOR data before saving.
# Saved data for Region (CENTRO DEL VALLE, STATE_ACTOR) to centrodelvalle_victims_state_actor.tsv
#
# Processing region: SUMAPAZ for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUMAPAZ - STATE_ACTOR data before saving.
# Saved data for Region (SUMAPAZ, STATE_ACTOR) to sumapaz_victims_state_actor.tsv
#
# Processing region: SUR DEL HUILA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUR DEL HUILA - STATE_ACTOR data before saving.
# Saved data for Region (SUR DEL HUILA, STATE_ACTOR) to surdelhuila_victims_state_actor.tsv
#
# Processing region: PATIA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within PATIA - STATE_ACTOR data before saving.
# Saved data for Region (PATIA, STATE_ACTOR) to patia_victims_state_actor.tsv
#
# Processing region: NORTE DEL HUILA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NORTE DEL HUILA - STATE_ACTOR data before saving.
# Saved data for Region (NORTE DEL HUILA, STATE_ACTOR) to nortedelhuila_victims_state_actor.tsv
#
# Processing region: ALTIPLANO CUNDIBOYACENSE for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ALTIPLANO CUNDIBOYACENSE - STATE_ACTOR data before saving.
# Saved data for Region (ALTIPLANO CUNDIBOYACENSE, STATE_ACTOR) to altiplanocundiboyacense_victims_state_actor.tsv
#
# Processing region: CENTRO DEL HUILA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CENTRO DEL HUILA - STATE_ACTOR data before saving.
# Saved data for Region (CENTRO DEL HUILA, STATE_ACTOR) to centrodelhuila_victims_state_actor.tsv
#
# Processing region: SIN INFORMACION for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SIN INFORMACION - STATE_ACTOR data before saving.
# Saved data for Region (SIN INFORMACION, STATE_ACTOR) to sininformacion_victims_state_actor.tsv
#
# Processing region: CENTRO DE NARIÑO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CENTRO DE NARIÑO - STATE_ACTOR data before saving.
# Saved data for Region (CENTRO DE NARIÑO, STATE_ACTOR) to centrodenariño_victims_state_actor.tsv
#
# Processing region: CAGUAN for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CAGUAN - STATE_ACTOR data before saving.
# Saved data for Region (CAGUAN, STATE_ACTOR) to caguan_victims_state_actor.tsv
#
# Processing region: NOROCCIDENTE DE CUNDINAMARCA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NOROCCIDENTE DE CUNDINAMARCA - STATE_ACTOR data before saving.
# Saved data for Region (NOROCCIDENTE DE CUNDINAMARCA, STATE_ACTOR) to noroccidentedecundinamarca_victims_state_actor.tsv
#
# Processing region: SUR DE CESAR for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUR DE CESAR - STATE_ACTOR data before saving.
# Saved data for Region (SUR DE CESAR, STATE_ACTOR) to surdecesar_victims_state_actor.tsv
#
# Processing region: LITORAL PACIFICO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within LITORAL PACIFICO - STATE_ACTOR data before saving.
# Saved data for Region (LITORAL PACIFICO, STATE_ACTOR) to litoralpacifico_victims_state_actor.tsv
#
# Processing region: PROVINCIA DE RICAURTE for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within PROVINCIA DE RICAURTE - STATE_ACTOR data before saving.
# Saved data for Region (PROVINCIA DE RICAURTE, STATE_ACTOR) to provinciadericaurte_victims_state_actor.tsv
#
# Processing region: ATRATO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ATRATO - STATE_ACTOR data before saving.
# Saved data for Region (ATRATO, STATE_ACTOR) to atrato_victims_state_actor.tsv
#
# Processing region: PROVINCIA COMUNERA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within PROVINCIA COMUNERA - STATE_ACTOR data before saving.
# Saved data for Region (PROVINCIA COMUNERA, STATE_ACTOR) to provinciacomunera_victims_state_actor.tsv
#
# Processing region: AMAZONIA SUR-ORIENTAL for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within AMAZONIA SUR-ORIENTAL - STATE_ACTOR data before saving.
# Saved data for Region (AMAZONIA SUR-ORIENTAL, STATE_ACTOR) to amazoniasur-oriental_victims_state_actor.tsv
#
# Processing region: NORTE DE ANTIOQUIA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NORTE DE ANTIOQUIA - STATE_ACTOR data before saving.
# Saved data for Region (NORTE DE ANTIOQUIA, STATE_ACTOR) to nortedeantioquia_victims_state_actor.tsv
#
# Processing region: NORTE DE CORDOBA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NORTE DE CORDOBA - STATE_ACTOR data before saving.
# Saved data for Region (NORTE DE CORDOBA, STATE_ACTOR) to nortedecordoba_victims_state_actor.tsv
#
# Processing region: SUR DE BOLIVAR for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUR DE BOLIVAR - STATE_ACTOR data before saving.
# Saved data for Region (SUR DE BOLIVAR, STATE_ACTOR) to surdebolivar_victims_state_actor.tsv
#
# Processing region: AREA METROPOLITANA DE BOGOTA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within AREA METROPOLITANA DE BOGOTA - STATE_ACTOR data before saving.
# Saved data for Region (AREA METROPOLITANA DE BOGOTA, STATE_ACTOR) to areametropolitanadebogota_victims_state_actor.tsv
#
# Processing region: MACIZO COLOMBIANO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within MACIZO COLOMBIANO - STATE_ACTOR data before saving.
# Saved data for Region (MACIZO COLOMBIANO, STATE_ACTOR) to macizocolombiano_victims_state_actor.tsv
#
# Processing region: PROVINCIA DE GARCIA ROVIRA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within PROVINCIA DE GARCIA ROVIRA - STATE_ACTOR data before saving.
# Saved data for Region (PROVINCIA DE GARCIA ROVIRA, STATE_ACTOR) to provinciadegarciarovira_victims_state_actor.tsv
#
# Processing region: SUROCCIDENTE DE NORTE DE SANTANDER for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUROCCIDENTE DE NORTE DE SANTANDER - STATE_ACTOR data before saving.
# Saved data for Region (SUROCCIDENTE DE NORTE DE SANTANDER, STATE_ACTOR) to suroccidentedenortedesantander_victims_state_actor.tsv
#
# Processing region: OCCIDENTE DE NARIÑO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within OCCIDENTE DE NARIÑO - STATE_ACTOR data before saving.
# Saved data for Region (OCCIDENTE DE NARIÑO, STATE_ACTOR) to occidentedenariño_victims_state_actor.tsv
#
# Processing region: PROVINCIA DE GUANENTA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within PROVINCIA DE GUANENTA - STATE_ACTOR data before saving.
# Saved data for Region (PROVINCIA DE GUANENTA, STATE_ACTOR) to provinciadeguanenta_victims_state_actor.tsv
#
# Processing region: ORIENTE DE BOYACA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ORIENTE DE BOYACA - STATE_ACTOR data before saving.
# Saved data for Region (ORIENTE DE BOYACA, STATE_ACTOR) to orientedeboyaca_victims_state_actor.tsv
#
# Processing region: CENTRO DE NORTE DE SANTANDER for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CENTRO DE NORTE DE SANTANDER - STATE_ACTOR data before saving.
# Saved data for Region (CENTRO DE NORTE DE SANTANDER, STATE_ACTOR) to centrodenortedesantander_victims_state_actor.tsv
#
# Processing region: MEDIO PUTUMAYO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within MEDIO PUTUMAYO - STATE_ACTOR data before saving.
# Saved data for Region (MEDIO PUTUMAYO, STATE_ACTOR) to medioputumayo_victims_state_actor.tsv
#
# Processing region: CENTRO ORIENTE DE ATLANTICO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CENTRO ORIENTE DE ATLANTICO - STATE_ACTOR data before saving.
# Saved data for Region (CENTRO ORIENTE DE ATLANTICO, STATE_ACTOR) to centroorientedeatlantico_victims_state_actor.tsv
#
# Processing region: NORTE DE ATLANTICO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NORTE DE ATLANTICO - STATE_ACTOR data before saving.
# Saved data for Region (NORTE DE ATLANTICO, STATE_ACTOR) to nortedeatlantico_victims_state_actor.tsv
#
# Processing region: OCCIDENTE DE ATLANTICO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within OCCIDENTE DE ATLANTICO - STATE_ACTOR data before saving.
# Saved data for Region (OCCIDENTE DE ATLANTICO, STATE_ACTOR) to occidentedeatlantico_victims_state_actor.tsv
#
# Processing region: SUR DE NARIÑO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUR DE NARIÑO - STATE_ACTOR data before saving.
# Saved data for Region (SUR DE NARIÑO, STATE_ACTOR) to surdenariño_victims_state_actor.tsv
#
# Processing region: MAGDALENA MEDIO ANTIOQUEÑO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within MAGDALENA MEDIO ANTIOQUEÑO - STATE_ACTOR data before saving.
# Saved data for Region (MAGDALENA MEDIO ANTIOQUEÑO, STATE_ACTOR) to magdalenamedioantioqueño_victims_state_actor.tsv
#
# Processing region: SUROCCIDENTE DE CUNDINAMARCA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SUROCCIDENTE DE CUNDINAMARCA - STATE_ACTOR data before saving.
# Saved data for Region (SUROCCIDENTE DE CUNDINAMARCA, STATE_ACTOR) to suroccidentedecundinamarca_victims_state_actor.tsv
#
# Processing region: ALTO PUTUMAYO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ALTO PUTUMAYO - STATE_ACTOR data before saving.
# Saved data for Region (ALTO PUTUMAYO, STATE_ACTOR) to altoputumayo_victims_state_actor.tsv
#
# Processing region: NORTE DE NARIÑO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within NORTE DE NARIÑO - STATE_ACTOR data before saving.
# Saved data for Region (NORTE DE NARIÑO, STATE_ACTOR) to nortedenariño_victims_state_actor.tsv
#
# Processing region: SERRANIA DE LOS YARIGUIES for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SERRANIA DE LOS YARIGUIES - STATE_ACTOR data before saving.
# Saved data for Region (SERRANIA DE LOS YARIGUIES, STATE_ACTOR) to serraniadelosyariguies_victims_state_actor.tsv
#
# Processing region: SURORIENTE DE NORTE DE SANTANDER for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within SURORIENTE DE NORTE DE SANTANDER - STATE_ACTOR data before saving.
# Saved data for Region (SURORIENTE DE NORTE DE SANTANDER, STATE_ACTOR) to surorientedenortedesantander_victims_state_actor.tsv
#
# Processing region: CENTRO OCCIDENTE DE NARIÑO for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within CENTRO OCCIDENTE DE NARIÑO - STATE_ACTOR data before saving.
# Saved data for Region (CENTRO OCCIDENTE DE NARIÑO, STATE_ACTOR) to centrooccidentedenariño_victims_state_actor.tsv
#
# Processing region: ARCHIPIELAGO DE SAN ANDRES, PROVIDENCIA Y SANTA CATALINA for ActorType: STATE_ACTOR
# Warning: Removed 1215240 duplicate rows for (Año, Mes, violence type) within ARCHIPIELAGO DE SAN ANDRES, PROVIDENCIA Y SANTA CATALINA - STATE_ACTOR data before saving.
# Saved data for Region (ARCHIPIELAGO DE SAN ANDRES, PROVIDENCIA Y SANTA CATALINA, STATE_ACTOR) to archipielagodesanandres,providenciaysantacatalina_victims_state_actor.tsv
#
# Region-level victims data processing and saving by ActorType complete.
