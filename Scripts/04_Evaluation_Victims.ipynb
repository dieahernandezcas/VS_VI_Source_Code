# %% [markdown]
# # Notebook: Prediction Model Evaluation and Performance Metrics
#
# ## Introduction
# This Jupyter Notebook is designed to evaluate the performance of the violence dynamics prediction model. Its primary purpose is to compare the predictions generated by the 03_Predictions_victims.ipynb notebook (Intensity and Escalation) with the actual observed values (derived from the 02_Intensity_Escalation_victims.ipynb notebook). The objective is to assess the accuracy and reliability of these predictions at various geographical levels (Country, Department, and Region) and, crucially, broken down by armed actor type.
#
# ## Evaluation Methodology
# For each geographical unit (e.g., Colombia, Antioquia, Pacífico) and each violence type (VS, VI, VC), and now also for each armed actor type (State Actors, Non-State Actors, Unknown Actor Type), the notebook performs the following steps:
#
# 1. Data Loading
# Predicted values for 'Intensity' and 'Escalation' (from _victims_predictions.tsv files) and actual (true) values for 'Intensity' and 'Escalation' (from _victims_metrics.tsv files) are loaded. It's important to note that the "Previous State" is used as an input variable for prediction logic, but it is not directly evaluated as a predicted output variable.
#
# 2. Data Alignment and Merging
# The predicted and actual datasets are carefully merged using common identifiers such as 'Year', 'Month', and 'violence type'. This ensures that comparisons are made at the same temporal points and for the same types of violence.
#
# 3. Calculation of Evaluation Metrics
# For each prediction target ('Intensity' and 'Escalation'), the following metrics are calculated:
#
# Confusion Matrix: A table summarizing the performance of a classification algorithm. It shows the number of correct and incorrect predictions, broken down by each class (-1, 0, 1).
#
# Classification Report: A detailed report that includes precision, recall, F1-score, and support for each class, as well as macro and weighted averages. This allows for an in-depth assessment of the model's performance for each category of change (decrease, no change, increase).
#
# 4. Report Generation and Saving
# Evaluation results are generated and saved into plain text files (.txt) following an organized directory structure:
#
# Individual Reports: Separate reports are created for each individual geographical unit (Country, each Department, each Region) within specific subfolders for each armed actor type. This allows for a detailed analysis of the model's performance in each case.
#
# Aggregated/Global Reports: For Department and Region levels, data from all individual units within that level are consolidated to generate a single aggregated evaluation report. This provides an overview of the model's performance on a larger scale, also broken down by actor type. Country-level is already evaluated individually, and its individual report serves as its global view.
#
# ## Output Structure
# The evaluation results will be saved in the following folder structure:
#
# results/
# └── evaluation/
#     └── victims/
#         ├── country/
#         │   ├── state_actors/
#         │   │   └── colombia_evaluation.txt
#         │   ├── non_state_actors/
#         │   │   └── colombia_evaluation.txt
#         │   └── unknown_actor_type/
#         │       └── colombia_evaluation.txt
#         ├── department/
#         │   ├── state_actors/
#         │   │   ├── antioquia_evaluation.txt
#         │   │   ├── bogota_evaluation.txt
#         │   │   └── departments_global_evaluation.txt (aggregated)
#         │   ├── non_state_actors/
#         │   │   ├── antioquia_evaluation.txt
#         │   │   ├── bogota_evaluation.txt
#         │   │   └── departments_global_evaluation.txt (aggregated)
#         │   └── unknown_actor_type/
#         │       ├── antioquia_evaluation.txt
#         │       ├── bogota_evaluation.txt
#         │       └── departments_global_evaluation.txt (aggregated)
#         └── region/
#             ├── state_actors/
#             │   ├── pacifica_evaluation.txt
#             │   ├── caribe_evaluation.txt
#             │   └── regions_global_evaluation.txt (aggregated)
#             ├── non_state_actors/
#             │   ├── pacifica_evaluation.txt
#             │   ├── caribe_evaluation.txt
#             │   └── regions_global_evaluation.txt (aggregated)
#             └── unknown_actor_type/
#                 ├── pacifica_evaluation.txt
#                 ├── caribe_evaluation.txt
#                 └── regions_global_evaluation.txt (aggregated)
#
# This comprehensive evaluation approach allows for a detailed understanding of the model's robustness and applicability across diverse geographical conditions and among different types of actors responsible for violence.

# %% [markdown]
# ### 1. Initial Setup, Library Imports, and Path Configuration
# This block performs the initial setup for the model evaluation notebook. It includes importing all necessary Python libraries for data handling, file system operations, and, crucially, for calculating classification metrics. It defines the relative paths for both the input directories containing the predicted data (from the prediction notebook) and the actual/true data (from the metrics calculation notebook), now accounting for the nested ActorType subfolders. It also sets up the output directory where the final evaluation results will be saved, maintaining the same nested structure.

# %%
# 1. Initial Setup, Library Imports, and Path Configuration

import pandas as pd
import os
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import sys # Added for stdout redirection in Cell 4 and Cell 3
import io # Added for output buffering in Cell 3 and Cell 4

# Define the base input directory for predicted data (output from the prediction notebook)
# This directory now contains subfolders like 'country/state_actors', 'department/non_state_actors', etc.
predicted_data_base_dir = os.path.join(os.getcwd(), '..', 'Results', 'predictions', 'victims')

# Define the base input directory for actual/true data (output from the metrics calculation notebook)
# This directory also contains subfolders like 'country/state_actors', 'department/non_state_actors', etc.
actual_data_base_dir = os.path.join(os.getcwd(), '..', 'Results', 'intensity & escalation', 'victims')

# Define the base output directory for evaluation results
# Evaluation results will be saved following a similar nested structure.
evaluation_results_base_dir = os.path.join(os.getcwd(), '..', 'Results', 'evaluation', 'victims')

# List of actor types subfolders to iterate through.
ACTOR_TYPES_SUBFOLDERS = ['state_actor', 'non_state_actor', 'unknown_actor_type']

# Define possible labels for classification reports to ensure all classes are shown consistently.
# These should cover all possible values for Intensity and Escalation.
intensity_escalation_labels = [-1, 0, 1]
# Note: 'Previous State' is no longer a prediction target, so its specific labels are not strictly needed
# for the output reports, but can be kept for consistency if evaluating the true Previous State distribution.
# state_labels = sorted(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'Start']) # No longer needed for prediction eval.

print("Initial setup, library imports, and path configuration complete for evaluation.")
print(f"Predicted data will be read from: {predicted_data_base_dir}")
print(f"Actual data will be read from: {actual_data_base_dir}")
print(f"Evaluation results will be saved in: {evaluation_results_base_dir}")
print(f"Processing will be segmented by Actor Types: {ACTOR_TYPES_SUBFOLDERS}")

# Create the top-level evaluation results directory if it doesn't exist.
# Subdirectories for levels and actor types will be created later.
os.makedirs(evaluation_results_base_dir, exist_ok=True)
# Out:
# Initial setup, library imports, and path configuration complete for evaluation.
# Predicted data will be read from: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/predictions/victims
# Actual data will be read from: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/intensity & escalation/victims
# Evaluation results will be saved in: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/evaluation/victims
# Processing will be segmented by Actor Types: ['state_actor', 'non_state_actor', 'unknown_actor_type']

# %% [markdown]
# ### 2. Define Evaluation Logic Functions
# This block defines the core functions required for evaluating the model's predictions. These functions facilitate the comparison between actual and predicted values and the generation of performance metrics.
#
# align_and_merge_data(df_actual, df_predicted): A helper function to merge the actual and predicted DataFrames based on common temporal and type identifiers (Año, Mes, violence type). This ensures that each prediction is correctly matched with its corresponding true value.
#
# evaluate_predictions(y_true, y_pred, target_name, labels=None): This function takes the true and predicted labels for a specific target variable (e.g., 'State', 'Intensity', 'Escalation'). It then calculates and prints the confusion matrix and a detailed classification report, providing insights into the model's performance for each class.

# %%
# 2. Define Evaluation Logic Functions

print("\n--- Defining Evaluation Logic Functions ---")

def align_and_merge_data(df_actual, df_predicted):
    """
    Merges actual and predicted DataFrames on common identifiers to prepare for evaluation.

    Args:
        df_actual (pd.DataFrame): DataFrame containing actual values (from _victims_metrics.tsv).
                                  Expected columns: 'Año', 'Mes', 'violence type',
                                  'Previous State', 'Intensity', 'Escalation'.
        df_predicted (pd.DataFrame): DataFrame containing predicted values (from _victims_predictions.tsv).
                                   Expected columns: 'Año', 'Mes', 'violence type',
                                   'Predicted_State', 'Predicted_Intensity', 'Predicted_Escalation'.

    Returns:
        pd.DataFrame: A merged DataFrame with actual and predicted values aligned,
                      or an empty DataFrame if merging fails or results in no common data.
    """
    # Define common columns for merging
    merge_cols = ['Año', 'Mes', 'violence type']

    # Perform an inner merge to keep only rows present in both DataFrames
    # This ensures we only compare predictions where we have corresponding actual values.
    merged_df = pd.merge(df_actual, df_predicted, on=merge_cols, how='inner', suffixes=('_actual', '_predicted'))

    if merged_df.empty:
        print("Warning: Merging actual and predicted data resulted in an empty DataFrame. Check data alignment.")
        return pd.DataFrame()

    # Sort the merged DataFrame to ensure consistent order for evaluation
    merged_df = merged_df.sort_values(by=merge_cols).reset_index(drop=True)

    return merged_df

def evaluate_predictions(y_true, y_pred, target_name, labels=None):
    """
    Calculates and prints the confusion matrix and classification report for predictions.

    Args:
        y_true (pd.Series or list): Actual (true) labels.
        y_pred (pd.Series or list): Predicted labels.
        target_name (str): Name of the target variable being evaluated (e.g., 'State', 'Intensity').
        labels (list, optional): List of unique labels to consider. If None, labels are inferred from y_true/y_pred.
                                 Useful for ensuring all classes are represented in the report, even if not predicted.
    """
    print(f"\n--- Evaluation for {target_name} ---")

    if len(y_true) == 0 or len(y_pred) == 0:
        print(f"No data available for {target_name} evaluation.")
        return

    # Generate Confusion Matrix
    # If labels are provided, use them to ensure consistent matrix shape and class order
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    print(f"\nConfusion Matrix for {target_name}:")
    print(cm)

    # Generate Classification Report
    # zero_division handles how to report precision/recall for classes with no true samples or no predicted samples.
    # 'warn' will issue a warning, '0' will set to 0.0, 'np.nan' will set to NaN.
    # We use 'None' to let sklearn handle it (usually 0.0 for precision/recall where support is 0).
    report = classification_report(y_true, y_pred, labels=labels, zero_division=0)
    print(f"\nClassification Report for {target_name}:")
    print(report)

print("Evaluation logic functions defined.")
# Out:
# --- Defining Evaluation Logic Functions ---
# Evaluation logic functions defined.

# %% [markdown]
# ### 3. Perform Evaluation and Save Results (Individual Units)
# This block orchestrates the evaluation process for the predictions generated in the previous notebook. It iterates through each geographical level (Country, Department, Region) and then through each defined ActorType (State Actor, Non-State Actor, Unknown).
#
# For each specific combination of geographical unit, violence type (VS, VI, VC), and actor type, the process is as follows:
#
# Data Loading: It loads the relevant actual metrics data (_victims_metrics.tsv) and predicted values (_victims_predictions.tsv) for the corresponding unit and actor type.
#
# Data Alignment and Merging: The actual and predicted datasets are merged based on common identifiers (Año, Mes, violence type) to ensure a correct comparison of month-by-month predictions.
#
# Evaluation Metrics Calculation: For both 'Intensity' and 'Escalation' prediction targets, it calculates:
#
# Confusion Matrix: To visualize the correct and incorrect classifications for each category (-1, 0, 1).
#
# Classification Report: Providing precision, recall, f1-score, and support for each class, as well as overall averages.
#
# Results Saving (Individual Reports): The confusion matrices and classification reports for each individual unit (Country, Department, Region) and actor type are saved to separate text files within a structured output directory (../Results/evaluation/victims/{level}/{actor_type}/).
#
# This comprehensive evaluation at the individual unit level allows for a granular assessment of model performance across different geographical contexts and responsible actors.

# %%
# 3. Perform Evaluation and Save Results (Individual Units)

print("\n--- Performing Evaluation and Saving Individual Unit Results ---")

# Ensure required global variables are defined
if 'predicted_data_base_dir' not in globals() or \
   'actual_data_base_dir' not in globals() or \
   'evaluation_results_base_dir' not in globals() or \
   'ACTOR_TYPES_SUBFOLDERS' not in globals() or \
   'intensity_escalation_labels' not in globals() or \
   'io' not in globals() or \
   'sys' not in globals():
    print("Error: Required global variables or functions not found. Please run Cell 1 and Cell 2.")
else:
    # Define the geographical levels for iteration
    levels_info = [
        {'name': 'Country', 'input_subdir_actual': 'country', 'input_subdir_predicted': 'country'},
        {'name': 'Department', 'input_subdir_actual': 'department', 'input_subdir_predicted': 'department'},
        {'name': 'Region', 'input_subdir_actual': 'region', 'input_subdir_predicted': 'region'}
    ]

    # Targets for evaluation (Intensity and Escalation)
    prediction_targets = ['Intensity', 'Escalation']

    for level in levels_info:
        level_name = level['name']
        actual_base_level_dir = os.path.join(actual_data_base_dir, level['input_subdir_actual'])
        predicted_base_level_dir = os.path.join(predicted_data_base_dir, level['input_subdir_predicted'])

        print(f"\n=======================================================")
        print(f"=== Starting Evaluation for {level_name} Level ===")
        print(f"=======================================================")

        # Loop through each actor type subfolder
        for actor_type_subfolder in ACTOR_TYPES_SUBFOLDERS:
            current_actual_dir = os.path.join(actual_base_level_dir, actor_type_subfolder)
            current_predicted_dir = os.path.join(predicted_base_level_dir, actor_type_subfolder)
            current_output_dir = os.path.join(evaluation_results_base_dir, level_name.lower(), actor_type_subfolder)

            print(f"\n--- Processing {level_name} Level for Actor Type: {actor_type_subfolder} ---")

            # Create the output directory for this level and actor type if it doesn't exist
            os.makedirs(current_output_dir, exist_ok=True)
            print(f"Ensured output directory exists: {current_output_dir}")

            # Check if input directories exist
            if not os.path.exists(current_actual_dir):
                print(f"Error: Actual data directory not found for {level_name} ({actor_type_subfolder}): {current_actual_dir}. Skipping.")
                continue
            if not os.path.exists(current_predicted_dir):
                print(f"Error: Predicted data directory not found for {level_name} ({actor_type_subfolder}): {current_predicted_dir}. Skipping.")
                continue

            # List all actual and predicted TSV files in their respective directories
            # Assuming filenames are consistent: 'unitname_victims_metrics.tsv' for actual, 'unitname_victims_predictions.tsv' for predicted
            actual_files = {f.replace("_victims_metrics.tsv", ""): os.path.join(current_actual_dir, f)
                            for f in os.listdir(current_actual_dir) if f.endswith('_victims_metrics.tsv')}
            predicted_files = {f.replace("_victims_predictions.tsv", ""): os.path.join(current_predicted_dir, f)
                               for f in os.listdir(current_predicted_dir) if f.endswith('_victims_predictions.tsv')}

            # Find common units between actual and predicted files
            common_units = sorted(list(set(actual_files.keys()) & set(predicted_files.keys())))

            if not common_units:
                print(f"Warning: No matching actual and predicted files found for {level_name} ({actor_type_subfolder}). Skipping evaluation.")
                continue

            print(f"Found {len(common_units)} common units for {level_name} ({actor_type_subfolder}). Evaluating each...")

            for unit_name in common_units:
                actual_file_path = actual_files[unit_name]
                predicted_file_path = predicted_files[unit_name]

                print(f"\nEvaluating {level_name}: {unit_name} ({actor_type_subfolder})")
                print(f"  Actual data from: {os.path.basename(actual_file_path)}")
                print(f"  Predicted data from: {os.path.basename(predicted_file_path)}")

                try:
                    df_actual = pd.read_csv(actual_file_path, sep='\t')
                    df_predicted = pd.read_csv(predicted_file_path, sep='\t')

                    # Ensure essential columns for merging and evaluation are present
                    common_cols = ['Año', 'Mes', 'violence type']
                    if not all(col in df_actual.columns for col in common_cols + prediction_targets):
                        print(f"Error: Missing required columns in actual data for {unit_name}. Skipping.")
                        continue
                    if not all(col in df_predicted.columns for col in common_cols + [f'Predicted_{p}' for p in prediction_targets]):
                        print(f"Error: Missing required columns in predicted data for {unit_name}. Skipping.")
                        continue

                    # Merge actual and predicted data
                    # Use 'inner' join to only compare months where both actual and predicted data exist
                    merged_df = pd.merge(df_actual, df_predicted, on=common_cols, how='inner', suffixes=('_actual', '_predicted'))

                    if merged_df.empty:
                        print(f"Warning: Merged data for {unit_name} is empty after alignment. Skipping evaluation.")
                        continue

                    # Evaluate each prediction target (Intensity, Escalation) for each violence type
                    output_buffer = [] # To collect all evaluation reports for the unit

                    output_buffer.append(f"Evaluation Report for {level_name}: {unit_name} (Actor Type: {actor_type_subfolder})\n")
                    output_buffer.append("---------------------------------------------------------------------------\n")

                    # NEW: Loop through each violence type (VS, VI, VC)
                    # Ensure consistent order for output
                    violence_types_to_evaluate = sorted(merged_df['violence type'].unique())

                    for v_type in violence_types_to_evaluate:
                        output_buffer.append(f"\n----- Violence Type: {v_type} -----\n")
                        df_subset_vtype = merged_df[merged_df['violence type'] == v_type].copy()

                        if df_subset_vtype.empty:
                            output_buffer.append(f"  No merged data for {v_type} in {unit_name}. Skipping evaluation for this violence type.\n")
                            continue

                        for target in prediction_targets: # Iterates Intensity, Escalation
                            actual_col = f'{target}'
                            predicted_col = f'Predicted_{target}'

                            if actual_col not in df_subset_vtype.columns or predicted_col not in df_subset_vtype.columns:
                                output_buffer.append(f"  Skipping evaluation for '{target}' (Violence Type: {v_type}): Required columns not found.\n")
                                continue

                            # Ensure data types are consistent and valid for classification
                            df_subset_vtype[actual_col] = pd.to_numeric(df_subset_vtype[actual_col], errors='coerce').fillna(0).astype(int)
                            df_subset_vtype[predicted_col] = pd.to_numeric(df_subset_vtype[predicted_col], errors='coerce').fillna(0).astype(int)

                            # Drop rows with NaN in target columns after conversion (if any happened)
                            eval_data = df_subset_vtype.dropna(subset=[actual_col, predicted_col]).copy()

                            if eval_data.empty:
                                output_buffer.append(f"  No valid data for {target} after cleaning for {v_type} in {unit_name}. Skipping evaluation for this target.\n")
                                continue

                            y_true = eval_data[actual_col]
                            y_pred = eval_data[predicted_col]

                            # Use io.StringIO to capture evaluate_predictions output to buffer
                            temp_output_buffer = io.StringIO()
                            original_stdout = sys.stdout # Save original stdout
                            sys.stdout = temp_output_buffer # Redirect stdout to the buffer

                            # Call evaluate_predictions to print to the redirected buffer
                            evaluate_predictions(y_true, y_pred,
                                                 f"{target} ({v_type})", # Updated target name to include violence type
                                                 labels=intensity_escalation_labels)

                            sys.stdout = original_stdout # Restore original stdout
                            output_buffer.append(temp_output_buffer.getvalue()) # Add captured output to main buffer

                    # Save the evaluation report for the current unit
                    output_filename = f"{unit_name.lower().replace(' ', '')}_evaluation.txt"
                    output_path = os.path.join(current_output_dir, output_filename)

                    try:
                        with open(output_path, 'w') as f:
                            f.writelines(output_buffer)
                        print(f"Saved evaluation report for {level_name}: {unit_name} to {output_filename}")
                    except Exception as e:
                        print(f"Error saving evaluation report for {unit_name}: {e}")

                except Exception as e:
                    print(f"An unexpected error occurred during evaluation for {unit_name}: {e}")

            print(f"\n{level_name}-level individual evaluation for Actor Type: {actor_type_subfolder} complete.")

    print("\n--- Overall Individual Unit Evaluation Process Finished ---")
# Out:
# --- Performing Evaluation and Saving Individual Unit Results ---
#
# =======================================================
# === Starting Evaluation for Country Level ===
# =======================================================
#
# --- Processing Country Level for Actor Type: state_actor ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/evaluation/victims/country/state_actor
# Found 1 common units for Country (state_actor). Evaluating each...
#
# Evaluating Country: colombia (state_actor)
#   Actual data from: colombia_victims_metrics.tsv
#   Predicted data from: colombia_victims_predictions.tsv
# Saved evaluation report for Country: colombia to colombia_evaluation.txt
#
# Country-level individual evaluation for Actor Type: state_actor complete.
#
# --- Processing Country Level for Actor Type: non_state_actor ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/evaluation/victims/country/non_state_actor
# Found 1 common units for Country (non_state_actor). Evaluating each...
#
# Evaluating Country: colombia (non_state_actor)
#   Actual data from: colombia_victims_metrics.tsv
#   Predicted data from: colombia_victims_predictions.tsv
# Saved evaluation report for Country: colombia to colombia_evaluation.txt
#
# Country-level individual evaluation for Actor Type: non_state_actor complete.
#
# --- Processing Country Level for Actor Type: unknown_actor_type ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/evaluation/victims/country/unknown_actor_type
# Warning: No matching actual and predicted files found for Country (unknown_actor_type). Skipping evaluation.
#
# =======================================================
# === Starting Evaluation for Department Level ===
# =======================================================
#
# --- Processing Department Level for Actor Type: state_actor ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/evaluation/victims/department/state_actor
# Found 35 common units for Department (state_actor). Evaluating each...
#
# Evaluating Department: amazonas (state_actor)
#   Actual data from: amazonas_victims_metrics.tsv
#   Predicted data from: amazonas_victims_predictions.tsv
# Saved evaluation report for Department: amazonas to amazonas_evaluation.txt
#
# Evaluating Department: antioquia (state_actor)
#   Actual data from: antioquia_victims_metrics.tsv
#   Predicted data from: antioquia_victims_predictions.tsv
# Saved evaluation report for Department: antioquia to antioquia_evaluation.txt
#
# Evaluating Department: arauca (state_actor)
#   Actual data from: arauca_victims_metrics.tsv
#   Predicted data from: arauca_victims_predictions.tsv
# Saved evaluation report for Department: arauca to arauca_evaluation.txt
#
# Evaluating Department: archipielagodesanandres,providenciaysantacatalina (state_actor)
#   Actual data from: archipielagodesanandres,providenciaysantacatalina_victims_metrics.tsv
#   Predicted data from: archipielagodesanandres,providenciaysantacatalina_victims_predictions.tsv
# Saved evaluation report for Department: archipielagodesanandres,providenciaysantacatalina to archipielagodesanandres,providenciaysantacatalina_evaluation.txt
#
# Evaluating Department: atlantico (state_actor)
#   Actual data from: atlantico_victims_metrics.tsv
#   Predicted data from: atlantico_victims_predictions.tsv
# Saved evaluation report for Department: atlantico to atlantico_evaluation.txt
#
# Evaluating Department: bogota,d.c. (state_actor)
#   Actual data from: bogota,d.c._victims_metrics.tsv
#   Predicted data from: bogota,d.c._victims_predictions.tsv
# Saved evaluation report for Department: bogota,d.c. to bogota,d.c._evaluation.txt
#
# Evaluating Department: bolivar (state_actor)
#   Actual data from: bolivar_victims_metrics.tsv
#   Predicted data from: bolivar_victims_predictions.tsv
# Saved evaluation report for Department: bolivar to bolivar_evaluation.txt
#
# Evaluating Department: boyaca (state_actor)
#   Actual data from: boyaca_victims_metrics.tsv
#   Predicted data from: boyaca_victims_predictions.tsv
# Saved evaluation report for Department: boyaca to boyaca_evaluation.txt
#
# Evaluating Department: caldas (state_actor)
#   Actual data from: caldas_victims_metrics.tsv
#   Predicted data from: caldas_victims_predictions.tsv
# Saved evaluation report for Department: caldas to caldas_evaluation.txt
#
# Evaluating Department: caqueta (state_actor)
#   Actual data from: caqueta_victims_metrics.tsv
#   Predicted data from: caqueta_victims_predictions.tsv
# Saved evaluation report for Department: caqueta to caqueta_evaluation.txt
#
# Evaluating Department: casanare (state_actor)
#   Actual data from: casanare_victims_metrics.tsv
#   Predicted data from: casanare_victims_predictions.tsv
# Saved evaluation report for Department: casanare to casanare_evaluation.txt
#
# Evaluating Department: cauca (state_actor)
#   Actual data from: cauca_victims_metrics.tsv
#   Predicted data from: cauca_victims_predictions.tsv
# Saved evaluation report for Department: cauca to cauca_evaluation.txt
#
# Evaluating Department: cesar (state_actor)
#   Actual data from: cesar_victims_metrics.tsv
#   Predicted data from: cesar_victims_predictions.tsv
# Saved evaluation report for Department: cesar to cesar_evaluation.txt
#
# Evaluating Department: choco (state_actor)
#   Actual data from: choco_victims_metrics.tsv
#   Predicted data from: choco_victims_predictions.tsv
# Saved evaluation report for Department: choco to choco_evaluation.txt
#
# Evaluating Department: cordoba (state_actor)
#   Actual data from: cordoba_victims_metrics.tsv
#   Predicted data from: cordoba_victims_predictions.tsv
# Saved evaluation report for Department: cordoba to cordoba_evaluation.txt
#
# Evaluating Department: cundinamarca (state_actor)
#   Actual data from: cundinamarca_victims_metrics.tsv
#   Predicted data from: cundinamarca_victims_predictions.tsv
# Saved evaluation report for Department: cundinamarca to cundinamarca_evaluation.txt
#
# Evaluating Department: exterior (state_actor)
#   Actual data from: exterior_victims_metrics.tsv
#   Predicted data from: exterior_victims_predictions.tsv
# Saved evaluation report for Department: exterior to exterior_evaluation.txt
#
# Evaluating Department: guainia (state_actor)
#   Actual data from: guainia_victims_metrics.tsv
#   Predicted data from: guainia_victims_predictions.tsv
# Saved evaluation report for Department: guainia to guainia_evaluation.txt
#
# Evaluating Department: guaviare (state_actor)
#   Actual data from: guaviare_victims_metrics.tsv
#   Predicted data from: guaviare_victims_predictions.tsv
# Saved evaluation report for Department: guaviare to guaviare_evaluation.txt
#
# Evaluating Department: huila (state_actor)
#   Actual data from: huila_victims_metrics.tsv
#   Predicted data from: huila_victims_predictions.tsv
# Saved evaluation report for Department: huila to huila_evaluation.txt
#
# Evaluating Department: laguajira (state_actor)
#   Actual data from: laguajira_victims_metrics.tsv
#   Predicted data from: laguajira_victims_predictions.tsv
# Saved evaluation report for Department: laguajira to laguajira_evaluation.txt
#
# Evaluating Department: magdalena (state_actor)
#   Actual data from: magdalena_victims_metrics.tsv
#   Predicted data from: magdalena_victims_predictions.tsv
# Saved evaluation report for Department: magdalena to magdalena_evaluation.txt
#
# Evaluating Department: meta (state_actor)
#   Actual data from: meta_victims_metrics.tsv
#   Predicted data from: meta_victims_predictions.tsv
# Saved evaluation report for Department: meta to meta_evaluation.txt
#
# Evaluating Department: nariño (state_actor)
#   Actual data from: nariño_victims_metrics.tsv
#   Predicted data from: nariño_victims_predictions.tsv
# Saved evaluation report for Department: nariño to nariño_evaluation.txt
#
# Evaluating Department: nortedesantander (state_actor)
#   Actual data from: nortedesantander_victims_metrics.tsv
#   Predicted data from: nortedesantander_victims_predictions.tsv
# Saved evaluation report for Department: nortedesantander to nortedesantander_evaluation.txt
#
# Evaluating Department: putumayo (state_actor)
#   Actual data from: putumayo_victims_metrics.tsv
#   Predicted data from: putumayo_victims_predictions.tsv
# Saved evaluation report for Department: putumayo to putumayo_evaluation.txt
#
# Evaluating Department: quindio (state_actor)
#   Actual data from: quindio_victims_metrics.tsv
#   Predicted data from: quindio_victims_predictions.tsv
# Saved evaluation report for Department: quindio to quindio_evaluation.txt
#
# Evaluating Department: risaralda (state_actor)
#   Actual data from: risaralda_victims_metrics.tsv
#   Predicted data from: risaralda_victims_predictions.tsv
# Saved evaluation report for Department: risaralda to risaralda_evaluation.txt
#
# Evaluating Department: santander (state_actor)
#   Actual data from: santander_victims_metrics.tsv
#   Predicted data from: santander_victims_predictions.tsv
# Saved evaluation report for Department: santander to santander_evaluation.txt
#
# Evaluating Department: sininformacion (state_actor)
#   Actual data from: sininformacion_victims_metrics.tsv
#   Predicted data from: sininformacion_victims_predictions.tsv
# Saved evaluation report for Department: sininformacion to sininformacion_evaluation.txt
#
# Evaluating Department: sucre (state_actor)
#   Actual data from: sucre_victims_metrics.tsv
#   Predicted data from: sucre_victims_predictions.tsv
# Saved evaluation report for Department: sucre to sucre_evaluation.txt
#
# Evaluating Department: tolima (state_actor)
#   Actual data from: tolima_victims_metrics.tsv
#   Predicted data from: tolima_victims_predictions.tsv
# Saved evaluation report for Department: tolima to tolima_evaluation.txt
#
# Evaluating Department: valledelcauca (state_actor)
#   Actual data from: valledelcauca_victims_metrics.tsv
#   Predicted data from: valledelcauca_victims_predictions.tsv
# Saved evaluation report for Department: valledelcauca to valledelcauca_evaluation.txt
#
# Evaluating Department: vaupes (state_actor)
#   Actual data from: vaupes_victims_metrics.tsv
#   Predicted data from: vaupes_victims_predictions.tsv
# Saved evaluation report for Department: vaupes to vaupes_evaluation.txt
#
# Evaluating Department: vichada (state_actor)
#   Actual data from: vichada_victims_metrics.tsv
#   Predicted data from: vichada_victims_predictions.tsv
# Saved evaluation report for Department: vichada to vichada_evaluation.txt
#
# Department-level individual evaluation for Actor Type: state_actor complete.
#
# --- Processing Department Level for Actor Type: non_state_actor ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/evaluation/victims/department/non_state_actor
# Found 35 common units for Department (non_state_actor). Evaluating each...
#
# Evaluating Department: amazonas (non_state_actor)
#   Actual data from: amazonas_victims_metrics.tsv
#   Predicted data from: amazonas_victims_predictions.tsv
# Saved evaluation report for Department: amazonas to amazonas_evaluation.txt
#
# Evaluating Department: antioquia (non_state_actor)
#   Actual data from: antioquia_victims_metrics.tsv
#   Predicted data from: antioquia_victims_predictions.tsv
# Saved evaluation report for Department: antioquia to antioquia_evaluation.txt
#
# Evaluating Department: arauca (non_state_actor)
#   Actual data from: arauca_victims_metrics.tsv
#   Predicted data from: arauca_victims_predictions.tsv
# Saved evaluation report for Department: arauca to arauca_evaluation.txt
#
# Evaluating Department: archipielagodesanandres,providenciaysantacatalina (non_state_actor)
#   Actual data from: archipielagodesanandres,providenciaysantacatalina_victims_metrics.tsv
#   Predicted data from: archipielagodesanandres,providenciaysantacatalina_victims_predictions.tsv
# Saved evaluation report for Department: archipielagodesanandres,providenciaysantacatalina to archipielagodesanandres,providenciaysantacatalina_evaluation.txt
#
# Evaluating Department: atlantico (non_state_actor)
#   Actual data from: atlantico_victims_metrics.tsv
#   Predicted data from: atlantico_victims_predictions.tsv
# Saved evaluation report for Department: atlantico to atlantico_evaluation.txt
#
# Evaluating Department: bogota,d.c. (non_state_actor)
#   Actual data from: bogota,d.c._victims_metrics.tsv
#   Predicted data from: bogota,d.c._victims_predictions.tsv
# Saved evaluation report for Department: bogota,d.c. to bogota,d.c._evaluation.txt
#
# Evaluating Department: bolivar (non_state_actor)
#   Actual data from: bolivar_victims_metrics.tsv
#   Predicted data from: bolivar_victims_predictions.tsv
# Saved evaluation report for Department: bolivar to bolivar_evaluation.txt
#
# Evaluating Department: boyaca (non_state_actor)
#   Actual data from: boyaca_victims_metrics.tsv
#   Predicted data from: boyaca_victims_predictions.tsv
# Saved evaluation report for Department: boyaca to boyaca_evaluation.txt
#
# Evaluating Department: caldas (non_state_actor)
#   Actual data from: caldas_victims_metrics.tsv
#   Predicted data from: caldas_victims_predictions.tsv
# Saved evaluation report for Department: caldas to caldas_evaluation.txt
#
# Evaluating Department: caqueta (non_state_actor)
#   Actual data from: caqueta_victims_metrics.tsv
#   Predicted data from: caqueta_victims_predictions.tsv
# Saved evaluation report for Department: caqueta to caqueta_evaluation.txt
#
# Evaluating Department: casanare (non_state_actor)
#   Actual data from: casanare_victims_metrics.tsv
#   Predicted data from: casanare_victims_predictions.tsv
# Saved evaluation report for Department: casanare to casanare_evaluation.txt
#
# Evaluating Department: cauca (non_state_actor)
#   Actual data from: cauca_victims_metrics.tsv
#   Predicted data from: cauca_victims_predictions.tsv
# Saved evaluation report for Department: cauca to cauca_evaluation.txt
#
# Evaluating Department: cesar (non_state_actor)
#   Actual data from: cesar_victims_metrics.tsv
#   Predicted data from: cesar_victims_predictions.tsv
# Saved evaluation report for Department: cesar to cesar_evaluation.txt
#
# Evaluating Department: choco (non_state_actor)
#   Actual data from: choco_victims_metrics.tsv
#   Predicted data from: choco_victims_predictions.tsv
# Saved evaluation report for Department: choco to choco_evaluation.txt
#
# Evaluating Department: cordoba (non_state_actor)
#   Actual data from: cordoba_victims_metrics.tsv
#   Predicted data from: cordoba_victims_predictions.tsv
# Saved evaluation report for Department: cordoba to cordoba_evaluation.txt
#
# Evaluating Department: cundinamarca (non_state_actor)
#   Actual data from: cundinamarca_victims_metrics.tsv
#   Predicted data from: cundinamarca_victims_predictions.tsv
# Saved evaluation report for Department: cundinamarca to cundinamarca_evaluation.txt
#
# Evaluating Department: exterior (non_state_actor)
#   Actual data from: exterior_victims_metrics.tsv
#   Predicted data from: exterior_victims_predictions.tsv
# Saved evaluation report for Department: exterior to exterior_evaluation.txt
#
# Evaluating Department: guainia (non_state_actor)
#   Actual data from: guainia_victims_metrics.tsv
#   Predicted data from: guainia_victims_predictions.tsv
# Saved evaluation report for Department: guainia to guainia_evaluation.txt
#
# Evaluating Department: guaviare (non_state_actor)
#   Actual data from: guaviare_victims_metrics.tsv
#   Predicted data from: guaviare_victims_predictions.tsv
# Saved evaluation report for Department: guaviare to guaviare_evaluation.txt
#
# Evaluating Department: huila (non_state_actor)
#   Actual data from: huila_victims_metrics.tsv
#   Predicted data from: huila_victims_predictions.tsv
# Saved evaluation report for Department: huila to huila_evaluation.txt
#
# Evaluating Department: laguajira (non_state_actor)
#   Actual data from: laguajira_victims_metrics.tsv
#   Predicted data from: laguajira_victims_predictions.tsv
# Saved evaluation report for Department: laguajira to laguajira_evaluation.txt
#
# Evaluating Department: magdalena (non_state_actor)
#   Actual data from: magdalena_victims_metrics.tsv
#   Predicted data from: magdalena_victims_predictions.tsv
# Saved evaluation report for Department: magdalena to magdalena_evaluation.txt
#
# Evaluating Department: meta (non_state_actor)
#   Actual data from: meta_victims_metrics.tsv
#   Predicted data from: meta_victims_predictions.tsv
# Saved evaluation report for Department: meta to meta_evaluation.txt
#
# Evaluating Department: nariño (non_state_actor)
#   Actual data from: nariño_victims_metrics.tsv
#   Predicted data from: nariño_victims_predictions.tsv
# Saved evaluation report for Department: nariño to nariño_evaluation.txt
#
# Evaluating Department: nortedesantander (non_state_actor)
#   Actual data from: nortedesantander_victims_metrics.tsv
#   Predicted data from: nortedesantander_victims_predictions.tsv
# Saved evaluation report for Department: nortedesantander to nortedesantander_evaluation.txt
#
# Evaluating Department: putumayo (non_state_actor)
#   Actual data from: putumayo_victims_metrics.tsv
#   Predicted data from: putumayo_victims_predictions.tsv
# Saved evaluation report for Department: putumayo to putumayo_evaluation.txt
#
# Evaluating Department: quindio (non_state_actor)
#   Actual data from: quindio_victims_metrics.tsv
#   Predicted data from: quindio_victims_predictions.tsv
# Saved evaluation report for Department: quindio to quindio_evaluation.txt
#
# Evaluating Department: risaralda (non_state_actor)
#   Actual data from: risaralda_victims_metrics.tsv
#   Predicted data from: risaralda_victims_predictions.tsv
# Saved evaluation report for Department: risaralda to risaralda_evaluation.txt
#
# Evaluating Department: santander (non_state_actor)
#   Actual data from: santander_victims_metrics.tsv
#   Predicted data from: santander_victims_predictions.tsv
# Saved evaluation report for Department: santander to santander_evaluation.txt
#
# Evaluating Department: sininformacion (non_state_actor)
#   Actual data from: sininformacion_victims_metrics.tsv
#   Predicted data from: sininformacion_victims_predictions.tsv
# Saved evaluation report for Department: sininformacion to sininformacion_evaluation.txt
#
# Evaluating Department: sucre (non_state_actor)
#   Actual data from: sucre_victims_metrics.tsv
#   Predicted data from: sucre_victims_predictions.tsv
# Saved evaluation report for Department: sucre to sucre_evaluation.txt
#
# Evaluating Department: tolima (non_state_actor)
#   Actual data from: tolima_victims_metrics.tsv
#   Predicted data from: tolima_victims_predictions.tsv
# Saved evaluation report for Department: tolima to tolima_evaluation.txt
#
# Evaluating Department: valledelcauca (non_state_actor)
#   Actual data from: valledelcauca_victims_metrics.tsv
#   Predicted data from: valledelcauca_victims_predictions.tsv
# Saved evaluation report for Department: valledelcauca to valledelcauca_evaluation.txt
#
# Evaluating Department: vaupes (non_state_actor)
#   Actual data from: vaupes_victims_metrics.tsv
#   Predicted data from: vaupes_victims_predictions.tsv
# Saved evaluation report for Department: vaupes to vaupes_evaluation.txt
#
# Evaluating Department: vichada (non_state_actor)
#   Actual data from: vichada_victims_metrics.tsv
#   Predicted data from: vichada_victims_predictions.tsv
# Saved evaluation report for Department: vichada to vichada_evaluation.txt
#
# Department-level individual evaluation for Actor Type: non_state_actor complete.
#
# --- Processing Department Level for Actor Type: unknown_actor_type ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/evaluation/victims/department/unknown_actor_type
# Warning: No matching actual and predicted files found for Department (unknown_actor_type). Skipping evaluation.
#
# =======================================================
# === Starting Evaluation for Region Level ===
# =======================================================
#
# --- Processing Region Level for Actor Type: state_actor ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/evaluation/victims/region/state_actor
# Found 78 common units for Region (state_actor). Evaluating each...
#
# Evaluating Region: altaguajira (state_actor)
#   Actual data from: altaguajira_victims_metrics.tsv
#   Predicted data from: altaguajira_victims_predictions.tsv
# Saved evaluation report for Region: altaguajira to altaguajira_evaluation.txt
#
# Evaluating Region: altillanura (state_actor)
#   Actual data from: altillanura_victims_metrics.tsv
#   Predicted data from: altillanura_victims_predictions.tsv
# Saved evaluation report for Region: altillanura to altillanura_evaluation.txt
#
# Evaluating Region: altiplanocundiboyacense (state_actor)
#   Actual data from: altiplanocundiboyacense_victims_metrics.tsv
#   Predicted data from: altiplanocundiboyacense_victims_predictions.tsv
# Saved evaluation report for Region: altiplanocundiboyacense to altiplanocundiboyacense_evaluation.txt
#
# Evaluating Region: altoputumayo (state_actor)
#   Actual data from: altoputumayo_victims_metrics.tsv
#   Predicted data from: altoputumayo_victims_predictions.tsv
# Saved evaluation report for Region: altoputumayo to altoputumayo_evaluation.txt
#
# Evaluating Region: altosinuysanjorge (state_actor)
#   Actual data from: altosinuysanjorge_victims_metrics.tsv
#   Predicted data from: altosinuysanjorge_victims_predictions.tsv
# Saved evaluation report for Region: altosinuysanjorge to altosinuysanjorge_evaluation.txt
#
# Evaluating Region: amazoniasur-oriental (state_actor)
#   Actual data from: amazoniasur-oriental_victims_metrics.tsv
#   Predicted data from: amazoniasur-oriental_victims_predictions.tsv
# Saved evaluation report for Region: amazoniasur-oriental to amazoniasur-oriental_evaluation.txt
#
# Evaluating Region: andenpacificosur (state_actor)
#   Actual data from: andenpacificosur_victims_metrics.tsv
#   Predicted data from: andenpacificosur_victims_predictions.tsv
# Saved evaluation report for Region: andenpacificosur to andenpacificosur_evaluation.txt
#
# Evaluating Region: archipielagodesanandres,providenciaysantacatalina (state_actor)
#   Actual data from: archipielagodesanandres,providenciaysantacatalina_victims_metrics.tsv
#   Predicted data from: archipielagodesanandres,providenciaysantacatalina_victims_predictions.tsv
# Saved evaluation report for Region: archipielagodesanandres,providenciaysantacatalina to archipielagodesanandres,providenciaysantacatalina_evaluation.txt
#
# Evaluating Region: areametropolitanadebogota (state_actor)
#   Actual data from: areametropolitanadebogota_victims_metrics.tsv
#   Predicted data from: areametropolitanadebogota_victims_predictions.tsv
# Saved evaluation report for Region: areametropolitanadebogota to areametropolitanadebogota_evaluation.txt
#
# Evaluating Region: areametropolitanadecucuta (state_actor)
#   Actual data from: areametropolitanadecucuta_victims_metrics.tsv
#   Predicted data from: areametropolitanadecucuta_victims_predictions.tsv
# Saved evaluation report for Region: areametropolitanadecucuta to areametropolitanadecucuta_evaluation.txt
#
# Evaluating Region: ariariguayabero (state_actor)
#   Actual data from: ariariguayabero_victims_metrics.tsv
#   Predicted data from: ariariguayabero_victims_predictions.tsv
# Saved evaluation report for Region: ariariguayabero to ariariguayabero_evaluation.txt
#
# Evaluating Region: atrato (state_actor)
#   Actual data from: atrato_victims_metrics.tsv
#   Predicted data from: atrato_victims_predictions.tsv
# Saved evaluation report for Region: atrato to atrato_evaluation.txt
#
# Evaluating Region: bajocaucaantioqueño (state_actor)
#   Actual data from: bajocaucaantioqueño_victims_metrics.tsv
#   Predicted data from: bajocaucaantioqueño_victims_predictions.tsv
# Saved evaluation report for Region: bajocaucaantioqueño to bajocaucaantioqueño_evaluation.txt
#
# Evaluating Region: bajoputumayo (state_actor)
#   Actual data from: bajoputumayo_victims_metrics.tsv
#   Predicted data from: bajoputumayo_victims_predictions.tsv
# Saved evaluation report for Region: bajoputumayo to bajoputumayo_evaluation.txt
#
# Evaluating Region: caguan (state_actor)
#   Actual data from: caguan_victims_metrics.tsv
#   Predicted data from: caguan_victims_predictions.tsv
# Saved evaluation report for Region: caguan to caguan_evaluation.txt
#
# Evaluating Region: canaldeldique (state_actor)
#   Actual data from: canaldeldique_victims_metrics.tsv
#   Predicted data from: canaldeldique_victims_predictions.tsv
# Saved evaluation report for Region: canaldeldique to canaldeldique_evaluation.txt
#
# Evaluating Region: catatumbo (state_actor)
#   Actual data from: catatumbo_victims_metrics.tsv
#   Predicted data from: catatumbo_victims_predictions.tsv
# Saved evaluation report for Region: catatumbo to catatumbo_evaluation.txt
#
# Evaluating Region: centrodelhuila (state_actor)
#   Actual data from: centrodelhuila_victims_metrics.tsv
#   Predicted data from: centrodelhuila_victims_predictions.tsv
# Saved evaluation report for Region: centrodelhuila to centrodelhuila_evaluation.txt
#
# Evaluating Region: centrodelvalle (state_actor)
#   Actual data from: centrodelvalle_victims_metrics.tsv
#   Predicted data from: centrodelvalle_victims_predictions.tsv
# Saved evaluation report for Region: centrodelvalle to centrodelvalle_evaluation.txt
#
# Evaluating Region: centrodenariño (state_actor)
#   Actual data from: centrodenariño_victims_metrics.tsv
#   Predicted data from: centrodenariño_victims_predictions.tsv
# Saved evaluation report for Region: centrodenariño to centrodenariño_evaluation.txt
#
# Evaluating Region: centrodenortedesantander (state_actor)
#   Actual data from: centrodenortedesantander_victims_metrics.tsv
#   Predicted data from: centrodenortedesantander_victims_predictions.tsv
# Saved evaluation report for Region: centrodenortedesantander to centrodenortedesantander_evaluation.txt
#
# Evaluating Region: centrooccidentedenariño (state_actor)
#   Actual data from: centrooccidentedenariño_victims_metrics.tsv
#   Predicted data from: centrooccidentedenariño_victims_predictions.tsv
# Saved evaluation report for Region: centrooccidentedenariño to centrooccidentedenariño_evaluation.txt
#
# Evaluating Region: centroorientedeatlantico (state_actor)
#   Actual data from: centroorientedeatlantico_victims_metrics.tsv
#   Predicted data from: centroorientedeatlantico_victims_predictions.tsv
# Saved evaluation report for Region: centroorientedeatlantico to centroorientedeatlantico_evaluation.txt
#
# Evaluating Region: cienagagrandedesantamarta (state_actor)
#   Actual data from: cienagagrandedesantamarta_victims_metrics.tsv
#   Predicted data from: cienagagrandedesantamarta_victims_predictions.tsv
# Saved evaluation report for Region: cienagagrandedesantamarta to cienagagrandedesantamarta_evaluation.txt
#
# Evaluating Region: ejecafetero (state_actor)
#   Actual data from: ejecafetero_victims_metrics.tsv
#   Predicted data from: ejecafetero_victims_predictions.tsv
# Saved evaluation report for Region: ejecafetero to ejecafetero_evaluation.txt
#
# Evaluating Region: florenciayareadeinfluencia (state_actor)
#   Actual data from: florenciayareadeinfluencia_victims_metrics.tsv
#   Predicted data from: florenciayareadeinfluencia_victims_predictions.tsv
# Saved evaluation report for Region: florenciayareadeinfluencia to florenciayareadeinfluencia_evaluation.txt
#
# Evaluating Region: lamojana (state_actor)
#   Actual data from: lamojana_victims_metrics.tsv
#   Predicted data from: lamojana_victims_predictions.tsv
# Saved evaluation report for Region: lamojana to lamojana_evaluation.txt
#
# Evaluating Region: litoralpacifico (state_actor)
#   Actual data from: litoralpacifico_victims_metrics.tsv
#   Predicted data from: litoralpacifico_victims_predictions.tsv
# Saved evaluation report for Region: litoralpacifico to litoralpacifico_evaluation.txt
#
# Evaluating Region: llanosorientales (state_actor)
#   Actual data from: llanosorientales_victims_metrics.tsv
#   Predicted data from: llanosorientales_victims_predictions.tsv
# Saved evaluation report for Region: llanosorientales to llanosorientales_evaluation.txt
#
# Evaluating Region: macizocolombiano (state_actor)
#   Actual data from: macizocolombiano_victims_metrics.tsv
#   Predicted data from: macizocolombiano_victims_predictions.tsv
# Saved evaluation report for Region: macizocolombiano to macizocolombiano_evaluation.txt
#
# Evaluating Region: magdalenamedio (state_actor)
#   Actual data from: magdalenamedio_victims_metrics.tsv
#   Predicted data from: magdalenamedio_victims_predictions.tsv
# Saved evaluation report for Region: magdalenamedio to magdalenamedio_evaluation.txt
#
# Evaluating Region: magdalenamedioantioqueño (state_actor)
#   Actual data from: magdalenamedioantioqueño_victims_metrics.tsv
#   Predicted data from: magdalenamedioantioqueño_victims_predictions.tsv
# Saved evaluation report for Region: magdalenamedioantioqueño to magdalenamedioantioqueño_evaluation.txt
#
# Evaluating Region: medioputumayo (state_actor)
#   Actual data from: medioputumayo_victims_metrics.tsv
#   Predicted data from: medioputumayo_victims_predictions.tsv
# Saved evaluation report for Region: medioputumayo to medioputumayo_evaluation.txt
#
# Evaluating Region: montesdemaria (state_actor)
#   Actual data from: montesdemaria_victims_metrics.tsv
#   Predicted data from: montesdemaria_victims_predictions.tsv
# Saved evaluation report for Region: montesdemaria to montesdemaria_evaluation.txt
#
# Evaluating Region: morrosquilloysabanasdesucre (state_actor)
#   Actual data from: morrosquilloysabanasdesucre_victims_metrics.tsv
#   Predicted data from: morrosquilloysabanasdesucre_victims_predictions.tsv
# Saved evaluation report for Region: morrosquilloysabanasdesucre to morrosquilloysabanasdesucre_evaluation.txt
#
# Evaluating Region: nordesteantioqueño (state_actor)
#   Actual data from: nordesteantioqueño_victims_metrics.tsv
#   Predicted data from: nordesteantioqueño_victims_predictions.tsv
# Saved evaluation report for Region: nordesteantioqueño to nordesteantioqueño_evaluation.txt
#
# Evaluating Region: noroccidentedecundinamarca (state_actor)
#   Actual data from: noroccidentedecundinamarca_victims_metrics.tsv
#   Predicted data from: noroccidentedecundinamarca_victims_predictions.tsv
# Saved evaluation report for Region: noroccidentedecundinamarca to noroccidentedecundinamarca_evaluation.txt
#
# Evaluating Region: nortedeantioquia (state_actor)
#   Actual data from: nortedeantioquia_victims_metrics.tsv
#   Predicted data from: nortedeantioquia_victims_predictions.tsv
# Saved evaluation report for Region: nortedeantioquia to nortedeantioquia_evaluation.txt
#
# Evaluating Region: nortedeatlantico (state_actor)
#   Actual data from: nortedeatlantico_victims_metrics.tsv
#   Predicted data from: nortedeatlantico_victims_predictions.tsv
# Saved evaluation report for Region: nortedeatlantico to nortedeatlantico_evaluation.txt
#
# Evaluating Region: nortedecordoba (state_actor)
#   Actual data from: nortedecordoba_victims_metrics.tsv
#   Predicted data from: nortedecordoba_victims_predictions.tsv
# Saved evaluation report for Region: nortedecordoba to nortedecordoba_evaluation.txt
#
# Evaluating Region: nortedelcauca (state_actor)
#   Actual data from: nortedelcauca_victims_metrics.tsv
#   Predicted data from: nortedelcauca_victims_predictions.tsv
# Saved evaluation report for Region: nortedelcauca to nortedelcauca_evaluation.txt
#
# Evaluating Region: nortedelhuila (state_actor)
#   Actual data from: nortedelhuila_victims_metrics.tsv
#   Predicted data from: nortedelhuila_victims_predictions.tsv
# Saved evaluation report for Region: nortedelhuila to nortedelhuila_evaluation.txt
#
# Evaluating Region: nortedeltolima (state_actor)
#   Actual data from: nortedeltolima_victims_metrics.tsv
#   Predicted data from: nortedeltolima_victims_predictions.tsv
# Saved evaluation report for Region: nortedeltolima to nortedeltolima_evaluation.txt
#
# Evaluating Region: nortedelvalle (state_actor)
#   Actual data from: nortedelvalle_victims_metrics.tsv
#   Predicted data from: nortedelvalle_victims_predictions.tsv
# Saved evaluation report for Region: nortedelvalle to nortedelvalle_evaluation.txt
#
# Evaluating Region: nortedenariño (state_actor)
#   Actual data from: nortedenariño_victims_metrics.tsv
#   Predicted data from: nortedenariño_victims_predictions.tsv
# Saved evaluation report for Region: nortedenariño to nortedenariño_evaluation.txt
#
# Evaluating Region: occidenteantioqueño (state_actor)
#   Actual data from: occidenteantioqueño_victims_metrics.tsv
#   Predicted data from: occidenteantioqueño_victims_predictions.tsv
# Saved evaluation report for Region: occidenteantioqueño to occidenteantioqueño_evaluation.txt
#
# Evaluating Region: occidentedeatlantico (state_actor)
#   Actual data from: occidentedeatlantico_victims_metrics.tsv
#   Predicted data from: occidentedeatlantico_victims_predictions.tsv
# Saved evaluation report for Region: occidentedeatlantico to occidentedeatlantico_evaluation.txt
#
# Evaluating Region: occidentedenariño (state_actor)
#   Actual data from: occidentedenariño_victims_metrics.tsv
#   Predicted data from: occidentedenariño_victims_predictions.tsv
# Saved evaluation report for Region: occidentedenariño to occidentedenariño_evaluation.txt
#
# Evaluating Region: orienteantioqueño (state_actor)
#   Actual data from: orienteantioqueño_victims_metrics.tsv
#   Predicted data from: orienteantioqueño_victims_predictions.tsv
# Saved evaluation report for Region: orienteantioqueño to orienteantioqueño_evaluation.txt
#
# Evaluating Region: orientedeboyaca (state_actor)
#   Actual data from: orientedeboyaca_victims_metrics.tsv
#   Predicted data from: orientedeboyaca_victims_predictions.tsv
# Saved evaluation report for Region: orientedeboyaca to orientedeboyaca_evaluation.txt
#
# Evaluating Region: patia (state_actor)
#   Actual data from: patia_victims_metrics.tsv
#   Predicted data from: patia_victims_predictions.tsv
# Saved evaluation report for Region: patia to patia_evaluation.txt
#
# Evaluating Region: piedemontellanero (state_actor)
#   Actual data from: piedemontellanero_victims_metrics.tsv
#   Predicted data from: piedemontellanero_victims_predictions.tsv
# Saved evaluation report for Region: piedemontellanero to piedemontellanero_evaluation.txt
#
# Evaluating Region: provinciacomunera (state_actor)
#   Actual data from: provinciacomunera_victims_metrics.tsv
#   Predicted data from: provinciacomunera_victims_predictions.tsv
# Saved evaluation report for Region: provinciacomunera to provinciacomunera_evaluation.txt
#
# Evaluating Region: provinciadegarciarovira (state_actor)
#   Actual data from: provinciadegarciarovira_victims_metrics.tsv
#   Predicted data from: provinciadegarciarovira_victims_predictions.tsv
# Saved evaluation report for Region: provinciadegarciarovira to provinciadegarciarovira_evaluation.txt
#
# Evaluating Region: provinciadeguanenta (state_actor)
#   Actual data from: provinciadeguanenta_victims_metrics.tsv
#   Predicted data from: provinciadeguanenta_victims_predictions.tsv
# Saved evaluation report for Region: provinciadeguanenta to provinciadeguanenta_evaluation.txt
#
# Evaluating Region: provinciadericaurte (state_actor)
#   Actual data from: provinciadericaurte_victims_metrics.tsv
#   Predicted data from: provinciadericaurte_victims_predictions.tsv
# Saved evaluation report for Region: provinciadericaurte to provinciadericaurte_evaluation.txt
#
# Evaluating Region: provinciadesoto (state_actor)
#   Actual data from: provinciadesoto_victims_metrics.tsv
#   Predicted data from: provinciadesoto_victims_predictions.tsv
# Saved evaluation report for Region: provinciadesoto to provinciadesoto_evaluation.txt
#
# Evaluating Region: provinciadevelez (state_actor)
#   Actual data from: provinciadevelez_victims_metrics.tsv
#   Predicted data from: provinciadevelez_victims_predictions.tsv
# Saved evaluation report for Region: provinciadevelez to provinciadevelez_evaluation.txt
#
# Evaluating Region: sarare (state_actor)
#   Actual data from: sarare_victims_metrics.tsv
#   Predicted data from: sarare_victims_predictions.tsv
# Saved evaluation report for Region: sarare to sarare_evaluation.txt
#
# Evaluating Region: serraniadelosyariguies (state_actor)
#   Actual data from: serraniadelosyariguies_victims_metrics.tsv
#   Predicted data from: serraniadelosyariguies_victims_predictions.tsv
# Saved evaluation report for Region: serraniadelosyariguies to serraniadelosyariguies_evaluation.txt
#
# Evaluating Region: serraniadelperija (state_actor)
#   Actual data from: serraniadelperija_victims_metrics.tsv
#   Predicted data from: serraniadelperija_victims_predictions.tsv
# Saved evaluation report for Region: serraniadelperija to serraniadelperija_evaluation.txt
#
# Evaluating Region: sierranevadadesantamarta (state_actor)
#   Actual data from: sierranevadadesantamarta_victims_metrics.tsv
#   Predicted data from: sierranevadadesantamarta_victims_predictions.tsv
# Saved evaluation report for Region: sierranevadadesantamarta to sierranevadadesantamarta_evaluation.txt
#
# Evaluating Region: sininformacion (state_actor)
#   Actual data from: sininformacion_victims_metrics.tsv
#   Predicted data from: sininformacion_victims_predictions.tsv
# Saved evaluation report for Region: sininformacion to sininformacion_evaluation.txt
#
# Evaluating Region: sumapaz (state_actor)
#   Actual data from: sumapaz_victims_metrics.tsv
#   Predicted data from: sumapaz_victims_predictions.tsv
# Saved evaluation report for Region: sumapaz to sumapaz_evaluation.txt
#
# Evaluating Region: surdebolivar (state_actor)
#   Actual data from: surdebolivar_victims_metrics.tsv
#   Predicted data from: surdebolivar_victims_predictions.tsv
# Saved evaluation report for Region: surdebolivar to surdebolivar_evaluation.txt
#
# Evaluating Region: surdecesar (state_actor)
#   Actual data from: surdecesar_victims_metrics.tsv
#   Predicted data from: surdecesar_victims_predictions.tsv
# Saved evaluation report for Region: surdecesar to surdecesar_evaluation.txt
#
# Evaluating Region: surdelhuila (state_actor)
#   Actual data from: surdelhuila_victims_metrics.tsv
#   Predicted data from: surdelhuila_victims_predictions.tsv
# Saved evaluation report for Region: surdelhuila to surdelhuila_evaluation.txt
#
# Evaluating Region: surdeltolima (state_actor)
#   Actual data from: surdeltolima_victims_metrics.tsv
#   Predicted data from: surdeltolima_victims_predictions.tsv
# Saved evaluation report for Region: surdeltolima to surdeltolima_evaluation.txt
#
# Evaluating Region: surdelvalle (state_actor)
#   Actual data from: surdelvalle_victims_metrics.tsv
#   Predicted data from: surdelvalle_victims_predictions.tsv
# Saved evaluation report for Region: surdelvalle to surdelvalle_evaluation.txt
#
# Evaluating Region: surdemagdalena (state_actor)
#   Actual data from: surdemagdalena_victims_metrics.tsv
#   Predicted data from: surdemagdalena_victims_predictions.tsv
# Saved evaluation report for Region: surdemagdalena to surdemagdalena_evaluation.txt
#
# Evaluating Region: surdenariño (state_actor)
#   Actual data from: surdenariño_victims_metrics.tsv
#   Predicted data from: surdenariño_victims_predictions.tsv
# Saved evaluation report for Region: surdenariño to surdenariño_evaluation.txt
#
# Evaluating Region: suroccidentedecundinamarca (state_actor)
#   Actual data from: suroccidentedecundinamarca_victims_metrics.tsv
#   Predicted data from: suroccidentedecundinamarca_victims_predictions.tsv
# Saved evaluation report for Region: suroccidentedecundinamarca to suroccidentedecundinamarca_evaluation.txt
#
# Evaluating Region: suroccidentedenortedesantander (state_actor)
#   Actual data from: suroccidentedenortedesantander_victims_metrics.tsv
#   Predicted data from: suroccidentedenortedesantander_victims_predictions.tsv
# Saved evaluation report for Region: suroccidentedenortedesantander to suroccidentedenortedesantander_evaluation.txt
#
# Evaluating Region: suroesteantioqueño (state_actor)
#   Actual data from: suroesteantioqueño_victims_metrics.tsv
#   Predicted data from: suroesteantioqueño_victims_predictions.tsv
# Saved evaluation report for Region: suroesteantioqueño to suroesteantioqueño_evaluation.txt
#
# Evaluating Region: surorientedenortedesantander (state_actor)
#   Actual data from: surorientedenortedesantander_victims_metrics.tsv
#   Predicted data from: surorientedenortedesantander_victims_predictions.tsv
# Saved evaluation report for Region: surorientedenortedesantander to surorientedenortedesantander_evaluation.txt
#
# Evaluating Region: uraba (state_actor)
#   Actual data from: uraba_victims_metrics.tsv
#   Predicted data from: uraba_victims_predictions.tsv
# Saved evaluation report for Region: uraba to uraba_evaluation.txt
#
# Evaluating Region: valledeaburra (state_actor)
#   Actual data from: valledeaburra_victims_metrics.tsv
#   Predicted data from: valledeaburra_victims_predictions.tsv
# Saved evaluation report for Region: valledeaburra to valledeaburra_evaluation.txt
#
# Evaluating Region: valledesanjuan (state_actor)
#   Actual data from: valledesanjuan_victims_metrics.tsv
#   Predicted data from: valledesanjuan_victims_predictions.tsv
# Saved evaluation report for Region: valledesanjuan to valledesanjuan_evaluation.txt
#
# Region-level individual evaluation for Actor Type: state_actor complete.
#
# --- Processing Region Level for Actor Type: non_state_actor ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/evaluation/victims/region/non_state_actor
# Found 78 common units for Region (non_state_actor). Evaluating each...
#
# Evaluating Region: altaguajira (non_state_actor)
#   Actual data from: altaguajira_victims_metrics.tsv
#   Predicted data from: altaguajira_victims_predictions.tsv
# Saved evaluation report for Region: altaguajira to altaguajira_evaluation.txt
#
# Evaluating Region: altillanura (non_state_actor)
#   Actual data from: altillanura_victims_metrics.tsv
#   Predicted data from: altillanura_victims_predictions.tsv
# Saved evaluation report for Region: altillanura to altillanura_evaluation.txt
#
# Evaluating Region: altiplanocundiboyacense (non_state_actor)
#   Actual data from: altiplanocundiboyacense_victims_metrics.tsv
#   Predicted data from: altiplanocundiboyacense_victims_predictions.tsv
# Saved evaluation report for Region: altiplanocundiboyacense to altiplanocundiboyacense_evaluation.txt
#
# Evaluating Region: altoputumayo (non_state_actor)
#   Actual data from: altoputumayo_victims_metrics.tsv
#   Predicted data from: altoputumayo_victims_predictions.tsv
# Saved evaluation report for Region: altoputumayo to altoputumayo_evaluation.txt
#
# Evaluating Region: altosinuysanjorge (non_state_actor)
#   Actual data from: altosinuysanjorge_victims_metrics.tsv
#   Predicted data from: altosinuysanjorge_victims_predictions.tsv
# Saved evaluation report for Region: altosinuysanjorge to altosinuysanjorge_evaluation.txt
#
# Evaluating Region: amazoniasur-oriental (non_state_actor)
#   Actual data from: amazoniasur-oriental_victims_metrics.tsv
#   Predicted data from: amazoniasur-oriental_victims_predictions.tsv
# Saved evaluation report for Region: amazoniasur-oriental to amazoniasur-oriental_evaluation.txt
#
# Evaluating Region: andenpacificosur (non_state_actor)
#   Actual data from: andenpacificosur_victims_metrics.tsv
#   Predicted data from: andenpacificosur_victims_predictions.tsv
# Saved evaluation report for Region: andenpacificosur to andenpacificosur_evaluation.txt
#
# Evaluating Region: archipielagodesanandres,providenciaysantacatalina (non_state_actor)
#   Actual data from: archipielagodesanandres,providenciaysantacatalina_victims_metrics.tsv
#   Predicted data from: archipielagodesanandres,providenciaysantacatalina_victims_predictions.tsv
# Saved evaluation report for Region: archipielagodesanandres,providenciaysantacatalina to archipielagodesanandres,providenciaysantacatalina_evaluation.txt
#
# Evaluating Region: areametropolitanadebogota (non_state_actor)
#   Actual data from: areametropolitanadebogota_victims_metrics.tsv
#   Predicted data from: areametropolitanadebogota_victims_predictions.tsv
# Saved evaluation report for Region: areametropolitanadebogota to areametropolitanadebogota_evaluation.txt
#
# Evaluating Region: areametropolitanadecucuta (non_state_actor)
#   Actual data from: areametropolitanadecucuta_victims_metrics.tsv
#   Predicted data from: areametropolitanadecucuta_victims_predictions.tsv
# Saved evaluation report for Region: areametropolitanadecucuta to areametropolitanadecucuta_evaluation.txt
#
# Evaluating Region: ariariguayabero (non_state_actor)
#   Actual data from: ariariguayabero_victims_metrics.tsv
#   Predicted data from: ariariguayabero_victims_predictions.tsv
# Saved evaluation report for Region: ariariguayabero to ariariguayabero_evaluation.txt
#
# Evaluating Region: atrato (non_state_actor)
#   Actual data from: atrato_victims_metrics.tsv
#   Predicted data from: atrato_victims_predictions.tsv
# Saved evaluation report for Region: atrato to atrato_evaluation.txt
#
# Evaluating Region: bajocaucaantioqueño (non_state_actor)
#   Actual data from: bajocaucaantioqueño_victims_metrics.tsv
#   Predicted data from: bajocaucaantioqueño_victims_predictions.tsv
# Saved evaluation report for Region: bajocaucaantioqueño to bajocaucaantioqueño_evaluation.txt
#
# Evaluating Region: bajoputumayo (non_state_actor)
#   Actual data from: bajoputumayo_victims_metrics.tsv
#   Predicted data from: bajoputumayo_victims_predictions.tsv
# Saved evaluation report for Region: bajoputumayo to bajoputumayo_evaluation.txt
#
# Evaluating Region: caguan (non_state_actor)
#   Actual data from: caguan_victims_metrics.tsv
#   Predicted data from: caguan_victims_predictions.tsv
# Saved evaluation report for Region: caguan to caguan_evaluation.txt
#
# Evaluating Region: canaldeldique (non_state_actor)
#   Actual data from: canaldeldique_victims_metrics.tsv
#   Predicted data from: canaldeldique_victims_predictions.tsv
# Saved evaluation report for Region: canaldeldique to canaldeldique_evaluation.txt
#
# Evaluating Region: catatumbo (non_state_actor)
#   Actual data from: catatumbo_victims_metrics.tsv
#   Predicted data from: catatumbo_victims_predictions.tsv
# Saved evaluation report for Region: catatumbo to catatumbo_evaluation.txt
#
# Evaluating Region: centrodelhuila (non_state_actor)
#   Actual data from: centrodelhuila_victims_metrics.tsv
#   Predicted data from: centrodelhuila_victims_predictions.tsv
# Saved evaluation report for Region: centrodelhuila to centrodelhuila_evaluation.txt
#
# Evaluating Region: centrodelvalle (non_state_actor)
#   Actual data from: centrodelvalle_victims_metrics.tsv
#   Predicted data from: centrodelvalle_victims_predictions.tsv
# Saved evaluation report for Region: centrodelvalle to centrodelvalle_evaluation.txt
#
# Evaluating Region: centrodenariño (non_state_actor)
#   Actual data from: centrodenariño_victims_metrics.tsv
#   Predicted data from: centrodenariño_victims_predictions.tsv
# Saved evaluation report for Region: centrodenariño to centrodenariño_evaluation.txt
#
# Evaluating Region: centrodenortedesantander (non_state_actor)
#   Actual data from: centrodenortedesantander_victims_metrics.tsv
#   Predicted data from: centrodenortedesantander_victims_predictions.tsv
# Saved evaluation report for Region: centrodenortedesantander to centrodenortedesantander_evaluation.txt
#
# Evaluating Region: centrooccidentedenariño (non_state_actor)
#   Actual data from: centrooccidentedenariño_victims_metrics.tsv
#   Predicted data from: centrooccidentedenariño_victims_predictions.tsv
# Saved evaluation report for Region: centrooccidentedenariño to centrooccidentedenariño_evaluation.txt
#
# Evaluating Region: centroorientedeatlantico (non_state_actor)
#   Actual data from: centroorientedeatlantico_victims_metrics.tsv
#   Predicted data from: centroorientedeatlantico_victims_predictions.tsv
# Saved evaluation report for Region: centroorientedeatlantico to centroorientedeatlantico_evaluation.txt
#
# Evaluating Region: cienagagrandedesantamarta (non_state_actor)
#   Actual data from: cienagagrandedesantamarta_victims_metrics.tsv
#   Predicted data from: cienagagrandedesantamarta_victims_predictions.tsv
# Saved evaluation report for Region: cienagagrandedesantamarta to cienagagrandedesantamarta_evaluation.txt
#
# Evaluating Region: ejecafetero (non_state_actor)
#   Actual data from: ejecafetero_victims_metrics.tsv
#   Predicted data from: ejecafetero_victims_predictions.tsv
# Saved evaluation report for Region: ejecafetero to ejecafetero_evaluation.txt
#
# Evaluating Region: florenciayareadeinfluencia (non_state_actor)
#   Actual data from: florenciayareadeinfluencia_victims_metrics.tsv
#   Predicted data from: florenciayareadeinfluencia_victims_predictions.tsv
# Saved evaluation report for Region: florenciayareadeinfluencia to florenciayareadeinfluencia_evaluation.txt
#
# Evaluating Region: lamojana (non_state_actor)
#   Actual data from: lamojana_victims_metrics.tsv
#   Predicted data from: lamojana_victims_predictions.tsv
# Saved evaluation report for Region: lamojana to lamojana_evaluation.txt
#
# Evaluating Region: litoralpacifico (non_state_actor)
#   Actual data from: litoralpacifico_victims_metrics.tsv
#   Predicted data from: litoralpacifico_victims_predictions.tsv
# Saved evaluation report for Region: litoralpacifico to litoralpacifico_evaluation.txt
#
# Evaluating Region: llanosorientales (non_state_actor)
#   Actual data from: llanosorientales_victims_metrics.tsv
#   Predicted data from: llanosorientales_victims_predictions.tsv
# Saved evaluation report for Region: llanosorientales to llanosorientales_evaluation.txt
#
# Evaluating Region: macizocolombiano (non_state_actor)
#   Actual data from: macizocolombiano_victims_metrics.tsv
#   Predicted data from: macizocolombiano_victims_predictions.tsv
# Saved evaluation report for Region: macizocolombiano to macizocolombiano_evaluation.txt
#
# Evaluating Region: magdalenamedio (non_state_actor)
#   Actual data from: magdalenamedio_victims_metrics.tsv
#   Predicted data from: magdalenamedio_victims_predictions.tsv
# Saved evaluation report for Region: magdalenamedio to magdalenamedio_evaluation.txt
#
# Evaluating Region: magdalenamedioantioqueño (non_state_actor)
#   Actual data from: magdalenamedioantioqueño_victims_metrics.tsv
#   Predicted data from: magdalenamedioantioqueño_victims_predictions.tsv
# Saved evaluation report for Region: magdalenamedioantioqueño to magdalenamedioantioqueño_evaluation.txt
#
# Evaluating Region: medioputumayo (non_state_actor)
#   Actual data from: medioputumayo_victims_metrics.tsv
#   Predicted data from: medioputumayo_victims_predictions.tsv
# Saved evaluation report for Region: medioputumayo to medioputumayo_evaluation.txt
#
# Evaluating Region: montesdemaria (non_state_actor)
#   Actual data from: montesdemaria_victims_metrics.tsv
#   Predicted data from: montesdemaria_victims_predictions.tsv
# Saved evaluation report for Region: montesdemaria to montesdemaria_evaluation.txt
#
# Evaluating Region: morrosquilloysabanasdesucre (non_state_actor)
#   Actual data from: morrosquilloysabanasdesucre_victims_metrics.tsv
#   Predicted data from: morrosquilloysabanasdesucre_victims_predictions.tsv
# Saved evaluation report for Region: morrosquilloysabanasdesucre to morrosquilloysabanasdesucre_evaluation.txt
#
# Evaluating Region: nordesteantioqueño (non_state_actor)
#   Actual data from: nordesteantioqueño_victims_metrics.tsv
#   Predicted data from: nordesteantioqueño_victims_predictions.tsv
# Saved evaluation report for Region: nordesteantioqueño to nordesteantioqueño_evaluation.txt
#
# Evaluating Region: noroccidentedecundinamarca (non_state_actor)
#   Actual data from: noroccidentedecundinamarca_victims_metrics.tsv
#   Predicted data from: noroccidentedecundinamarca_victims_predictions.tsv
# Saved evaluation report for Region: noroccidentedecundinamarca to noroccidentedecundinamarca_evaluation.txt
#
# Evaluating Region: nortedeantioquia (non_state_actor)
#   Actual data from: nortedeantioquia_victims_metrics.tsv
#   Predicted data from: nortedeantioquia_victims_predictions.tsv
# Saved evaluation report for Region: nortedeantioquia to nortedeantioquia_evaluation.txt
#
# Evaluating Region: nortedeatlantico (non_state_actor)
#   Actual data from: nortedeatlantico_victims_metrics.tsv
#   Predicted data from: nortedeatlantico_victims_predictions.tsv
# Saved evaluation report for Region: nortedeatlantico to nortedeatlantico_evaluation.txt
#
# Evaluating Region: nortedecordoba (non_state_actor)
#   Actual data from: nortedecordoba_victims_metrics.tsv
#   Predicted data from: nortedecordoba_victims_predictions.tsv
# Saved evaluation report for Region: nortedecordoba to nortedecordoba_evaluation.txt
#
# Evaluating Region: nortedelcauca (non_state_actor)
#   Actual data from: nortedelcauca_victims_metrics.tsv
#   Predicted data from: nortedelcauca_victims_predictions.tsv
# Saved evaluation report for Region: nortedelcauca to nortedelcauca_evaluation.txt
#
# Evaluating Region: nortedelhuila (non_state_actor)
#   Actual data from: nortedelhuila_victims_metrics.tsv
#   Predicted data from: nortedelhuila_victims_predictions.tsv
# Saved evaluation report for Region: nortedelhuila to nortedelhuila_evaluation.txt
#
# Evaluating Region: nortedeltolima (non_state_actor)
#   Actual data from: nortedeltolima_victims_metrics.tsv
#   Predicted data from: nortedeltolima_victims_predictions.tsv
# Saved evaluation report for Region: nortedeltolima to nortedeltolima_evaluation.txt
#
# Evaluating Region: nortedelvalle (non_state_actor)
#   Actual data from: nortedelvalle_victims_metrics.tsv
#   Predicted data from: nortedelvalle_victims_predictions.tsv
# Saved evaluation report for Region: nortedelvalle to nortedelvalle_evaluation.txt
#
# Evaluating Region: nortedenariño (non_state_actor)
#   Actual data from: nortedenariño_victims_metrics.tsv
#   Predicted data from: nortedenariño_victims_predictions.tsv
# Saved evaluation report for Region: nortedenariño to nortedenariño_evaluation.txt
#
# Evaluating Region: occidenteantioqueño (non_state_actor)
#   Actual data from: occidenteantioqueño_victims_metrics.tsv
#   Predicted data from: occidenteantioqueño_victims_predictions.tsv
# Saved evaluation report for Region: occidenteantioqueño to occidenteantioqueño_evaluation.txt
#
# Evaluating Region: occidentedeatlantico (non_state_actor)
#   Actual data from: occidentedeatlantico_victims_metrics.tsv
#   Predicted data from: occidentedeatlantico_victims_predictions.tsv
# Saved evaluation report for Region: occidentedeatlantico to occidentedeatlantico_evaluation.txt
#
# Evaluating Region: occidentedenariño (non_state_actor)
#   Actual data from: occidentedenariño_victims_metrics.tsv
#   Predicted data from: occidentedenariño_victims_predictions.tsv
# Saved evaluation report for Region: occidentedenariño to occidentedenariño_evaluation.txt
#
# Evaluating Region: orienteantioqueño (non_state_actor)
#   Actual data from: orienteantioqueño_victims_metrics.tsv
#   Predicted data from: orienteantioqueño_victims_predictions.tsv
# Saved evaluation report for Region: orienteantioqueño to orienteantioqueño_evaluation.txt
#
# Evaluating Region: orientedeboyaca (non_state_actor)
#   Actual data from: orientedeboyaca_victims_metrics.tsv
#   Predicted data from: orientedeboyaca_victims_predictions.tsv
# Saved evaluation report for Region: orientedeboyaca to orientedeboyaca_evaluation.txt
#
# Evaluating Region: patia (non_state_actor)
#   Actual data from: patia_victims_metrics.tsv
#   Predicted data from: patia_victims_predictions.tsv
# Saved evaluation report for Region: patia to patia_evaluation.txt
#
# Evaluating Region: piedemontellanero (non_state_actor)
#   Actual data from: piedemontellanero_victims_metrics.tsv
#   Predicted data from: piedemontellanero_victims_predictions.tsv
# Saved evaluation report for Region: piedemontellanero to piedemontellanero_evaluation.txt
#
# Evaluating Region: provinciacomunera (non_state_actor)
#   Actual data from: provinciacomunera_victims_metrics.tsv
#   Predicted data from: provinciacomunera_victims_predictions.tsv
# Saved evaluation report for Region: provinciacomunera to provinciacomunera_evaluation.txt
#
# Evaluating Region: provinciadegarciarovira (non_state_actor)
#   Actual data from: provinciadegarciarovira_victims_metrics.tsv
#   Predicted data from: provinciadegarciarovira_victims_predictions.tsv
# Saved evaluation report for Region: provinciadegarciarovira to provinciadegarciarovira_evaluation.txt
#
# Evaluating Region: provinciadeguanenta (non_state_actor)
#   Actual data from: provinciadeguanenta_victims_metrics.tsv
#   Predicted data from: provinciadeguanenta_victims_predictions.tsv
# Saved evaluation report for Region: provinciadeguanenta to provinciadeguanenta_evaluation.txt
#
# Evaluating Region: provinciadericaurte (non_state_actor)
#   Actual data from: provinciadericaurte_victims_metrics.tsv
#   Predicted data from: provinciadericaurte_victims_predictions.tsv
# Saved evaluation report for Region: provinciadericaurte to provinciadericaurte_evaluation.txt
#
# Evaluating Region: provinciadesoto (non_state_actor)
#   Actual data from: provinciadesoto_victims_metrics.tsv
#   Predicted data from: provinciadesoto_victims_predictions.tsv
# Saved evaluation report for Region: provinciadesoto to provinciadesoto_evaluation.txt
#
# Evaluating Region: provinciadevelez (non_state_actor)
#   Actual data from: provinciadevelez_victims_metrics.tsv
#   Predicted data from: provinciadevelez_victims_predictions.tsv
# Saved evaluation report for Region: provinciadevelez to provinciadevelez_evaluation.txt
#
# Evaluating Region: sarare (non_state_actor)
#   Actual data from: sarare_victims_metrics.tsv
#   Predicted data from: sarare_victims_predictions.tsv
# Saved evaluation report for Region: sarare to sarare_evaluation.txt
#
# Evaluating Region: serraniadelosyariguies (non_state_actor)
#   Actual data from: serraniadelosyariguies_victims_metrics.tsv
#   Predicted data from: serraniadelosyariguies_victims_predictions.tsv
# Saved evaluation report for Region: serraniadelosyariguies to serraniadelosyariguies_evaluation.txt
#
# Evaluating Region: serraniadelperija (non_state_actor)
#   Actual data from: serraniadelperija_victims_metrics.tsv
#   Predicted data from: serraniadelperija_victims_predictions.tsv
# Saved evaluation report for Region: serraniadelperija to serraniadelperija_evaluation.txt
#
# Evaluating Region: sierranevadadesantamarta (non_state_actor)
#   Actual data from: sierranevadadesantamarta_victims_metrics.tsv
#   Predicted data from: sierranevadadesantamarta_victims_predictions.tsv
# Saved evaluation report for Region: sierranevadadesantamarta to sierranevadadesantamarta_evaluation.txt
#
# Evaluating Region: sininformacion (non_state_actor)
#   Actual data from: sininformacion_victims_metrics.tsv
#   Predicted data from: sininformacion_victims_predictions.tsv
# Saved evaluation report for Region: sininformacion to sininformacion_evaluation.txt
#
# Evaluating Region: sumapaz (non_state_actor)
#   Actual data from: sumapaz_victims_metrics.tsv
#   Predicted data from: sumapaz_victims_predictions.tsv
# Saved evaluation report for Region: sumapaz to sumapaz_evaluation.txt
#
# Evaluating Region: surdebolivar (non_state_actor)
#   Actual data from: surdebolivar_victims_metrics.tsv
#   Predicted data from: surdebolivar_victims_predictions.tsv
# Saved evaluation report for Region: surdebolivar to surdebolivar_evaluation.txt
#
# Evaluating Region: surdecesar (non_state_actor)
#   Actual data from: surdecesar_victims_metrics.tsv
#   Predicted data from: surdecesar_victims_predictions.tsv
# Saved evaluation report for Region: surdecesar to surdecesar_evaluation.txt
#
# Evaluating Region: surdelhuila (non_state_actor)
#   Actual data from: surdelhuila_victims_metrics.tsv
#   Predicted data from: surdelhuila_victims_predictions.tsv
# Saved evaluation report for Region: surdelhuila to surdelhuila_evaluation.txt
#
# Evaluating Region: surdeltolima (non_state_actor)
#   Actual data from: surdeltolima_victims_metrics.tsv
#   Predicted data from: surdeltolima_victims_predictions.tsv
# Saved evaluation report for Region: surdeltolima to surdeltolima_evaluation.txt
#
# Evaluating Region: surdelvalle (non_state_actor)
#   Actual data from: surdelvalle_victims_metrics.tsv
#   Predicted data from: surdelvalle_victims_predictions.tsv
# Saved evaluation report for Region: surdelvalle to surdelvalle_evaluation.txt
#
# Evaluating Region: surdemagdalena (non_state_actor)
#   Actual data from: surdemagdalena_victims_metrics.tsv
#   Predicted data from: surdemagdalena_victims_predictions.tsv
# Saved evaluation report for Region: surdemagdalena to surdemagdalena_evaluation.txt
#
# Evaluating Region: surdenariño (non_state_actor)
#   Actual data from: surdenariño_victims_metrics.tsv
#   Predicted data from: surdenariño_victims_predictions.tsv
# Saved evaluation report for Region: surdenariño to surdenariño_evaluation.txt
#
# Evaluating Region: suroccidentedecundinamarca (non_state_actor)
#   Actual data from: suroccidentedecundinamarca_victims_metrics.tsv
#   Predicted data from: suroccidentedecundinamarca_victims_predictions.tsv
# Saved evaluation report for Region: suroccidentedecundinamarca to suroccidentedecundinamarca_evaluation.txt
#
# Evaluating Region: suroccidentedenortedesantander (non_state_actor)
#   Actual data from: suroccidentedenortedesantander_victims_metrics.tsv
#   Predicted data from: suroccidentedenortedesantander_victims_predictions.tsv
# Saved evaluation report for Region: suroccidentedenortedesantander to suroccidentedenortedesantander_evaluation.txt
#
# Evaluating Region: suroesteantioqueño (non_state_actor)
#   Actual data from: suroesteantioqueño_victims_metrics.tsv
#   Predicted data from: suroesteantioqueño_victims_predictions.tsv
# Saved evaluation report for Region: suroesteantioqueño to suroesteantioqueño_evaluation.txt
#
# Evaluating Region: surorientedenortedesantander (non_state_actor)
#   Actual data from: surorientedenortedesantander_victims_metrics.tsv
#   Predicted data from: surorientedenortedesantander_victims_predictions.tsv
# Saved evaluation report for Region: surorientedenortedesantander to surorientedenortedesantander_evaluation.txt
#
# Evaluating Region: uraba (non_state_actor)
#   Actual data from: uraba_victims_metrics.tsv
#   Predicted data from: uraba_victims_predictions.tsv
# Saved evaluation report for Region: uraba to uraba_evaluation.txt
#
# Evaluating Region: valledeaburra (non_state_actor)
#   Actual data from: valledeaburra_victims_metrics.tsv
#   Predicted data from: valledeaburra_victims_predictions.tsv
# Saved evaluation report for Region: valledeaburra to valledeaburra_evaluation.txt
#
# Evaluating Region: valledesanjuan (non_state_actor)
#   Actual data from: valledesanjuan_victims_metrics.tsv
#   Predicted data from: valledesanjuan_victims_predictions.tsv
# Saved evaluation report for Region: valledesanjuan to valledesanjuan_evaluation.txt
#
# Region-level individual evaluation for Actor Type: non_state_actor complete.
#
# --- Processing Region Level for Actor Type: unknown_actor_type ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/evaluation/victims/region/unknown_actor_type
# Warning: No matching actual and predicted files found for Region (unknown_actor_type). Skipping evaluation.
#
# --- Overall Individual Unit Evaluation Process Finished ---

# %% [markdown]
# ### 4. Aggregated Global Evaluation and Saving Results
# This final evaluation block provides a consolidated view of the model's performance across broader geographical scopes: aggregated Department-level and aggregated Region-level. Instead of evaluating each individual department or region separately, this section combines all data within each category to generate a single set of confusion matrices and classification reports for each. The Country-level evaluation was already handled individually in Cell 3 (and effectively acts as a global evaluation for that level).
#
# The results for these aggregated evaluations will be captured and saved into separate plain text files (.txt) for easy review and record-keeping, providing a global perspective on the model's predictive capabilities for 'Intensity' and 'Escalation' at these consolidated levels, broken down by Actor Type.

# %%
# 4. Aggregated Global Evaluation and Saving Results

print("\n--- Starting Aggregated Global Evaluation and Saving Results ---")

# Ensure base directories and evaluation functions are defined from previous cells
if 'predicted_data_base_dir' not in globals() or \
   'actual_data_base_dir' not in globals() or \
   'evaluation_results_base_dir' not in globals() or \
   'ACTOR_TYPES_SUBFOLDERS' not in globals() or \
   'intensity_escalation_labels' not in globals() or \
   'align_and_merge_data' not in globals() or \
   'evaluate_predictions' not in globals() or \
   'sys' not in globals(): # Ensure sys is imported for stdout redirection
    print("Error: Required global variables or functions not found. Please ensure all previous cells (1, 2, 3) have been run correctly and 'import sys' is in Cell 1.")
else:
    # Targets for evaluation (Intensity and Escalation)
    prediction_targets = ['Intensity', 'Escalation']

    # Levels for aggregated evaluation (Department and Region)
    # Country is evaluated individually in Cell 3, which serves as its global view.
    aggregated_levels_info = [
        {'name': 'Department', 'input_subdir_actual': 'department', 'input_subdir_predicted': 'department'},
        {'name': 'Region', 'input_subdir_actual': 'region', 'input_subdir_predicted': 'region'}
    ]

    for level in aggregated_levels_info:
        level_name = level['name']
        actual_base_level_dir = os.path.join(actual_data_base_dir, level['input_subdir_actual'])
        predicted_base_level_dir = os.path.join(predicted_data_base_dir, level['input_subdir_predicted'])

        print(f"\n==========================================================")
        print(f"=== Aggregated Evaluation for All {level_name}s Combined ===")
        print(f"==========================================================")

        # Loop through each actor type subfolder for aggregated evaluation
        for actor_type_subfolder in ACTOR_TYPES_SUBFOLDERS:
            current_actual_dir = os.path.join(actual_base_level_dir, actor_type_subfolder)
            current_predicted_dir = os.path.join(predicted_base_level_dir, actor_type_subfolder)
            current_output_dir = os.path.join(evaluation_results_base_dir, level_name.lower(), actor_type_subfolder)

            print(f"\n--- Aggregated Evaluation for All {level_name}s (Actor Type: {actor_type_subfolder}) ---")

            # Create the output directory for this aggregated level and actor type if it doesn't exist
            os.makedirs(current_output_dir, exist_ok=True)
            print(f"Ensured output directory exists: {current_output_dir}")

            # Collect all actual and predicted dataframes for the current level and actor type
            all_level_actual_dfs = []
            all_level_predicted_dfs = []

            if not os.path.exists(current_actual_dir) or not os.path.exists(current_predicted_dir):
                print(f"Error: Data directories not found for {level_name} ({actor_type_subfolder}). Skipping aggregation.")
                continue

            # Load all actual files for the current level and actor type
            for f_name in os.listdir(current_actual_dir):
                if f_name.endswith('_victims_metrics.tsv'):
                    try:
                        df = pd.read_csv(os.path.join(current_actual_dir, f_name), sep='\t')
                        all_level_actual_dfs.append(df)
                    except Exception as e:
                        print(f"Error loading actual file {f_name} for {level_name} ({actor_type_subfolder}): {e}")

            # Load all predicted files for the current level and actor type
            for f_name in os.listdir(current_predicted_dir):
                if f_name.endswith('_victims_predictions.tsv'):
                    try:
                        df = pd.read_csv(os.path.join(current_predicted_dir, f_name), sep='\t')
                        all_level_predicted_dfs.append(df)
                    except Exception as e:
                        print(f"Error loading predicted file {f_name} for {level_name} ({actor_type_subfolder}): {e}")

            if not all_level_actual_dfs or not all_level_predicted_dfs:
                print(f"Warning: No actual or predicted files found for aggregated {level_name} ({actor_type_subfolder}). Skipping.")
                continue

            # Concatenate all dataframes for actual and predicted across all units in this level/actor type
            df_aggregated_actual = pd.concat(all_level_actual_dfs, ignore_index=True)
            df_aggregated_predicted = pd.concat(all_level_predicted_dfs, ignore_index=True)

            # Merge aggregated data
            merged_aggregated_data = align_and_merge_data(df_aggregated_actual, df_aggregated_predicted)

            if merged_aggregated_data.empty:
                print(f"No merged data for Aggregated {level_name} ({actor_type_subfolder}) evaluation. Skipping.")
                continue

            # Prepare the output buffer for saving to a .txt file
            output_buffer = io.StringIO()
            original_stdout = sys.stdout # Save original stdout

            sys.stdout = output_buffer # Redirect stdout to the buffer

            print(f"\n--- Consolidated Evaluation for All {level_name}s (Actor Type: {actor_type_subfolder}) ---")
            print("-------------------------------------------------------------------\n")

            # Evaluate for each violence type (VS, VI, VC)
            for v_type in merged_aggregated_data['violence type'].unique():
                print(f"\n----- Violence Type: {v_type} (Aggregated {level_name}) -----")
                df_subset = merged_aggregated_data[merged_aggregated_data['violence type'] == v_type].copy()

                if df_subset.empty:
                    print(f"No merged data for {v_type} in Aggregated {level_name} evaluation. Skipping.")
                    continue

                for target in prediction_targets:
                    actual_col = f'{target}'
                    predicted_col = f'Predicted_{target}'

                    if actual_col in df_subset.columns and predicted_col in df_subset.columns:
                        # Ensure data types are consistent and valid for classification
                        df_subset[actual_col] = pd.to_numeric(df_subset[actual_col], errors='coerce').fillna(0).astype(int)
                        df_subset[predicted_col] = pd.to_numeric(df_subset[predicted_col], errors='coerce').fillna(0).astype(int)

                        # Drop rows with NaN in target columns after conversion (if any happened)
                        eval_data = df_subset.dropna(subset=[actual_col, predicted_col]).copy()

                        if eval_data.empty:
                            print(f"  No valid data for {target} after cleaning for {v_type} in aggregated {level_name}. Skipping evaluation for this target.\n")
                            continue

                        y_true = eval_data[actual_col]
                        y_pred = eval_data[predicted_col]

                        # Call evaluate_predictions to print to the redirected buffer
                        evaluate_predictions(y_true, y_pred,
                                             f"{target} ({v_type}) - Aggregated {level_name}",
                                             labels=intensity_escalation_labels)
                    else:
                        print(f"  Missing '{actual_col}' or '{predicted_col}' columns for {v_type} in Aggregated {level_name} evaluation.")


            sys.stdout = original_stdout # Restore original stdout

            # Save the captured output to a .txt file
            output_filename = os.path.join(current_output_dir, f"{level_name.lower()}_global_evaluation.txt")
            with open(output_filename, 'w') as f:
                f.write(output_buffer.getvalue())
            print(f"Saved Aggregated {level_name}-level evaluation for Actor Type: {actor_type_subfolder} to: {output_filename}")


    print("\n--- Overall Aggregated Global Evaluation Finished ---")
# Out:
# --- Starting Aggregated Global Evaluation and Saving Results ---
#
# ==========================================================
# === Aggregated Evaluation for All Departments Combined ===
# ==========================================================
#
# --- Aggregated Evaluation for All Departments (Actor Type: state_actor) ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/evaluation/victims/department/state_actor
# Saved Aggregated Department-level evaluation for Actor Type: state_actor to: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/evaluation/victims/department/state_actor/department_global_evaluation.txt
#
# --- Aggregated Evaluation for All Departments (Actor Type: non_state_actor) ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/evaluation/victims/department/non_state_actor
# Saved Aggregated Department-level evaluation for Actor Type: non_state_actor to: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/evaluation/victims/department/non_state_actor/department_global_evaluation.txt
#
# --- Aggregated Evaluation for All Departments (Actor Type: unknown_actor_type) ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/evaluation/victims/department/unknown_actor_type
# Warning: No actual or predicted files found for aggregated Department (unknown_actor_type). Skipping.
#
# ==========================================================
# === Aggregated Evaluation for All Regions Combined ===
# ==========================================================
#
# --- Aggregated Evaluation for All Regions (Actor Type: state_actor) ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/evaluation/victims/region/state_actor
# Saved Aggregated Region-level evaluation for Actor Type: state_actor to: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/evaluation/victims/region/state_actor/region_global_evaluation.txt
#
# --- Aggregated Evaluation for All Regions (Actor Type: non_state_actor) ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/evaluation/victims/region/non_state_actor
# Saved Aggregated Region-level evaluation for Actor Type: non_state_actor to: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/evaluation/victims/region/non_state_actor/region_global_evaluation.txt
#
# --- Aggregated Evaluation for All Regions (Actor Type: unknown_actor_type) ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/evaluation/victims/region/unknown_actor_type
# Warning: No actual or predicted files found for aggregated Region (unknown_actor_type). Skipping.
#
# --- Overall Aggregated Global Evaluation Finished ---
