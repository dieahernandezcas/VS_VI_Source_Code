# %% [markdown]
# # Calculation of Intensity and Escalation Metrics for Cases (VS/VI/VC)
#
# ## Project:
# VS_VI_Source_CodeThis Jupyter Notebook is part of the VS_VI_Source_Code project, which aims to analyze the dynamics of Selective Violence (VS) and Indiscriminate Violence (VI) in Colombia.
#
# ## Purpose
# The primary purpose of this notebook is to calculate the key temporal metrics (Escalation and Intensity) for pre-processed monthly case counts of Selective Violence (VS), Indiscriminate Violence (VI), and their sum (Violencia Colectiva, VC). These calculations are performed for data at the Country, Department, and Region levels, using data files generated in previous processing steps. The calculated metrics are then saved for subsequent analysis and visualization.
#
# ## Workflow
# This notebook focuses on the Metric Calculation and Results Saving stages of the project's analytical workflow. It assumes that the monthly case counts per violence type (VS/VI) for each geographical unit have already been processed and saved in the ../Data/processed/cases/ directory structure.
#
# ## About
# This notebook implements the logic to read structured time series data (monthly case counts for VS and VI) from files, calculate the total collective violence (VC), apply the defined Escalation and Intensity functions to the time series of VS, VI, and VC, and store the final results including these metrics.

# %% [markdown]
# ### 1. Initial Setup, Library Imports, and Path Configuration
# This block performs the initial setup for the notebook environment. It includes importing all necessary Python libraries required for data handling, file system operations, numerical computations, and generating combinations (specifically for calculating VC). It defines the relative paths for the input directories containing the pre-processed monthly case counts (VS/VI) for each geographical level and the base output directory where the final results with calculated metrics will be stored.

# %%
# 1. Initial Setup, Library Imports, and Path Configuration

import pandas as pd
import os
import numpy as np
from itertools import product # Needed for potential future use or clarity, though VC calculation is simpler here

# Define the base output directory for results.
# Results for different levels (country, department, region) will go into subfolders here.
# Assumes the notebook is in a subfolder (e.g., 'notebooks') and results go one level up in 'Results/intensity & escalation/cases'.
# Adjust '../' if your actual folder structure is different.
# Example structure:
# Project_Root/
# ├── Data/
# │   └── processed/
# │       └── cases/
# │           ├── country/    # Processed country data (Input)
# │           ├── departments/ # Processed department data (Input)
# │           └── regions/    # Processed region data (Input)
# ├── Results/
# │   └── intensity & escalation/
# │       └── cases/    # Results will be saved here (Output)
# └── notebooks/        # This notebook is here
base_results_dir = os.path.join(os.getcwd(), '..', 'Results', 'intensity & escalation', 'cases')

# Define the input directories for processed data (monthly counts per type).
# These directories should contain the TSV files generated in previous steps (Cells 4, 5, and 6 of the other notebook).
processed_data_base_dir = os.path.join(os.getcwd(), '..', 'Data', 'processed', 'cases')
processed_data_country_dir = os.path.join(processed_data_base_dir, 'country')
processed_data_dept_dir = os.path.join(processed_data_base_dir, 'departments')
processed_data_region_dir = os.path.join(processed_data_base_dir, 'regions')

# Define the year range (for context, should match the processed data files).
min_year = 1958
max_year = 2022

print("Initial setup, library imports, and path configuration complete.")
print(f"Processed data will be read from: {processed_data_base_dir}")
print(f"Results will be saved in: {base_results_dir}")
# Out:
# Initial setup, library imports, and path configuration complete.
# Processed data will be read from: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/processed/cases
# Results will be saved in: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/intensity & escalation/cases

# %% [markdown]
# ### 2. Define Metric Calculation Functions
# This block defines the core Python functions used to calculate the temporal dynamics metrics: Escalation and Intensity. These functions are designed to operate on a single time series (a pandas Series or DataFrame column) of monthly counts.calculate_escalation(series): Computes the Escalation metric by comparing each month's count to the previous month's count.calculate_intensity(series, window=36): Computes the Intensity metric by comparing each month's count to the average count over a preceding rolling window (defaulting to 36 months).The functions return a series of the same length as the input, with values -1, 0, or 1, representing decrease, no change, or increase relative to the comparison point. Initial months where the comparison is not possible are handled by filling with 0.

# %%
# 2. Define Metric Calculation Functions

print("\n--- Defining Metric Calculation Functions ---")

def calculate_escalation(series):
    """
    Calculates the Escalation metric for a time series.
    Escalation = 1 if current > previous, 0 if current == previous, -1 if current < previous.
    Handles the first month (no previous month) by setting Escalation to 0.

    Args:
        series (pd.Series): A pandas Series representing a time series of counts.

    Returns:
        pd.Series: A pandas Series of the same length with Escalation values (-1, 0, 1).
    """
    # Shift the series to get the previous month's value
    previous_month = series.shift(1)

    # Calculate the difference
    difference = series - previous_month

    # Apply the conditions using numpy.sign to get -1, 0, or 1
    # Fill NaN for the first month's escalation (no previous data) with 0
    escalation = np.sign(difference).fillna(0).astype(int)

    return escalation

def calculate_intensity(series, window=36):
    """
    Calculates the Intensity metric for a time series.
    Intensity = 1 if current > 36-month mean, 0 if current == mean, -1 if current < mean.
    Requires at least 'window' months of data to calculate the mean.

    Args:
        series (pd.Series): A pandas Series representing a time series of counts.
        window (int): The number of preceding months to use for the rolling mean calculation.

    Returns:
        pd.Series: A pandas Series of the same length with Intensity values (-1, 0, 1).
    """
    # Calculate the rolling mean over the specified window
    rolling_mean = series.rolling(window=window).mean()

    # Calculate the difference between current and rolling mean
    difference = series - rolling_mean

    # Apply the conditions using numpy.sign to get -1, 0, or 1
    # Fill NaN for the first 'window' months (not enough data for mean) with 0
    intensity = np.sign(difference).fillna(0).astype(int)

    return intensity

print("Metric calculation functions defined.")
# Out:
# --- Defining Metric Calculation Functions ---
# Metric calculation functions defined.

# %% [markdown]
# ### 3. Calculate Intensity and Escalation Metrics from Processed Data with Previous State
# This block calculates the monthly Escalation and Intensity metrics for Selective Violence (VS), Indiscriminate Violence (VI), and their sum (Violencia Colectiva, VC) case counts from 1958 to 2022. These metrics are computed by loading the pre-processed monthly case counts (including VS/VI breakdown) for Country, Departments, and Regions from their respective directories (../Data/processed/cases/). The script iterates through the files for each level, calculates VC for each unit by summing the existing VS and VI counts, applies the metric functions (defined in Cell 2) to the time series for VS, VI, and VC, and crucially, adds a "Previous State" column. This new column indicates the combined state of the Intensity and Escalation metrics from the immediately preceding month, mapped to specific letter codes (A-I). Finally, it saves the resulting DataFrames (including counts, metrics, and the Previous State) to separate TSV files in the designated results directory structure (../Results/intensity & escalation/cases/). This process relies on the .tsv files generated in the previous data processing notebook (specifically, the outputs of its Cells 4, 5, and 6).

# %%
# 3. Calculate and Save Metrics from Processed Data

print("\n--- Calculating and Saving Metrics from Processed Data ---")

# Define the base output directory for results
base_results_dir = os.path.join(os.getcwd(), '..', 'Results', 'intensity & escalation', 'cases')

# Define the input directories for processed data (from cells 4, 5 and 6)
processed_data_base_dir = os.path.join(os.getcwd(), '..', 'Data', 'processed', 'cases')
processed_data_country_dir = os.path.join(processed_data_base_dir, 'country')
processed_data_dept_dir = os.path.join(processed_data_base_dir, 'departments')
processed_data_region_dir = os.path.join(processed_data_base_dir, 'regions')

# Ensure metric calculation functions are defined (from Cell 2)
if 'calculate_escalation' not in globals() or 'calculate_intensity' not in globals():
    print("Error: Metric calculation functions (calculate_escalation, calculate_intensity) not found. Please run Cell 2.")
else:

    # Define the mapping for [Intensity, Escalation] pairs to states
    state_mapping = {
        (1, 1): 'A',
        (1, 0): 'B',
        (1, -1): 'C',
        (0, 1): 'D',
        (0, 0): 'E',
        (0, -1): 'F',
        (-1, 1): 'G',
        (-1, 0): 'H',
        (-1, -1): 'I'
    }

    # --- Helper Function to Calculate Metrics and State for VS, VI, and VC ---

    def calculate_metrics_and_state_for_types(df_unit_counts):
        """
        Calculates Escalation, Intensity, and Previous State for VS, VI, and VC
        within a single DataFrame containing 'Año', 'Mes', 'violence type', and 'CaseCount'.
        Assumes the input DataFrame is already complete for Year-Month-Violence Type
        combinations and sorted.
        """
        metrics_list = []
        for v_type in ['VS', 'VI', 'VC']:
            # Filter data for the current violence type
            df_type = df_unit_counts[df_unit_counts['violence type'] == v_type].copy()

            if not df_type.empty:
                # Ensure the time series is sorted for correct shift/rolling calculations
                df_type = df_type.sort_values(by=['Año', 'Mes']).reset_index(drop=True)

                # Calculate metrics using the functions defined in Cell 2
                df_type['Escalation'] = calculate_escalation(df_type['CaseCount'])
                df_type['Intensity'] = calculate_intensity(df_type['CaseCount'])

                # --- Calculate Current State and Shift for Previous State ---
                # Create a temporary column with the (Intensity, Escalation) tuple for the current month
                df_type['CurrentState_Tuple'] = list(zip(df_type['Intensity'], df_type['Escalation']))

                # Map the tuple to the state letter using the defined mapping
                # Use .get() with a default (e.g., 'Unknown' or NaN) for safety if a pair isn't in mapping
                df_type['CurrentState'] = df_type['CurrentState_Tuple'].apply(lambda x: state_mapping.get(x, 'Unknown'))

                # Shift the 'CurrentState' column to get the 'Previous State'
                df_type['Previous State'] = df_type['CurrentState'].shift(1).fillna('Start') # Fill the first month's previous state with 'Start' or similar

                # Drop the temporary columns
                df_type = df_type.drop(columns=['CurrentState_Tuple', 'CurrentState'])

                # Select relevant columns and append, including the new 'Previous State'
                metrics_list.append(df_type[['Año', 'Mes', 'violence type', 'CaseCount', 'Escalation', 'Intensity', 'Previous State']])

        # Concatenate metrics for all types (VS, VI, VC) for this unit
        if metrics_list:
            unit_final_df = pd.concat(metrics_list, ignore_index=True)
            # Sort the final DataFrame
            unit_final_df = unit_final_df.sort_values(by=['Año', 'Mes', 'violence type']).reset_index(drop=True)
            return unit_final_df
        else:
            return pd.DataFrame() # Return empty DataFrame if no metrics were calculated


    # --- Helper Function to Process a Single Processed Data File ---

    def process_file_and_calculate_metrics(file_path, output_dir, level_name, unit_name):
        """
        Reads a processed TSV file (containing VS/VI counts), calculates VC,
        Escalation, Intensity, and Previous State for VS, VI, and VC, and saves results.
        """
        print(f"\nProcessing {level_name}: {unit_name} from file: {os.path.basename(file_path)}")

        try:
            # Read the processed TSV file containing 'Año', 'Mes', 'violence type' (VS/VI), 'CaseCount'
            df_counts_vsvi = pd.read_csv(file_path, sep='\t')

            # Ensure required columns are present
            required_cols = ['Año', 'Mes', 'violence type', 'CaseCount']
            if not all(col in df_counts_vsvi.columns for col in required_cols):
                print(f"Error: Missing required columns in {os.path.basename(file_path)}: {required_cols}. Skipping.")
                return # Exit function

            # Ensure data types are correct and drop NaNs in essential columns
            df_counts_vsvi['Año'] = pd.to_numeric(df_counts_vsvi['Año'], errors='coerce')
            df_counts_vsvi['Mes'] = pd.to_numeric(df_counts_vsvi['Mes'], errors='coerce')
            df_counts_vsvi['CaseCount'] = pd.to_numeric(df_counts_vsvi['CaseCount'], errors='coerce').fillna(0).astype(int)
            df_counts_vsvi = df_counts_vsvi.dropna(subset=required_cols).copy()

            # Ensure the DataFrame contains only VS and VI types before calculating VC
            # Filter out any unexpected violence types if present, but keep VS and VI
            valid_vsvi_df = df_counts_vsvi[df_counts_vsvi['violence type'].isin(['VS', 'VI'])].copy()

            if valid_vsvi_df.empty:
                 print(f"Warning: No valid VS or VI data found in {os.path.basename(file_path)} to calculate metrics. Skipping.")
                 return


            # Calculate VC (VS + VI) for the unit from the existing VS and VI counts
            # Need to pivot the valid VS/VI data to sum correctly
            # Use dropna=False to keep all Year-Month combinations even if one type is missing for a month
            pivot_for_vc = valid_vsvi_df.pivot_table(
                index=['Año', 'Mes'],
                columns='violence type',
                values='CaseCount',
                fill_value=0,
                dropna=False # Keep all index values
            )
            # Calculate VC by summing VS and VI columns from the pivot table
            pivot_for_vc['VC'] = pivot_for_vc.get('VS', 0) + pivot_for_vc.get('VI', 0)

            # Unpivot VC back to long format
            vc_df = pivot_for_vc[['VC']].stack().reset_index(name='CaseCount')
            vc_df['violence type'] = 'VC'

            # Combine VS, VI, and VC dataframes for this unit for metric calculation
            # Start with the original valid VS/VI data and concatenate the calculated VC data
            combined_unit_counts_df = pd.concat([valid_vsvi_df, vc_df], ignore_index=True)
            # Sort chronologically and by violence type
            combined_unit_counts_df = combined_unit_counts_df.sort_values(by=['Año', 'Mes', 'violence type']).reset_index(drop=True)


            # Calculate metrics and state for the unit (VS, VI, VC) using the helper function
            unit_final_df = calculate_metrics_and_state_for_types(combined_unit_counts_df) # Use the updated function

            # Save the results
            if not unit_final_df.empty:
                # Generate the output filename: unit name (lowercase, no spaces) + "_cases_metrics.tsv"
                output_filename = unit_name.lower().replace(" ", "") + "_cases_metrics.tsv"
                output_path = os.path.join(output_dir, output_filename)

                try:
                    unit_final_df.to_csv(output_path, sep='\t', index=False)
                    print(f"Saved metrics for {level_name}: {unit_name} to {output_filename}")
                except Exception as e:
                    print(f"Error saving metrics for {level_name}: {unit_name} to {output_filename}: {e}")
            else:
                 print(f"No metrics calculated for {level_name}: {unit_name}. Skipping save.")

        except Exception as e:
            print(f"An unexpected error occurred during processing file {os.path.basename(file_path)}: {e}")
            # Return empty DataFrame on exception
            return pd.DataFrame()


    # --- Process Each Level ---

    # Define the levels and their corresponding input/output directories
    levels_info = [
        {'name': 'Country', 'input_dir': processed_data_country_dir, 'output_subdir': 'country'},
        {'name': 'Department', 'input_dir': processed_data_dept_dir, 'output_subdir': 'department'},
        {'name': 'Region', 'input_dir': processed_data_region_dir, 'output_subdir': 'region'}
    ]

    for level in levels_info:
        level_name = level['name']
        input_dir = level['input_dir']
        output_subdir = level['output_subdir']
        output_dir = os.path.join(base_results_dir, output_subdir)

        print(f"\n--- Processing {level_name} Level ---")

        # Create the output directory for this level if it doesn't exist
        os.makedirs(output_dir, exist_ok=True)
        print(f"Ensured output directory exists: {output_dir}")

        # Check if the input directory exists
        if not os.path.exists(input_dir):
            print(f"Error: Processed data directory not found for {level_name}: {input_dir}. Skipping this level.")
            continue # Skip to the next level

        # List all TSV files in the input directory for this level
        processed_files = [f for f in os.listdir(input_dir) if f.endswith('.tsv')] # Assuming filenames end with _cases.tsv

        if not processed_files:
            print(f"Warning: No processed TSV files found in {input_dir}. Skipping {level_name} processing.")
        else:
            print(f"Found {len(processed_files)} processed {level_name} files. Processing each...")
            for filename in processed_files:
                file_path = os.path.join(input_dir, filename)
                # Extract unit name from filename (e.g., 'colombia', 'antioquia', 'pacifica')
                # Assumes filename format is like 'unitname_cases.tsv'
                unit_name = filename.replace("_cases.tsv", "")

                # Process the file, calculate metrics and state, and get the result DataFrame
                unit_metrics_df = process_file_and_calculate_metrics(file_path, output_dir, level_name, unit_name)

                # Saving is handled inside process_file_and_calculate_metrics now.
                # We could add a check here if needed, but the helper already saves.
                # if not unit_metrics_df.empty:
                #     print(f"Successfully processed {level_name}: {unit_name}. File saved by helper function.")
                # else:
                #      print(f"Processing {level_name}: {unit_name} resulted in an empty DataFrame.")


        print(f"\n{level_name}-level metrics calculation and saving complete.")

print("\n--- Overall Intensity and Escalation Calculation Process Finished ---")
# Out:
# --- Calculating and Saving Metrics from Processed Data ---
#
# --- Processing Country Level ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/intensity & escalation/cases/country
# Found 1 processed Country files. Processing each...
#
# Processing Country: 1958_2022_cases_country.tsv from file: 1958_2022_cases_country.tsv
# Saved metrics for Country: 1958_2022_cases_country.tsv to 1958_2022_cases_country.tsv_cases_metrics.tsv
#
# Country-level metrics calculation and saving complete.
#
# --- Processing Department Level ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/intensity & escalation/cases/department
# Found 35 processed Department files. Processing each...
#
# Processing Department: meta from file: meta_cases.tsv
# Saved metrics for Department: meta to meta_cases_metrics.tsv
#
# Processing Department: atlantico from file: atlantico_cases.tsv
# Saved metrics for Department: atlantico to atlantico_cases_metrics.tsv
#
# Processing Department: risaralda from file: risaralda_cases.tsv
# Saved metrics for Department: risaralda to risaralda_cases_metrics.tsv
#
# Processing Department: caqueta from file: caqueta_cases.tsv
# Saved metrics for Department: caqueta to caqueta_cases_metrics.tsv
#
# Processing Department: magdalena from file: magdalena_cases.tsv
# Saved metrics for Department: magdalena to magdalena_cases_metrics.tsv
#
# Processing Department: cauca from file: cauca_cases.tsv
# Saved metrics for Department: cauca to cauca_cases_metrics.tsv
#
# Processing Department: nortedesantander from file: nortedesantander_cases.tsv
# Saved metrics for Department: nortedesantander to nortedesantander_cases_metrics.tsv
#
# Processing Department: caldas from file: caldas_cases.tsv
# Saved metrics for Department: caldas to caldas_cases_metrics.tsv
#
# Processing Department: arauca from file: arauca_cases.tsv
# Saved metrics for Department: arauca to arauca_cases_metrics.tsv
#
# Processing Department: guainia from file: guainia_cases.tsv
# Saved metrics for Department: guainia to guainia_cases_metrics.tsv
#
# Processing Department: choco from file: choco_cases.tsv
# Saved metrics for Department: choco to choco_cases_metrics.tsv
#
# Processing Department: sucre from file: sucre_cases.tsv
# Saved metrics for Department: sucre to sucre_cases_metrics.tsv
#
# Processing Department: santander from file: santander_cases.tsv
# Saved metrics for Department: santander to santander_cases_metrics.tsv
#
# Processing Department: antioquia from file: antioquia_cases.tsv
# Saved metrics for Department: antioquia to antioquia_cases_metrics.tsv
#
# Processing Department: boyaca from file: boyaca_cases.tsv
# Saved metrics for Department: boyaca to boyaca_cases_metrics.tsv
#
# Processing Department: vichada from file: vichada_cases.tsv
# Saved metrics for Department: vichada to vichada_cases_metrics.tsv
#
# Processing Department: guaviare from file: guaviare_cases.tsv
# Saved metrics for Department: guaviare to guaviare_cases_metrics.tsv
#
# Processing Department: sininformacion from file: sininformacion_cases.tsv
# Saved metrics for Department: sininformacion to sininformacion_cases_metrics.tsv
#
# Processing Department: cundinamarca from file: cundinamarca_cases.tsv
# Saved metrics for Department: cundinamarca to cundinamarca_cases_metrics.tsv
#
# Processing Department: nariño from file: nariño_cases.tsv
# Saved metrics for Department: nariño to nariño_cases_metrics.tsv
#
# Processing Department: archipielagodesanandres,providenciaysantacatalina from file: archipielagodesanandres,providenciaysantacatalina_cases.tsv
# Saved metrics for Department: archipielagodesanandres,providenciaysantacatalina to archipielagodesanandres,providenciaysantacatalina_cases_metrics.tsv
#
# Processing Department: putumayo from file: putumayo_cases.tsv
# Saved metrics for Department: putumayo to putumayo_cases_metrics.tsv
#
# Processing Department: tolima from file: tolima_cases.tsv
# Saved metrics for Department: tolima to tolima_cases_metrics.tsv
#
# Processing Department: bolivar from file: bolivar_cases.tsv
# Saved metrics for Department: bolivar to bolivar_cases_metrics.tsv
#
# Processing Department: huila from file: huila_cases.tsv
# Saved metrics for Department: huila to huila_cases_metrics.tsv
#
# Processing Department: valledelcauca from file: valledelcauca_cases.tsv
# Saved metrics for Department: valledelcauca to valledelcauca_cases_metrics.tsv
#
# Processing Department: exterior from file: exterior_cases.tsv
# Saved metrics for Department: exterior to exterior_cases_metrics.tsv
#
# Processing Department: cordoba from file: cordoba_cases.tsv
# Saved metrics for Department: cordoba to cordoba_cases_metrics.tsv
#
# Processing Department: cesar from file: cesar_cases.tsv
# Saved metrics for Department: cesar to cesar_cases_metrics.tsv
#
# Processing Department: casanare from file: casanare_cases.tsv
# Saved metrics for Department: casanare to casanare_cases_metrics.tsv
#
# Processing Department: bogota,d.c. from file: bogota,d.c._cases.tsv
# Saved metrics for Department: bogota,d.c. to bogota,d.c._cases_metrics.tsv
#
# Processing Department: laguajira from file: laguajira_cases.tsv
# Saved metrics for Department: laguajira to laguajira_cases_metrics.tsv
#
# Processing Department: quindio from file: quindio_cases.tsv
# Saved metrics for Department: quindio to quindio_cases_metrics.tsv
#
# Processing Department: amazonas from file: amazonas_cases.tsv
# Saved metrics for Department: amazonas to amazonas_cases_metrics.tsv
#
# Processing Department: vaupes from file: vaupes_cases.tsv
# Saved metrics for Department: vaupes to vaupes_cases_metrics.tsv
#
# Department-level metrics calculation and saving complete.
#
# --- Processing Region Level ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/intensity & escalation/cases/region
# Found 78 processed Region files. Processing each...
#
# Processing Region: ariariguayabero from file: ariariguayabero_cases.tsv
# Saved metrics for Region: ariariguayabero to ariariguayabero_cases_metrics.tsv
#
# Processing Region: caguan from file: caguan_cases.tsv
# Saved metrics for Region: caguan to caguan_cases_metrics.tsv
#
# Processing Region: provinciadericaurte from file: provinciadericaurte_cases.tsv
# Saved metrics for Region: provinciadericaurte to provinciadericaurte_cases_metrics.tsv
#
# Processing Region: ejecafetero from file: ejecafetero_cases.tsv
# Saved metrics for Region: ejecafetero to ejecafetero_cases_metrics.tsv
#
# Processing Region: magdalenamedioantioqueño from file: magdalenamedioantioqueño_cases.tsv
# Saved metrics for Region: magdalenamedioantioqueño to magdalenamedioantioqueño_cases_metrics.tsv
#
# Processing Region: areametropolitanadecucuta from file: areametropolitanadecucuta_cases.tsv
# Saved metrics for Region: areametropolitanadecucuta to areametropolitanadecucuta_cases_metrics.tsv
#
# Processing Region: nortedecordoba from file: nortedecordoba_cases.tsv
# Saved metrics for Region: nortedecordoba to nortedecordoba_cases_metrics.tsv
#
# Processing Region: florenciayareadeinfluencia from file: florenciayareadeinfluencia_cases.tsv
# Saved metrics for Region: florenciayareadeinfluencia to florenciayareadeinfluencia_cases_metrics.tsv
#
# Processing Region: surdecesar from file: surdecesar_cases.tsv
# Saved metrics for Region: surdecesar to surdecesar_cases_metrics.tsv
#
# Processing Region: altiplanocundiboyacense from file: altiplanocundiboyacense_cases.tsv
# Saved metrics for Region: altiplanocundiboyacense to altiplanocundiboyacense_cases_metrics.tsv
#
# Processing Region: surdelhuila from file: surdelhuila_cases.tsv
# Saved metrics for Region: surdelhuila to surdelhuila_cases_metrics.tsv
#
# Processing Region: nortedelvalle from file: nortedelvalle_cases.tsv
# Saved metrics for Region: nortedelvalle to nortedelvalle_cases_metrics.tsv
#
# Processing Region: amazoniasur-oriental from file: amazoniasur-oriental_cases.tsv
# Saved metrics for Region: amazoniasur-oriental to amazoniasur-oriental_cases_metrics.tsv
#
# Processing Region: suroccidentedenortedesantander from file: suroccidentedenortedesantander_cases.tsv
# Saved metrics for Region: suroccidentedenortedesantander to suroccidentedenortedesantander_cases_metrics.tsv
#
# Processing Region: montesdemaria from file: montesdemaria_cases.tsv
# Saved metrics for Region: montesdemaria to montesdemaria_cases_metrics.tsv
#
# Processing Region: magdalenamedio from file: magdalenamedio_cases.tsv
# Saved metrics for Region: magdalenamedio to magdalenamedio_cases_metrics.tsv
#
# Processing Region: uraba from file: uraba_cases.tsv
# Saved metrics for Region: uraba to uraba_cases_metrics.tsv
#
# Processing Region: lamojana from file: lamojana_cases.tsv
# Saved metrics for Region: lamojana to lamojana_cases_metrics.tsv
#
# Processing Region: patia from file: patia_cases.tsv
# Saved metrics for Region: patia to patia_cases_metrics.tsv
#
# Processing Region: noroccidentedecundinamarca from file: noroccidentedecundinamarca_cases.tsv
# Saved metrics for Region: noroccidentedecundinamarca to noroccidentedecundinamarca_cases_metrics.tsv
#
# Processing Region: nortedeantioquia from file: nortedeantioquia_cases.tsv
# Saved metrics for Region: nortedeantioquia to nortedeantioquia_cases_metrics.tsv
#
# Processing Region: andenpacificosur from file: andenpacificosur_cases.tsv
# Saved metrics for Region: andenpacificosur to andenpacificosur_cases_metrics.tsv
#
# Processing Region: surdenariño from file: surdenariño_cases.tsv
# Saved metrics for Region: surdenariño to surdenariño_cases_metrics.tsv
#
# Processing Region: sarare from file: sarare_cases.tsv
# Saved metrics for Region: sarare to sarare_cases_metrics.tsv
#
# Processing Region: altaguajira from file: altaguajira_cases.tsv
# Saved metrics for Region: altaguajira to altaguajira_cases_metrics.tsv
#
# Processing Region: areametropolitanadebogota from file: areametropolitanadebogota_cases.tsv
# Saved metrics for Region: areametropolitanadebogota to areametropolitanadebogota_cases_metrics.tsv
#
# Processing Region: provinciadevelez from file: provinciadevelez_cases.tsv
# Saved metrics for Region: provinciadevelez to provinciadevelez_cases_metrics.tsv
#
# Processing Region: nortedelhuila from file: nortedelhuila_cases.tsv
# Saved metrics for Region: nortedelhuila to nortedelhuila_cases_metrics.tsv
#
# Processing Region: surdelvalle from file: surdelvalle_cases.tsv
# Saved metrics for Region: surdelvalle to surdelvalle_cases_metrics.tsv
#
# Processing Region: sumapaz from file: sumapaz_cases.tsv
# Saved metrics for Region: sumapaz to sumapaz_cases_metrics.tsv
#
# Processing Region: nortedeatlantico from file: nortedeatlantico_cases.tsv
# Saved metrics for Region: nortedeatlantico to nortedeatlantico_cases_metrics.tsv
#
# Processing Region: provinciadesoto from file: provinciadesoto_cases.tsv
# Saved metrics for Region: provinciadesoto to provinciadesoto_cases_metrics.tsv
#
# Processing Region: altillanura from file: altillanura_cases.tsv
# Saved metrics for Region: altillanura to altillanura_cases_metrics.tsv
#
# Processing Region: surdebolivar from file: surdebolivar_cases.tsv
# Saved metrics for Region: surdebolivar to surdebolivar_cases_metrics.tsv
#
# Processing Region: suroesteantioqueño from file: suroesteantioqueño_cases.tsv
# Saved metrics for Region: suroesteantioqueño to suroesteantioqueño_cases_metrics.tsv
#
# Processing Region: catatumbo from file: catatumbo_cases.tsv
# Saved metrics for Region: catatumbo to catatumbo_cases_metrics.tsv
#
# Processing Region: morrosquilloysabanasdesucre from file: morrosquilloysabanasdesucre_cases.tsv
# Saved metrics for Region: morrosquilloysabanasdesucre to morrosquilloysabanasdesucre_cases_metrics.tsv
#
# Processing Region: atrato from file: atrato_cases.tsv
# Saved metrics for Region: atrato to atrato_cases_metrics.tsv
#
# Processing Region: bajocaucaantioqueño from file: bajocaucaantioqueño_cases.tsv
# Saved metrics for Region: bajocaucaantioqueño to bajocaucaantioqueño_cases_metrics.tsv
#
# Processing Region: litoralpacifico from file: litoralpacifico_cases.tsv
# Saved metrics for Region: litoralpacifico to litoralpacifico_cases_metrics.tsv
#
# Processing Region: centrodenariño from file: centrodenariño_cases.tsv
# Saved metrics for Region: centrodenariño to centrodenariño_cases_metrics.tsv
#
# Processing Region: nortedenariño from file: nortedenariño_cases.tsv
# Saved metrics for Region: nortedenariño to nortedenariño_cases_metrics.tsv
#
# Processing Region: occidentedenariño from file: occidentedenariño_cases.tsv
# Saved metrics for Region: occidentedenariño to occidentedenariño_cases_metrics.tsv
#
# Processing Region: serraniadelperija from file: serraniadelperija_cases.tsv
# Saved metrics for Region: serraniadelperija to serraniadelperija_cases_metrics.tsv
#
# Processing Region: orienteantioqueño from file: orienteantioqueño_cases.tsv
# Saved metrics for Region: orienteantioqueño to orienteantioqueño_cases_metrics.tsv
#
# Processing Region: cienagagrandedesantamarta from file: cienagagrandedesantamarta_cases.tsv
# Saved metrics for Region: cienagagrandedesantamarta to cienagagrandedesantamarta_cases_metrics.tsv
#
# Processing Region: altoputumayo from file: altoputumayo_cases.tsv
# Saved metrics for Region: altoputumayo to altoputumayo_cases_metrics.tsv
#
# Processing Region: surdeltolima from file: surdeltolima_cases.tsv
# Saved metrics for Region: surdeltolima to surdeltolima_cases_metrics.tsv
#
# Processing Region: centrodelvalle from file: centrodelvalle_cases.tsv
# Saved metrics for Region: centrodelvalle to centrodelvalle_cases_metrics.tsv
#
# Processing Region: sininformacion from file: sininformacion_cases.tsv
# Saved metrics for Region: sininformacion to sininformacion_cases_metrics.tsv
#
# Processing Region: centrooccidentedenariño from file: centrooccidentedenariño_cases.tsv
# Saved metrics for Region: centrooccidentedenariño to centrooccidentedenariño_cases_metrics.tsv
#
# Processing Region: medioputumayo from file: medioputumayo_cases.tsv
# Saved metrics for Region: medioputumayo to medioputumayo_cases_metrics.tsv
#
# Processing Region: altosinuysanjorge from file: altosinuysanjorge_cases.tsv
# Saved metrics for Region: altosinuysanjorge to altosinuysanjorge_cases_metrics.tsv
#
# Processing Region: occidenteantioqueño from file: occidenteantioqueño_cases.tsv
# Saved metrics for Region: occidenteantioqueño to occidenteantioqueño_cases_metrics.tsv
#
# Processing Region: valledesanjuan from file: valledesanjuan_cases.tsv
# Saved metrics for Region: valledesanjuan to valledesanjuan_cases_metrics.tsv
#
# Processing Region: sierranevadadesantamarta from file: sierranevadadesantamarta_cases.tsv
# Saved metrics for Region: sierranevadadesantamarta to sierranevadadesantamarta_cases_metrics.tsv
#
# Processing Region: bajoputumayo from file: bajoputumayo_cases.tsv
# Saved metrics for Region: bajoputumayo to bajoputumayo_cases_metrics.tsv
#
# Processing Region: valledeaburra from file: valledeaburra_cases.tsv
# Saved metrics for Region: valledeaburra to valledeaburra_cases_metrics.tsv
#
# Processing Region: archipielagodesanandres,providenciaysantacatalina from file: archipielagodesanandres,providenciaysantacatalina_cases.tsv
# Saved metrics for Region: archipielagodesanandres,providenciaysantacatalina to archipielagodesanandres,providenciaysantacatalina_cases_metrics.tsv
#
# Processing Region: provinciadeguanenta from file: provinciadeguanenta_cases.tsv
# Saved metrics for Region: provinciadeguanenta to provinciadeguanenta_cases_metrics.tsv
#
# Processing Region: surdemagdalena from file: surdemagdalena_cases.tsv
# Saved metrics for Region: surdemagdalena to surdemagdalena_cases_metrics.tsv
#
# Processing Region: nordesteantioqueño from file: nordesteantioqueño_cases.tsv
# Saved metrics for Region: nordesteantioqueño to nordesteantioqueño_cases_metrics.tsv
#
# Processing Region: suroccidentedecundinamarca from file: suroccidentedecundinamarca_cases.tsv
# Saved metrics for Region: suroccidentedecundinamarca to suroccidentedecundinamarca_cases_metrics.tsv
#
# Processing Region: surorientedenortedesantander from file: surorientedenortedesantander_cases.tsv
# Saved metrics for Region: surorientedenortedesantander to surorientedenortedesantander_cases_metrics.tsv
#
# Processing Region: nortedelcauca from file: nortedelcauca_cases.tsv
# Saved metrics for Region: nortedelcauca to nortedelcauca_cases_metrics.tsv
#
# Processing Region: provinciadegarciarovira from file: provinciadegarciarovira_cases.tsv
# Saved metrics for Region: provinciadegarciarovira to provinciadegarciarovira_cases_metrics.tsv
#
# Processing Region: piedemontellanero from file: piedemontellanero_cases.tsv
# Saved metrics for Region: piedemontellanero to piedemontellanero_cases_metrics.tsv
#
# Processing Region: nortedeltolima from file: nortedeltolima_cases.tsv
# Saved metrics for Region: nortedeltolima to nortedeltolima_cases_metrics.tsv
#
# Processing Region: centrodelhuila from file: centrodelhuila_cases.tsv
# Saved metrics for Region: centrodelhuila to centrodelhuila_cases_metrics.tsv
#
# Processing Region: canaldeldique from file: canaldeldique_cases.tsv
# Saved metrics for Region: canaldeldique to canaldeldique_cases_metrics.tsv
#
# Processing Region: orientedeboyaca from file: orientedeboyaca_cases.tsv
# Saved metrics for Region: orientedeboyaca to orientedeboyaca_cases_metrics.tsv
#
# Processing Region: serraniadelosyariguies from file: serraniadelosyariguies_cases.tsv
# Saved metrics for Region: serraniadelosyariguies to serraniadelosyariguies_cases_metrics.tsv
#
# Processing Region: provinciacomunera from file: provinciacomunera_cases.tsv
# Saved metrics for Region: provinciacomunera to provinciacomunera_cases_metrics.tsv
#
# Processing Region: llanosorientales from file: llanosorientales_cases.tsv
# Saved metrics for Region: llanosorientales to llanosorientales_cases_metrics.tsv
#
# Processing Region: centroorientedeatlantico from file: centroorientedeatlantico_cases.tsv
# Saved metrics for Region: centroorientedeatlantico to centroorientedeatlantico_cases_metrics.tsv
#
# Processing Region: occidentedeatlantico from file: occidentedeatlantico_cases.tsv
# Saved metrics for Region: occidentedeatlantico to occidentedeatlantico_cases_metrics.tsv
#
# Processing Region: centrodenortedesantander from file: centrodenortedesantander_cases.tsv
# Saved metrics for Region: centrodenortedesantander to centrodenortedesantander_cases_metrics.tsv
#
# Processing Region: macizocolombiano from file: macizocolombiano_cases.tsv
# Saved metrics for Region: macizocolombiano to macizocolombiano_cases_metrics.tsv
#
# Region-level metrics calculation and saving complete.
#
# --- Overall Intensity and Escalation Calculation Process Finished ---
