# %% [markdown]
# # Calculation of Intensity and Escalation Metrics for Cases (VS/VI/VC)
#
# ## Project:
# VS_VI_Source_CodeThis Jupyter Notebook is part of the VS_VI_Source_Code project, which aims to analyze the dynamics of Selective Violence (VS) and Indiscriminate Violence (VI) in Colombia.
#
# ## Purpose
# The primary purpose of this notebook is to calculate the key temporal metrics (Escalation and Intensity) for pre-processed monthly case counts of Selective Violence (VS), Indiscriminate Violence (VI), and their sum (Violencia Colectiva, VC). These calculations are performed for data at the Country, Department, and Region levels, using data files generated in previous processing steps. The calculated metrics are then saved for subsequent analysis and visualization.
#
# ## Workflow
# This notebook focuses on the Metric Calculation and Results Saving stages of the project's analytical workflow. It assumes that the monthly case counts per violence type (VS/VI) for each geographical unit have already been processed and saved in the ../Data/processed/cases/ directory structure.
#
# ## About
# This notebook implements the logic to read structured time series data (monthly case counts for VS and VI) from files, calculate the total collective violence (VC), apply the defined Escalation and Intensity functions to the time series of VS, VI, and VC, and store the final results including these metrics.

# %% [markdown]
# ### 1. Initial Setup, Library Imports, and Path Configuration
# This block performs the initial setup for the notebook environment. It includes importing all necessary Python libraries required for data handling, file system operations, numerical computations, and combinations. It defines the base input directories for the pre-processed monthly case counts (VS/VI) for each geographical level, now taking into account the new ActorType (State/Non-State) segmentation. It also sets up the base output directory where the final results with calculated metrics will be stored, following the same nested structure for ActorType.

# %%
# 1. Initial Setup, Library Imports, and Path Configuration

import pandas as pd
import os
import numpy as np
from itertools import product # Needed for potential future use or clarity

# Define the base output directory for results.
# Results for different levels (country, department, region) will go into subfolders here.
# Assumes the notebook is in a subfolder (e.g., 'notebooks') and results go one level up in 'Results/intensity & escalation/cases'.
# Adjust '../' if your actual folder structure is different.
# Example structure:
# Project_Root/
# ├── Data/
# │   └── processed/
# │       └── cases/
# │           ├── country/    # Processed country data (Input)
# │           ├── departments/ # Processed department data (Input)
# │           └── regions/    # Processed region data (Input)
# ├── Results/
# │   └── intensity & escalation/
# │       └── cases/    # Results will be saved here (Output)
# └── notebooks/        # This notebook is here

# Define the base output directory for results.
# Results for different levels (country, department, region) and ACTOR TYPES
# will go into subfolders here.
base_results_dir = os.path.join(os.getcwd(), '..', 'Results', 'intensity & escalation', 'cases')

# Define the base input directory for processed data (monthly counts per type and actor).
# These directories now contain subfolders for 'state_actors' and 'non_state_actors'.
processed_data_base_dir = os.path.join(os.getcwd(), '..', 'Data', 'processed', 'cases')

# List of actor types to iterate through. These correspond to the new subfolder names.
ACTOR_TYPES_SUBFOLDERS = ['state_actor', 'non_state_actor', 'unknown_actor_type'] # Ensure this matches your folder names from the previous notebook

# Define the year range (for context, should match the processed data files).
min_year = 1958
max_year = 2022

print("Initial setup, library imports, and path configuration complete.")
print(f"Processed data will be read from: {processed_data_base_dir}")
print(f"Results will be saved in: {base_results_dir}")
print(f"Processing will be segmented by Actor Types: {ACTOR_TYPES_SUBFOLDERS}")
# Out:
# Initial setup, library imports, and path configuration complete.
# Processed data will be read from: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/processed/cases
# Results will be saved in: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/intensity & escalation/cases
# Processing will be segmented by Actor Types: ['state_actor', 'non_state_actor', 'unknown_actor_type']

# %% [markdown]
# ### 2. Define Metric Calculation Functions
# This block defines the core Python functions used to calculate the temporal dynamics metrics: Escalation and Intensity. These functions are designed to operate on a single time series (a pandas Series or DataFrame column) of monthly counts.calculate_escalation(series): Computes the Escalation metric by comparing each month's count to the previous month's count.calculate_intensity(series, window=36): Computes the Intensity metric by comparing each month's count to the average count over a preceding rolling window (defaulting to 36 months).The functions return a series of the same length as the input, with values -1, 0, or 1, representing decrease, no change, or increase relative to the comparison point. Initial months where the comparison is not possible are handled by filling with 0.

# %%
# 2. Define Metric Calculation Functions

print("\n--- Defining Metric Calculation Functions ---")

def calculate_escalation(series):
    """
    Calculates the Escalation metric for a time series.
    Escalation = 1 if current > previous, 0 if current == previous, -1 if current < previous.
    Handles the first month (no previous month) by setting Escalation to 0.

    Args:
        series (pd.Series): A pandas Series representing a time series of counts.

    Returns:
        pd.Series: A pandas Series of the same length with Escalation values (-1, 0, 1).
    """
    # Shift the series to get the previous month's value
    previous_month = series.shift(1)

    # Calculate the difference
    difference = series - previous_month

    # Apply the conditions using numpy.sign to get -1, 0, or 1
    # Fill NaN for the first month's escalation (no previous data) with 0
    escalation = np.sign(difference).fillna(0).astype(int)

    return escalation

def calculate_intensity(series, window=36):
    """
    Calculates the Intensity metric for a time series.
    Intensity = 1 if current > 36-month mean, 0 if current == mean, -1 if current < mean.
    Requires at least 'window' months of data to calculate the mean.

    Args:
        series (pd.Series): A pandas Series representing a time series of counts.
        window (int): The number of preceding months to use for the rolling mean calculation.

    Returns:
        pd.Series: A pandas Series of the same length with Intensity values (-1, 0, 1).
    """
    # Calculate the rolling mean over the specified window
    rolling_mean = series.rolling(window=window).mean()

    # Calculate the difference between current and rolling mean
    difference = series - rolling_mean

    # Apply the conditions using numpy.sign to get -1, 0, or 1
    # Fill NaN for the first 'window' months (not enough data for mean) with 0
    intensity = np.sign(difference).fillna(0).astype(int)

    return intensity

print("Metric calculation functions defined.")
# Out:
# --- Defining Metric Calculation Functions ---
# Metric calculation functions defined.

# %% [markdown]
# ### 3. Calculate Intensity and Escalation Metrics from Processed Data with Previous State (Including Actor Types)
# This block calculates the monthly Escalation and Intensity metrics for Selective Violence (VS), Indiscriminate Violence (VI), and their sum (Violencia Colectiva, VC) case counts from 1958 to 2022. These metrics are computed by loading the pre-processed monthly case counts (including VS/VI breakdown) for Country, Departments, and Regions, now segmented by ActorType (State/Non-State).
#
# The script iterates through the input directories for each geographical level and then through each ActorType subfolder. For each file found, it reads the data, calculates VC for each unit by summing the existing VS and VI counts, applies the metric functions (defined in Cell 2) to the time series for VS, VI, and VC, and crucially, adds a "Previous State" column. This new column indicates the combined state of the Intensity and Escalation metrics from the immediately preceding month. Finally, it saves the resulting DataFrames (including counts, metrics, and the Previous State) to separate TSV files in the designated results directory structure, maintaining the ActorType segmentation.
#
# This process relies on the .tsv files generated in the previous data processing notebook (01_Data_Processing_Cases.ipynb), specifically the outputs from its Cells 3, 5, and 6, which now include actor type subdirectories.

# %%
# 3. Calculate and Save Metrics from Processed Data

print("\n--- Calculating and Saving Metrics from Processed Data ---")

# Ensure base directories and metric calculation functions are defined (from Cell 1 and Cell 2)
if 'base_results_dir' not in globals() or 'processed_data_base_dir' not in globals():
    print("Error: Base data directories not defined. Please run Cell 1.")
elif 'calculate_escalation' not in globals() or 'calculate_intensity' not in globals():
    print("Error: Metric calculation functions (calculate_escalation, calculate_intensity) not found. Please run Cell 2.")
else:

    # Define the mapping for [Intensity, Escalation] pairs to states
    state_mapping = {
        (1, 1): 'A',
        (1, 0): 'B',
        (1, -1): 'C',
        (0, 1): 'D',
        (0, 0): 'E',
        (0, -1): 'F',
        (-1, 1): 'G',
        (-1, 0): 'H',
        (-1, -1): 'I'
    }

    # --- Helper Function to Calculate Metrics and State for VS, VI, and VC ---\
    # This function remains largely the same, as it operates on a single df_unit_counts.
    # The external loop will handle filtering by ActorType before calling this.

    def calculate_metrics_and_state_for_types(df_unit_counts):
        """
        Calculates Escalation, Intensity, and Previous State for VS, VI, and VC
        within a single DataFrame containing 'Año', 'Mes', 'violence type', and 'CaseCount'.
        Assumes the input DataFrame is already complete for Year-Month-Violence Type
        combinations and sorted.
        """
        metrics_list = []
        for v_type in ['VS', 'VI', 'VC']:
            # Filter data for the current violence type
            df_type = df_unit_counts[df_unit_counts['violence type'] == v_type].copy()

            if not df_type.empty:
                # Ensure the time series is sorted for correct shift/rolling calculations
                df_type = df_type.sort_values(by=['Año', 'Mes']).reset_index(drop=True)

                # Calculate metrics using the functions defined in Cell 2
                df_type['Escalation'] = calculate_escalation(df_type['CaseCount'])
                df_type['Intensity'] = calculate_intensity(df_type['CaseCount'])

                # --- Calculate Current State and Shift for Previous State ---
                # Create a temporary column with the (Intensity, Escalation) tuple for the current month
                df_type['CurrentState_Tuple'] = list(zip(df_type['Intensity'], df_type['Escalation']))

                # Map the tuple to the state letter using the defined mapping
                # Use .get() with a default (e.g., 'Unknown' or NaN) for safety if a pair isn't in mapping
                df_type['CurrentState'] = df_type['CurrentState_Tuple'].apply(lambda x: state_mapping.get(x, 'Unknown'))

                # Shift the 'CurrentState' column to get the 'Previous State'
                df_type['Previous State'] = df_type['CurrentState'].shift(1).fillna('Start') # Fill the first month's previous state with 'Start' or similar

                # Drop the temporary columns
                df_type = df_type.drop(columns=['CurrentState_Tuple', 'CurrentState'])

                # Select relevant columns and append, including the new 'Previous State'
                metrics_list.append(df_type[['Año', 'Mes', 'violence type', 'CaseCount', 'Escalation', 'Intensity', 'Previous State']])

        # Concatenate metrics for all types (VS, VI, VC) for this unit
        if metrics_list:
            unit_final_df = pd.concat(metrics_list, ignore_index=True)
            # Sort the final DataFrame
            unit_final_df = unit_final_df.sort_values(by=['Año', 'Mes', 'violence type']).reset_index(drop=True)
            return unit_final_df
        else:
            return pd.DataFrame() # Return empty DataFrame if no metrics were calculated


    # --- Helper Function to Process a Single Processed Data File (Now aware of ActorType) ---

    # Modified to accept actor_type_subdir to correctly form input/output paths
    def process_file_and_calculate_metrics(file_path, output_dir_base, level_name, unit_name, actor_type_subdir):
        """
        Reads a processed TSV file (containing VS/VI counts), calculates VC,
        Escalation, Intensity, and Previous State for VS, VI, and VC, and saves results.
        Now takes 'actor_type_subdir' for dynamic path construction.
        """
        print(f"\nProcessing {level_name}: {unit_name} ({actor_type_subdir}) from file: {os.path.basename(file_path)}")

        try:
            # Read the processed TSV file containing 'Año', 'Mes', 'violence type' (VS/VI), 'CaseCount'
            df_counts_vsvi = pd.read_csv(file_path, sep='\t')

            # Ensure required columns are present
            required_cols = ['Año', 'Mes', 'violence type', 'CaseCount']
            if not all(col in df_counts_vsvi.columns for col in required_cols):
                print(f"Error: Missing required columns in {os.path.basename(file_path)}: {required_cols}. Skipping.")
                return pd.DataFrame() # Return empty DataFrame or handle error appropriately

            # Ensure data types are correct and drop NaNs in essential columns
            df_counts_vsvi['Año'] = pd.to_numeric(df_counts_vsvi['Año'], errors='coerce')
            df_counts_vsvi['Mes'] = pd.to_numeric(df_counts_vsvi['Mes'], errors='coerce')
            df_counts_vsvi['CaseCount'] = pd.to_numeric(df_counts_vsvi['CaseCount'], errors='coerce').fillna(0).astype(int)
            df_counts_vsvi = df_counts_vsvi.dropna(subset=required_cols).copy()

            # Ensure the DataFrame contains only VS and VI types before calculating VC
            valid_vsvi_df = df_counts_vsvi[df_counts_vsvi['violence type'].isin(['VS', 'VI'])].copy()

            if valid_vsvi_df.empty:
                 print(f"Warning: No valid VS or VI data found in {os.path.basename(file_path)} to calculate metrics. Skipping.")
                 return pd.DataFrame() # Return empty DataFrame

            # Calculate VC (VS + VI) for the unit from the existing VS and VI counts
            pivot_for_vc = valid_vsvi_df.pivot_table(
                index=['Año', 'Mes'],
                columns='violence type',
                values='CaseCount',
                fill_value=0,
                dropna=False
            )
            pivot_for_vc['VC'] = pivot_for_vc.get('VS', 0) + pivot_for_vc.get('VI', 0)

            # Unpivot VC back to long format
            vc_df = pivot_for_vc[['VC']].stack().reset_index(name='CaseCount')
            vc_df['violence type'] = 'VC'

            # Combine VS, VI, and VC dataframes for this unit for metric calculation
            combined_unit_counts_df = pd.concat([valid_vsvi_df, vc_df], ignore_index=True)
            combined_unit_counts_df = combined_unit_counts_df.sort_values(by=['Año', 'Mes', 'violence type']).reset_index(drop=True)

            # Calculate metrics and state for the unit (VS, VI, VC)
            unit_final_df = calculate_metrics_and_state_for_types(combined_unit_counts_df)

            # Save the results
            if not unit_final_df.empty:
                # Construct the full output directory including the actor type
                full_output_dir = os.path.join(output_dir_base, actor_type_subdir)
                os.makedirs(full_output_dir, exist_ok=True) # Ensure output directory exists

                # Generate the output filename: unit name + "_cases_metrics.tsv"
                output_filename = unit_name.lower().replace(" ", "") + "_cases_metrics.tsv"
                output_path = os.path.join(full_output_dir, output_filename)

                try:
                    unit_final_df.to_csv(output_path, sep='\t', index=False)
                    print(f"Saved metrics for {level_name}: {unit_name} ({actor_type_subdir}) to {output_filename}")
                    return unit_final_df # Return the DataFrame for potential further use/logging
                except Exception as e:
                    print(f"Error saving metrics for {level_name}: {unit_name} ({actor_type_subdir}) to {output_filename}: {e}")
                    return pd.DataFrame()
            else:
                 print(f"No metrics calculated for {level_name}: {unit_name} ({actor_type_subdir}). Skipping save.")
                 return pd.DataFrame()

        except Exception as e:
            print(f"An unexpected error occurred during processing file {os.path.basename(file_path)}: {e}")
            return pd.DataFrame()


    # --- Process Each Level and Actor Type ---

    # Define the geographical levels and their corresponding input/output directory structures
    # The 'input_subdir' refers to the folder within 'processed_data_base_dir'
    # The 'output_subdir_base' refers to the folder within 'base_results_dir'
    levels_info = [
        {'name': 'Country', 'input_subdir': 'country', 'output_subdir_base': 'country'},
        {'name': 'Department', 'input_subdir': 'departments', 'output_subdir_base': 'department'},
        {'name': 'Region', 'input_subdir': 'regions', 'output_subdir_base': 'region'}
    ]

    for level in levels_info:
        level_name = level['name']
        input_base_level_dir = os.path.join(processed_data_base_dir, level['input_subdir'])
        output_base_level_dir = os.path.join(base_results_dir, level['output_subdir_base'])

        print(f"\n--- Processing {level_name} Level ---")

        # Loop through each actor type subfolder
        for actor_type_subfolder in ACTOR_TYPES_SUBFOLDERS:
            current_input_dir = os.path.join(input_base_level_dir, actor_type_subfolder)
            current_output_dir_for_actor = os.path.join(output_base_level_dir, actor_type_subfolder)

            print(f"\n--- Processing {level_name} Level for Actor Type: {actor_type_subfolder} ---")

            # Create the output directory for this level and actor type if it doesn't exist
            os.makedirs(current_output_dir_for_actor, exist_ok=True)
            print(f"Ensured output directory exists: {current_output_dir_for_actor}")

            # Check if the input directory for the current actor type exists
            if not os.path.exists(current_input_dir):
                print(f"Error: Input data directory not found for {level_name} ({actor_type_subfolder}): {current_input_dir}. Skipping this actor type.")
                continue # Skip to the next actor type

            # List all TSV files in the input directory for this level and actor type
            # Assuming filenames end with '_cases_state_actor.tsv' or '_cases_non_state_actor.tsv' etc.
            # We are now looking for files like 'colombia_cases_state_actor.tsv'
            processed_files = [f for f in os.listdir(current_input_dir) if f.endswith('.tsv')]

            if not processed_files:
                print(f"Warning: No processed TSV files found in {current_input_dir}. Skipping {level_name} ({actor_type_subfolder}) processing.")
            else:
                print(f"Found {len(processed_files)} processed {level_name} ({actor_type_subfolder}) files. Processing each...")
                for filename in processed_files:
                    file_path = os.path.join(current_input_dir, filename)
                    # Extract unit name from filename (e.g., 'colombia', 'antioquia', 'pacifica')
                    # The filename will be something like 'unitname_cases_actortype.tsv'
                    # We need to remove the '_cases_actortype.tsv' part
                    # Find the last occurrence of '_cases_' to split the filename
                    parts = filename.split('_cases_')
                    if len(parts) > 1:
                        unit_name = parts[0]
                    else:
                        unit_name = filename.replace(".tsv", "") # Fallback if format is unexpected

                    # Process the file, calculate metrics and state, and save the result
                    # Pass the current_output_dir_for_actor and the actor_type_subfolder
                    unit_metrics_df = process_file_and_calculate_metrics(
                        file_path,
                        output_base_level_dir, # Pass the base directory for this level (e.g., 'country')
                        level_name,
                        unit_name,
                        actor_type_subfolder # Pass the specific actor type subfolder name
                    )

        print(f"\n{level_name}-level metrics calculation and saving complete for all actor types.")

    print("\n--- Overall Intensity and Escalation Calculation Process Finished ---")
# Out:
# --- Calculating and Saving Metrics from Processed Data ---
#
# --- Processing Country Level ---
#
# --- Processing Country Level for Actor Type: state_actor ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/intensity & escalation/cases/country/state_actor
# Found 1 processed Country (state_actor) files. Processing each...
#
# Processing Country: colombia (state_actor) from file: colombia_cases_state_actor.tsv
# Saved metrics for Country: colombia (state_actor) to colombia_cases_metrics.tsv
#
# --- Processing Country Level for Actor Type: non_state_actor ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/intensity & escalation/cases/country/non_state_actor
# Found 1 processed Country (non_state_actor) files. Processing each...
#
# Processing Country: colombia (non_state_actor) from file: colombia_cases_non_state_actor.tsv
# Saved metrics for Country: colombia (non_state_actor) to colombia_cases_metrics.tsv
#
# --- Processing Country Level for Actor Type: unknown_actor_type ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/intensity & escalation/cases/country/unknown_actor_type
# Error: Input data directory not found for Country (unknown_actor_type): /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/processed/cases/country/unknown_actor_type. Skipping this actor type.
#
# Country-level metrics calculation and saving complete for all actor types.
#
# --- Processing Department Level ---
#
# --- Processing Department Level for Actor Type: state_actor ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/intensity & escalation/cases/department/state_actor
# Found 35 processed Department (state_actor) files. Processing each...
#
# Processing Department: magdalena (state_actor) from file: magdalena_cases_state_actor.tsv
# Saved metrics for Department: magdalena (state_actor) to magdalena_cases_metrics.tsv
#
# Processing Department: antioquia (state_actor) from file: antioquia_cases_state_actor.tsv
# Saved metrics for Department: antioquia (state_actor) to antioquia_cases_metrics.tsv
#
# Processing Department: choco (state_actor) from file: choco_cases_state_actor.tsv
# Saved metrics for Department: choco (state_actor) to choco_cases_metrics.tsv
#
# Processing Department: caqueta (state_actor) from file: caqueta_cases_state_actor.tsv
# Saved metrics for Department: caqueta (state_actor) to caqueta_cases_metrics.tsv
#
# Processing Department: guaviare (state_actor) from file: guaviare_cases_state_actor.tsv
# Saved metrics for Department: guaviare (state_actor) to guaviare_cases_metrics.tsv
#
# Processing Department: vichada (state_actor) from file: vichada_cases_state_actor.tsv
# Saved metrics for Department: vichada (state_actor) to vichada_cases_metrics.tsv
#
# Processing Department: boyaca (state_actor) from file: boyaca_cases_state_actor.tsv
# Saved metrics for Department: boyaca (state_actor) to boyaca_cases_metrics.tsv
#
# Processing Department: cauca (state_actor) from file: cauca_cases_state_actor.tsv
# Saved metrics for Department: cauca (state_actor) to cauca_cases_metrics.tsv
#
# Processing Department: risaralda (state_actor) from file: risaralda_cases_state_actor.tsv
# Saved metrics for Department: risaralda (state_actor) to risaralda_cases_metrics.tsv
#
# Processing Department: bogota,d.c. (state_actor) from file: bogota,d.c._cases_state_actor.tsv
# Saved metrics for Department: bogota,d.c. (state_actor) to bogota,d.c._cases_metrics.tsv
#
# Processing Department: huila (state_actor) from file: huila_cases_state_actor.tsv
# Saved metrics for Department: huila (state_actor) to huila_cases_metrics.tsv
#
# Processing Department: laguajira (state_actor) from file: laguajira_cases_state_actor.tsv
# Saved metrics for Department: laguajira (state_actor) to laguajira_cases_metrics.tsv
#
# Processing Department: bolivar (state_actor) from file: bolivar_cases_state_actor.tsv
# Saved metrics for Department: bolivar (state_actor) to bolivar_cases_metrics.tsv
#
# Processing Department: amazonas (state_actor) from file: amazonas_cases_state_actor.tsv
# Saved metrics for Department: amazonas (state_actor) to amazonas_cases_metrics.tsv
#
# Processing Department: archipielagodesanandres,providenciaysantacatalina (state_actor) from file: archipielagodesanandres,providenciaysantacatalina_cases_state_actor.tsv
# Saved metrics for Department: archipielagodesanandres,providenciaysantacatalina (state_actor) to archipielagodesanandres,providenciaysantacatalina_cases_metrics.tsv
#
# Processing Department: santander (state_actor) from file: santander_cases_state_actor.tsv
# Saved metrics for Department: santander (state_actor) to santander_cases_metrics.tsv
#
# Processing Department: sucre (state_actor) from file: sucre_cases_state_actor.tsv
# Saved metrics for Department: sucre (state_actor) to sucre_cases_metrics.tsv
#
# Processing Department: cordoba (state_actor) from file: cordoba_cases_state_actor.tsv
# Saved metrics for Department: cordoba (state_actor) to cordoba_cases_metrics.tsv
#
# Processing Department: tolima (state_actor) from file: tolima_cases_state_actor.tsv
# Saved metrics for Department: tolima (state_actor) to tolima_cases_metrics.tsv
#
# Processing Department: meta (state_actor) from file: meta_cases_state_actor.tsv
# Saved metrics for Department: meta (state_actor) to meta_cases_metrics.tsv
#
# Processing Department: putumayo (state_actor) from file: putumayo_cases_state_actor.tsv
# Saved metrics for Department: putumayo (state_actor) to putumayo_cases_metrics.tsv
#
# Processing Department: sininformacion (state_actor) from file: sininformacion_cases_state_actor.tsv
# Saved metrics for Department: sininformacion (state_actor) to sininformacion_cases_metrics.tsv
#
# Processing Department: nortedesantander (state_actor) from file: nortedesantander_cases_state_actor.tsv
# Saved metrics for Department: nortedesantander (state_actor) to nortedesantander_cases_metrics.tsv
#
# Processing Department: cundinamarca (state_actor) from file: cundinamarca_cases_state_actor.tsv
# Saved metrics for Department: cundinamarca (state_actor) to cundinamarca_cases_metrics.tsv
#
# Processing Department: vaupes (state_actor) from file: vaupes_cases_state_actor.tsv
# Saved metrics for Department: vaupes (state_actor) to vaupes_cases_metrics.tsv
#
# Processing Department: casanare (state_actor) from file: casanare_cases_state_actor.tsv
# Saved metrics for Department: casanare (state_actor) to casanare_cases_metrics.tsv
#
# Processing Department: caldas (state_actor) from file: caldas_cases_state_actor.tsv
# Saved metrics for Department: caldas (state_actor) to caldas_cases_metrics.tsv
#
# Processing Department: cesar (state_actor) from file: cesar_cases_state_actor.tsv
# Saved metrics for Department: cesar (state_actor) to cesar_cases_metrics.tsv
#
# Processing Department: exterior (state_actor) from file: exterior_cases_state_actor.tsv
# Saved metrics for Department: exterior (state_actor) to exterior_cases_metrics.tsv
#
# Processing Department: quindio (state_actor) from file: quindio_cases_state_actor.tsv
# Saved metrics for Department: quindio (state_actor) to quindio_cases_metrics.tsv
#
# Processing Department: guainia (state_actor) from file: guainia_cases_state_actor.tsv
# Saved metrics for Department: guainia (state_actor) to guainia_cases_metrics.tsv
#
# Processing Department: valledelcauca (state_actor) from file: valledelcauca_cases_state_actor.tsv
# Saved metrics for Department: valledelcauca (state_actor) to valledelcauca_cases_metrics.tsv
#
# Processing Department: arauca (state_actor) from file: arauca_cases_state_actor.tsv
# Saved metrics for Department: arauca (state_actor) to arauca_cases_metrics.tsv
#
# Processing Department: nariño (state_actor) from file: nariño_cases_state_actor.tsv
# Saved metrics for Department: nariño (state_actor) to nariño_cases_metrics.tsv
#
# Processing Department: atlantico (state_actor) from file: atlantico_cases_state_actor.tsv
# Saved metrics for Department: atlantico (state_actor) to atlantico_cases_metrics.tsv
#
# --- Processing Department Level for Actor Type: non_state_actor ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/intensity & escalation/cases/department/non_state_actor
# Found 35 processed Department (non_state_actor) files. Processing each...
#
# Processing Department: quindio (non_state_actor) from file: quindio_cases_non_state_actor.tsv
# Saved metrics for Department: quindio (non_state_actor) to quindio_cases_metrics.tsv
#
# Processing Department: antioquia (non_state_actor) from file: antioquia_cases_non_state_actor.tsv
# Saved metrics for Department: antioquia (non_state_actor) to antioquia_cases_metrics.tsv
#
# Processing Department: cauca (non_state_actor) from file: cauca_cases_non_state_actor.tsv
# Saved metrics for Department: cauca (non_state_actor) to cauca_cases_metrics.tsv
#
# Processing Department: vaupes (non_state_actor) from file: vaupes_cases_non_state_actor.tsv
# Saved metrics for Department: vaupes (non_state_actor) to vaupes_cases_metrics.tsv
#
# Processing Department: sucre (non_state_actor) from file: sucre_cases_non_state_actor.tsv
# Saved metrics for Department: sucre (non_state_actor) to sucre_cases_metrics.tsv
#
# Processing Department: cundinamarca (non_state_actor) from file: cundinamarca_cases_non_state_actor.tsv
# Saved metrics for Department: cundinamarca (non_state_actor) to cundinamarca_cases_metrics.tsv
#
# Processing Department: sininformacion (non_state_actor) from file: sininformacion_cases_non_state_actor.tsv
# Saved metrics for Department: sininformacion (non_state_actor) to sininformacion_cases_metrics.tsv
#
# Processing Department: valledelcauca (non_state_actor) from file: valledelcauca_cases_non_state_actor.tsv
# Saved metrics for Department: valledelcauca (non_state_actor) to valledelcauca_cases_metrics.tsv
#
# Processing Department: exterior (non_state_actor) from file: exterior_cases_non_state_actor.tsv
# Saved metrics for Department: exterior (non_state_actor) to exterior_cases_metrics.tsv
#
# Processing Department: bogota,d.c. (non_state_actor) from file: bogota,d.c._cases_non_state_actor.tsv
# Saved metrics for Department: bogota,d.c. (non_state_actor) to bogota,d.c._cases_metrics.tsv
#
# Processing Department: magdalena (non_state_actor) from file: magdalena_cases_non_state_actor.tsv
# Saved metrics for Department: magdalena (non_state_actor) to magdalena_cases_metrics.tsv
#
# Processing Department: nortedesantander (non_state_actor) from file: nortedesantander_cases_non_state_actor.tsv
# Saved metrics for Department: nortedesantander (non_state_actor) to nortedesantander_cases_metrics.tsv
#
# Processing Department: nariño (non_state_actor) from file: nariño_cases_non_state_actor.tsv
# Saved metrics for Department: nariño (non_state_actor) to nariño_cases_metrics.tsv
#
# Processing Department: santander (non_state_actor) from file: santander_cases_non_state_actor.tsv
# Saved metrics for Department: santander (non_state_actor) to santander_cases_metrics.tsv
#
# Processing Department: huila (non_state_actor) from file: huila_cases_non_state_actor.tsv
# Saved metrics for Department: huila (non_state_actor) to huila_cases_metrics.tsv
#
# Processing Department: archipielagodesanandres,providenciaysantacatalina (non_state_actor) from file: archipielagodesanandres,providenciaysantacatalina_cases_non_state_actor.tsv
# Saved metrics for Department: archipielagodesanandres,providenciaysantacatalina (non_state_actor) to archipielagodesanandres,providenciaysantacatalina_cases_metrics.tsv
#
# Processing Department: guainia (non_state_actor) from file: guainia_cases_non_state_actor.tsv
# Saved metrics for Department: guainia (non_state_actor) to guainia_cases_metrics.tsv
#
# Processing Department: putumayo (non_state_actor) from file: putumayo_cases_non_state_actor.tsv
# Saved metrics for Department: putumayo (non_state_actor) to putumayo_cases_metrics.tsv
#
# Processing Department: amazonas (non_state_actor) from file: amazonas_cases_non_state_actor.tsv
# Saved metrics for Department: amazonas (non_state_actor) to amazonas_cases_metrics.tsv
#
# Processing Department: boyaca (non_state_actor) from file: boyaca_cases_non_state_actor.tsv
# Saved metrics for Department: boyaca (non_state_actor) to boyaca_cases_metrics.tsv
#
# Processing Department: bolivar (non_state_actor) from file: bolivar_cases_non_state_actor.tsv
# Saved metrics for Department: bolivar (non_state_actor) to bolivar_cases_metrics.tsv
#
# Processing Department: guaviare (non_state_actor) from file: guaviare_cases_non_state_actor.tsv
# Saved metrics for Department: guaviare (non_state_actor) to guaviare_cases_metrics.tsv
#
# Processing Department: atlantico (non_state_actor) from file: atlantico_cases_non_state_actor.tsv
# Saved metrics for Department: atlantico (non_state_actor) to atlantico_cases_metrics.tsv
#
# Processing Department: arauca (non_state_actor) from file: arauca_cases_non_state_actor.tsv
# Saved metrics for Department: arauca (non_state_actor) to arauca_cases_metrics.tsv
#
# Processing Department: cesar (non_state_actor) from file: cesar_cases_non_state_actor.tsv
# Saved metrics for Department: cesar (non_state_actor) to cesar_cases_metrics.tsv
#
# Processing Department: tolima (non_state_actor) from file: tolima_cases_non_state_actor.tsv
# Saved metrics for Department: tolima (non_state_actor) to tolima_cases_metrics.tsv
#
# Processing Department: risaralda (non_state_actor) from file: risaralda_cases_non_state_actor.tsv
# Saved metrics for Department: risaralda (non_state_actor) to risaralda_cases_metrics.tsv
#
# Processing Department: caldas (non_state_actor) from file: caldas_cases_non_state_actor.tsv
# Saved metrics for Department: caldas (non_state_actor) to caldas_cases_metrics.tsv
#
# Processing Department: cordoba (non_state_actor) from file: cordoba_cases_non_state_actor.tsv
# Saved metrics for Department: cordoba (non_state_actor) to cordoba_cases_metrics.tsv
#
# Processing Department: caqueta (non_state_actor) from file: caqueta_cases_non_state_actor.tsv
# Saved metrics for Department: caqueta (non_state_actor) to caqueta_cases_metrics.tsv
#
# Processing Department: laguajira (non_state_actor) from file: laguajira_cases_non_state_actor.tsv
# Saved metrics for Department: laguajira (non_state_actor) to laguajira_cases_metrics.tsv
#
# Processing Department: meta (non_state_actor) from file: meta_cases_non_state_actor.tsv
# Saved metrics for Department: meta (non_state_actor) to meta_cases_metrics.tsv
#
# Processing Department: choco (non_state_actor) from file: choco_cases_non_state_actor.tsv
# Saved metrics for Department: choco (non_state_actor) to choco_cases_metrics.tsv
#
# Processing Department: casanare (non_state_actor) from file: casanare_cases_non_state_actor.tsv
# Saved metrics for Department: casanare (non_state_actor) to casanare_cases_metrics.tsv
#
# Processing Department: vichada (non_state_actor) from file: vichada_cases_non_state_actor.tsv
# Saved metrics for Department: vichada (non_state_actor) to vichada_cases_metrics.tsv
#
# --- Processing Department Level for Actor Type: unknown_actor_type ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/intensity & escalation/cases/department/unknown_actor_type
# Error: Input data directory not found for Department (unknown_actor_type): /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/processed/cases/departments/unknown_actor_type. Skipping this actor type.
#
# Department-level metrics calculation and saving complete for all actor types.
#
# --- Processing Region Level ---
#
# --- Processing Region Level for Actor Type: state_actor ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/intensity & escalation/cases/region/state_actor
# Found 78 processed Region (state_actor) files. Processing each...
#
# Processing Region: morrosquilloysabanasdesucre (state_actor) from file: morrosquilloysabanasdesucre_cases_state_actor.tsv
# Saved metrics for Region: morrosquilloysabanasdesucre (state_actor) to morrosquilloysabanasdesucre_cases_metrics.tsv
#
# Processing Region: centrodenariño (state_actor) from file: centrodenariño_cases_state_actor.tsv
# Saved metrics for Region: centrodenariño (state_actor) to centrodenariño_cases_metrics.tsv
#
# Processing Region: altoputumayo (state_actor) from file: altoputumayo_cases_state_actor.tsv
# Saved metrics for Region: altoputumayo (state_actor) to altoputumayo_cases_metrics.tsv
#
# Processing Region: nortedelhuila (state_actor) from file: nortedelhuila_cases_state_actor.tsv
# Saved metrics for Region: nortedelhuila (state_actor) to nortedelhuila_cases_metrics.tsv
#
# Processing Region: medioputumayo (state_actor) from file: medioputumayo_cases_state_actor.tsv
# Saved metrics for Region: medioputumayo (state_actor) to medioputumayo_cases_metrics.tsv
#
# Processing Region: surdecesar (state_actor) from file: surdecesar_cases_state_actor.tsv
# Saved metrics for Region: surdecesar (state_actor) to surdecesar_cases_metrics.tsv
#
# Processing Region: centrooccidentedenariño (state_actor) from file: centrooccidentedenariño_cases_state_actor.tsv
# Saved metrics for Region: centrooccidentedenariño (state_actor) to centrooccidentedenariño_cases_metrics.tsv
#
# Processing Region: surorientedenortedesantander (state_actor) from file: surorientedenortedesantander_cases_state_actor.tsv
# Saved metrics for Region: surorientedenortedesantander (state_actor) to surorientedenortedesantander_cases_metrics.tsv
#
# Processing Region: nortedelcauca (state_actor) from file: nortedelcauca_cases_state_actor.tsv
# Saved metrics for Region: nortedelcauca (state_actor) to nortedelcauca_cases_metrics.tsv
#
# Processing Region: surdelvalle (state_actor) from file: surdelvalle_cases_state_actor.tsv
# Saved metrics for Region: surdelvalle (state_actor) to surdelvalle_cases_metrics.tsv
#
# Processing Region: piedemontellanero (state_actor) from file: piedemontellanero_cases_state_actor.tsv
# Saved metrics for Region: piedemontellanero (state_actor) to piedemontellanero_cases_metrics.tsv
#
# Processing Region: macizocolombiano (state_actor) from file: macizocolombiano_cases_state_actor.tsv
# Saved metrics for Region: macizocolombiano (state_actor) to macizocolombiano_cases_metrics.tsv
#
# Processing Region: uraba (state_actor) from file: uraba_cases_state_actor.tsv
# Saved metrics for Region: uraba (state_actor) to uraba_cases_metrics.tsv
#
# Processing Region: nordesteantioqueño (state_actor) from file: nordesteantioqueño_cases_state_actor.tsv
# Saved metrics for Region: nordesteantioqueño (state_actor) to nordesteantioqueño_cases_metrics.tsv
#
# Processing Region: nortedeantioquia (state_actor) from file: nortedeantioquia_cases_state_actor.tsv
# Saved metrics for Region: nortedeantioquia (state_actor) to nortedeantioquia_cases_metrics.tsv
#
# Processing Region: altaguajira (state_actor) from file: altaguajira_cases_state_actor.tsv
# Saved metrics for Region: altaguajira (state_actor) to altaguajira_cases_metrics.tsv
#
# Processing Region: orientedeboyaca (state_actor) from file: orientedeboyaca_cases_state_actor.tsv
# Saved metrics for Region: orientedeboyaca (state_actor) to orientedeboyaca_cases_metrics.tsv
#
# Processing Region: orienteantioqueño (state_actor) from file: orienteantioqueño_cases_state_actor.tsv
# Saved metrics for Region: orienteantioqueño (state_actor) to orienteantioqueño_cases_metrics.tsv
#
# Processing Region: catatumbo (state_actor) from file: catatumbo_cases_state_actor.tsv
# Saved metrics for Region: catatumbo (state_actor) to catatumbo_cases_metrics.tsv
#
# Processing Region: occidentedeatlantico (state_actor) from file: occidentedeatlantico_cases_state_actor.tsv
# Saved metrics for Region: occidentedeatlantico (state_actor) to occidentedeatlantico_cases_metrics.tsv
#
# Processing Region: altillanura (state_actor) from file: altillanura_cases_state_actor.tsv
# Saved metrics for Region: altillanura (state_actor) to altillanura_cases_metrics.tsv
#
# Processing Region: suroccidentedenortedesantander (state_actor) from file: suroccidentedenortedesantander_cases_state_actor.tsv
# Saved metrics for Region: suroccidentedenortedesantander (state_actor) to suroccidentedenortedesantander_cases_metrics.tsv
#
# Processing Region: nortedeltolima (state_actor) from file: nortedeltolima_cases_state_actor.tsv
# Saved metrics for Region: nortedeltolima (state_actor) to nortedeltolima_cases_metrics.tsv
#
# Processing Region: surdeltolima (state_actor) from file: surdeltolima_cases_state_actor.tsv
# Saved metrics for Region: surdeltolima (state_actor) to surdeltolima_cases_metrics.tsv
#
# Processing Region: provinciadevelez (state_actor) from file: provinciadevelez_cases_state_actor.tsv
# Saved metrics for Region: provinciadevelez (state_actor) to provinciadevelez_cases_metrics.tsv
#
# Processing Region: occidenteantioqueño (state_actor) from file: occidenteantioqueño_cases_state_actor.tsv
# Saved metrics for Region: occidenteantioqueño (state_actor) to occidenteantioqueño_cases_metrics.tsv
#
# Processing Region: magdalenamedioantioqueño (state_actor) from file: magdalenamedioantioqueño_cases_state_actor.tsv
# Saved metrics for Region: magdalenamedioantioqueño (state_actor) to magdalenamedioantioqueño_cases_metrics.tsv
#
# Processing Region: archipielagodesanandres,providenciaysantacatalina (state_actor) from file: archipielagodesanandres,providenciaysantacatalina_cases_state_actor.tsv
# Saved metrics for Region: archipielagodesanandres,providenciaysantacatalina (state_actor) to archipielagodesanandres,providenciaysantacatalina_cases_metrics.tsv
#
# Processing Region: provinciadesoto (state_actor) from file: provinciadesoto_cases_state_actor.tsv
# Saved metrics for Region: provinciadesoto (state_actor) to provinciadesoto_cases_metrics.tsv
#
# Processing Region: centrodenortedesantander (state_actor) from file: centrodenortedesantander_cases_state_actor.tsv
# Saved metrics for Region: centrodenortedesantander (state_actor) to centrodenortedesantander_cases_metrics.tsv
#
# Processing Region: provinciadericaurte (state_actor) from file: provinciadericaurte_cases_state_actor.tsv
# Saved metrics for Region: provinciadericaurte (state_actor) to provinciadericaurte_cases_metrics.tsv
#
# Processing Region: llanosorientales (state_actor) from file: llanosorientales_cases_state_actor.tsv
# Saved metrics for Region: llanosorientales (state_actor) to llanosorientales_cases_metrics.tsv
#
# Processing Region: provinciadegarciarovira (state_actor) from file: provinciadegarciarovira_cases_state_actor.tsv
# Saved metrics for Region: provinciadegarciarovira (state_actor) to provinciadegarciarovira_cases_metrics.tsv
#
# Processing Region: canaldeldique (state_actor) from file: canaldeldique_cases_state_actor.tsv
# Saved metrics for Region: canaldeldique (state_actor) to canaldeldique_cases_metrics.tsv
#
# Processing Region: caguan (state_actor) from file: caguan_cases_state_actor.tsv
# Saved metrics for Region: caguan (state_actor) to caguan_cases_metrics.tsv
#
# Processing Region: nortedecordoba (state_actor) from file: nortedecordoba_cases_state_actor.tsv
# Saved metrics for Region: nortedecordoba (state_actor) to nortedecordoba_cases_metrics.tsv
#
# Processing Region: areametropolitanadecucuta (state_actor) from file: areametropolitanadecucuta_cases_state_actor.tsv
# Saved metrics for Region: areametropolitanadecucuta (state_actor) to areametropolitanadecucuta_cases_metrics.tsv
#
# Processing Region: centrodelvalle (state_actor) from file: centrodelvalle_cases_state_actor.tsv
# Saved metrics for Region: centrodelvalle (state_actor) to centrodelvalle_cases_metrics.tsv
#
# Processing Region: magdalenamedio (state_actor) from file: magdalenamedio_cases_state_actor.tsv
# Saved metrics for Region: magdalenamedio (state_actor) to magdalenamedio_cases_metrics.tsv
#
# Processing Region: valledesanjuan (state_actor) from file: valledesanjuan_cases_state_actor.tsv
# Saved metrics for Region: valledesanjuan (state_actor) to valledesanjuan_cases_metrics.tsv
#
# Processing Region: sininformacion (state_actor) from file: sininformacion_cases_state_actor.tsv
# Saved metrics for Region: sininformacion (state_actor) to sininformacion_cases_metrics.tsv
#
# Processing Region: ariariguayabero (state_actor) from file: ariariguayabero_cases_state_actor.tsv
# Saved metrics for Region: ariariguayabero (state_actor) to ariariguayabero_cases_metrics.tsv
#
# Processing Region: andenpacificosur (state_actor) from file: andenpacificosur_cases_state_actor.tsv
# Saved metrics for Region: andenpacificosur (state_actor) to andenpacificosur_cases_metrics.tsv
#
# Processing Region: surdebolivar (state_actor) from file: surdebolivar_cases_state_actor.tsv
# Saved metrics for Region: surdebolivar (state_actor) to surdebolivar_cases_metrics.tsv
#
# Processing Region: nortedelvalle (state_actor) from file: nortedelvalle_cases_state_actor.tsv
# Saved metrics for Region: nortedelvalle (state_actor) to nortedelvalle_cases_metrics.tsv
#
# Processing Region: patia (state_actor) from file: patia_cases_state_actor.tsv
# Saved metrics for Region: patia (state_actor) to patia_cases_metrics.tsv
#
# Processing Region: bajocaucaantioqueño (state_actor) from file: bajocaucaantioqueño_cases_state_actor.tsv
# Saved metrics for Region: bajocaucaantioqueño (state_actor) to bajocaucaantioqueño_cases_metrics.tsv
#
# Processing Region: cienagagrandedesantamarta (state_actor) from file: cienagagrandedesantamarta_cases_state_actor.tsv
# Saved metrics for Region: cienagagrandedesantamarta (state_actor) to cienagagrandedesantamarta_cases_metrics.tsv
#
# Processing Region: altosinuysanjorge (state_actor) from file: altosinuysanjorge_cases_state_actor.tsv
# Saved metrics for Region: altosinuysanjorge (state_actor) to altosinuysanjorge_cases_metrics.tsv
#
# Processing Region: surdelhuila (state_actor) from file: surdelhuila_cases_state_actor.tsv
# Saved metrics for Region: surdelhuila (state_actor) to surdelhuila_cases_metrics.tsv
#
# Processing Region: ejecafetero (state_actor) from file: ejecafetero_cases_state_actor.tsv
# Saved metrics for Region: ejecafetero (state_actor) to ejecafetero_cases_metrics.tsv
#
# Processing Region: montesdemaria (state_actor) from file: montesdemaria_cases_state_actor.tsv
# Saved metrics for Region: montesdemaria (state_actor) to montesdemaria_cases_metrics.tsv
#
# Processing Region: serraniadelosyariguies (state_actor) from file: serraniadelosyariguies_cases_state_actor.tsv
# Saved metrics for Region: serraniadelosyariguies (state_actor) to serraniadelosyariguies_cases_metrics.tsv
#
# Processing Region: suroccidentedecundinamarca (state_actor) from file: suroccidentedecundinamarca_cases_state_actor.tsv
# Saved metrics for Region: suroccidentedecundinamarca (state_actor) to suroccidentedecundinamarca_cases_metrics.tsv
#
# Processing Region: altiplanocundiboyacense (state_actor) from file: altiplanocundiboyacense_cases_state_actor.tsv
# Saved metrics for Region: altiplanocundiboyacense (state_actor) to altiplanocundiboyacense_cases_metrics.tsv
#
# Processing Region: serraniadelperija (state_actor) from file: serraniadelperija_cases_state_actor.tsv
# Saved metrics for Region: serraniadelperija (state_actor) to serraniadelperija_cases_metrics.tsv
#
# Processing Region: sarare (state_actor) from file: sarare_cases_state_actor.tsv
# Saved metrics for Region: sarare (state_actor) to sarare_cases_metrics.tsv
#
# Processing Region: florenciayareadeinfluencia (state_actor) from file: florenciayareadeinfluencia_cases_state_actor.tsv
# Saved metrics for Region: florenciayareadeinfluencia (state_actor) to florenciayareadeinfluencia_cases_metrics.tsv
#
# Processing Region: amazoniasur-oriental (state_actor) from file: amazoniasur-oriental_cases_state_actor.tsv
# Saved metrics for Region: amazoniasur-oriental (state_actor) to amazoniasur-oriental_cases_metrics.tsv
#
# Processing Region: noroccidentedecundinamarca (state_actor) from file: noroccidentedecundinamarca_cases_state_actor.tsv
# Saved metrics for Region: noroccidentedecundinamarca (state_actor) to noroccidentedecundinamarca_cases_metrics.tsv
#
# Processing Region: bajoputumayo (state_actor) from file: bajoputumayo_cases_state_actor.tsv
# Saved metrics for Region: bajoputumayo (state_actor) to bajoputumayo_cases_metrics.tsv
#
# Processing Region: occidentedenariño (state_actor) from file: occidentedenariño_cases_state_actor.tsv
# Saved metrics for Region: occidentedenariño (state_actor) to occidentedenariño_cases_metrics.tsv
#
# Processing Region: provinciacomunera (state_actor) from file: provinciacomunera_cases_state_actor.tsv
# Saved metrics for Region: provinciacomunera (state_actor) to provinciacomunera_cases_metrics.tsv
#
# Processing Region: litoralpacifico (state_actor) from file: litoralpacifico_cases_state_actor.tsv
# Saved metrics for Region: litoralpacifico (state_actor) to litoralpacifico_cases_metrics.tsv
#
# Processing Region: surdenariño (state_actor) from file: surdenariño_cases_state_actor.tsv
# Saved metrics for Region: surdenariño (state_actor) to surdenariño_cases_metrics.tsv
#
# Processing Region: nortedenariño (state_actor) from file: nortedenariño_cases_state_actor.tsv
# Saved metrics for Region: nortedenariño (state_actor) to nortedenariño_cases_metrics.tsv
#
# Processing Region: areametropolitanadebogota (state_actor) from file: areametropolitanadebogota_cases_state_actor.tsv
# Saved metrics for Region: areametropolitanadebogota (state_actor) to areametropolitanadebogota_cases_metrics.tsv
#
# Processing Region: nortedeatlantico (state_actor) from file: nortedeatlantico_cases_state_actor.tsv
# Saved metrics for Region: nortedeatlantico (state_actor) to nortedeatlantico_cases_metrics.tsv
#
# Processing Region: atrato (state_actor) from file: atrato_cases_state_actor.tsv
# Saved metrics for Region: atrato (state_actor) to atrato_cases_metrics.tsv
#
# Processing Region: valledeaburra (state_actor) from file: valledeaburra_cases_state_actor.tsv
# Saved metrics for Region: valledeaburra (state_actor) to valledeaburra_cases_metrics.tsv
#
# Processing Region: sumapaz (state_actor) from file: sumapaz_cases_state_actor.tsv
# Saved metrics for Region: sumapaz (state_actor) to sumapaz_cases_metrics.tsv
#
# Processing Region: sierranevadadesantamarta (state_actor) from file: sierranevadadesantamarta_cases_state_actor.tsv
# Saved metrics for Region: sierranevadadesantamarta (state_actor) to sierranevadadesantamarta_cases_metrics.tsv
#
# Processing Region: centrodelhuila (state_actor) from file: centrodelhuila_cases_state_actor.tsv
# Saved metrics for Region: centrodelhuila (state_actor) to centrodelhuila_cases_metrics.tsv
#
# Processing Region: suroesteantioqueño (state_actor) from file: suroesteantioqueño_cases_state_actor.tsv
# Saved metrics for Region: suroesteantioqueño (state_actor) to suroesteantioqueño_cases_metrics.tsv
#
# Processing Region: provinciadeguanenta (state_actor) from file: provinciadeguanenta_cases_state_actor.tsv
# Saved metrics for Region: provinciadeguanenta (state_actor) to provinciadeguanenta_cases_metrics.tsv
#
# Processing Region: lamojana (state_actor) from file: lamojana_cases_state_actor.tsv
# Saved metrics for Region: lamojana (state_actor) to lamojana_cases_metrics.tsv
#
# Processing Region: centroorientedeatlantico (state_actor) from file: centroorientedeatlantico_cases_state_actor.tsv
# Saved metrics for Region: centroorientedeatlantico (state_actor) to centroorientedeatlantico_cases_metrics.tsv
#
# Processing Region: surdemagdalena (state_actor) from file: surdemagdalena_cases_state_actor.tsv
# Saved metrics for Region: surdemagdalena (state_actor) to surdemagdalena_cases_metrics.tsv
#
# --- Processing Region Level for Actor Type: non_state_actor ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/intensity & escalation/cases/region/non_state_actor
# Found 78 processed Region (non_state_actor) files. Processing each...
#
# Processing Region: nortedeantioquia (non_state_actor) from file: nortedeantioquia_cases_non_state_actor.tsv
# Saved metrics for Region: nortedeantioquia (non_state_actor) to nortedeantioquia_cases_metrics.tsv
#
# Processing Region: magdalenamedio (non_state_actor) from file: magdalenamedio_cases_non_state_actor.tsv
# Saved metrics for Region: magdalenamedio (non_state_actor) to magdalenamedio_cases_metrics.tsv
#
# Processing Region: amazoniasur-oriental (non_state_actor) from file: amazoniasur-oriental_cases_non_state_actor.tsv
# Saved metrics for Region: amazoniasur-oriental (non_state_actor) to amazoniasur-oriental_cases_metrics.tsv
#
# Processing Region: morrosquilloysabanasdesucre (non_state_actor) from file: morrosquilloysabanasdesucre_cases_non_state_actor.tsv
# Saved metrics for Region: morrosquilloysabanasdesucre (non_state_actor) to morrosquilloysabanasdesucre_cases_metrics.tsv
#
# Processing Region: occidentedeatlantico (non_state_actor) from file: occidentedeatlantico_cases_non_state_actor.tsv
# Saved metrics for Region: occidentedeatlantico (non_state_actor) to occidentedeatlantico_cases_metrics.tsv
#
# Processing Region: suroccidentedenortedesantander (non_state_actor) from file: suroccidentedenortedesantander_cases_non_state_actor.tsv
# Saved metrics for Region: suroccidentedenortedesantander (non_state_actor) to suroccidentedenortedesantander_cases_metrics.tsv
#
# Processing Region: provinciadericaurte (non_state_actor) from file: provinciadericaurte_cases_non_state_actor.tsv
# Saved metrics for Region: provinciadericaurte (non_state_actor) to provinciadericaurte_cases_metrics.tsv
#
# Processing Region: provinciadegarciarovira (non_state_actor) from file: provinciadegarciarovira_cases_non_state_actor.tsv
# Saved metrics for Region: provinciadegarciarovira (non_state_actor) to provinciadegarciarovira_cases_metrics.tsv
#
# Processing Region: surorientedenortedesantander (non_state_actor) from file: surorientedenortedesantander_cases_non_state_actor.tsv
# Saved metrics for Region: surorientedenortedesantander (non_state_actor) to surorientedenortedesantander_cases_metrics.tsv
#
# Processing Region: macizocolombiano (non_state_actor) from file: macizocolombiano_cases_non_state_actor.tsv
# Saved metrics for Region: macizocolombiano (non_state_actor) to macizocolombiano_cases_metrics.tsv
#
# Processing Region: canaldeldique (non_state_actor) from file: canaldeldique_cases_non_state_actor.tsv
# Saved metrics for Region: canaldeldique (non_state_actor) to canaldeldique_cases_metrics.tsv
#
# Processing Region: altaguajira (non_state_actor) from file: altaguajira_cases_non_state_actor.tsv
# Saved metrics for Region: altaguajira (non_state_actor) to altaguajira_cases_metrics.tsv
#
# Processing Region: surdemagdalena (non_state_actor) from file: surdemagdalena_cases_non_state_actor.tsv
# Saved metrics for Region: surdemagdalena (non_state_actor) to surdemagdalena_cases_metrics.tsv
#
# Processing Region: surdelhuila (non_state_actor) from file: surdelhuila_cases_non_state_actor.tsv
# Saved metrics for Region: surdelhuila (non_state_actor) to surdelhuila_cases_metrics.tsv
#
# Processing Region: nortedelhuila (non_state_actor) from file: nortedelhuila_cases_non_state_actor.tsv
# Saved metrics for Region: nortedelhuila (non_state_actor) to nortedelhuila_cases_metrics.tsv
#
# Processing Region: altosinuysanjorge (non_state_actor) from file: altosinuysanjorge_cases_non_state_actor.tsv
# Saved metrics for Region: altosinuysanjorge (non_state_actor) to altosinuysanjorge_cases_metrics.tsv
#
# Processing Region: patia (non_state_actor) from file: patia_cases_non_state_actor.tsv
# Saved metrics for Region: patia (non_state_actor) to patia_cases_metrics.tsv
#
# Processing Region: centrodelvalle (non_state_actor) from file: centrodelvalle_cases_non_state_actor.tsv
# Saved metrics for Region: centrodelvalle (non_state_actor) to centrodelvalle_cases_metrics.tsv
#
# Processing Region: sininformacion (non_state_actor) from file: sininformacion_cases_non_state_actor.tsv
# Saved metrics for Region: sininformacion (non_state_actor) to sininformacion_cases_metrics.tsv
#
# Processing Region: atrato (non_state_actor) from file: atrato_cases_non_state_actor.tsv
# Saved metrics for Region: atrato (non_state_actor) to atrato_cases_metrics.tsv
#
# Processing Region: centrodenortedesantander (non_state_actor) from file: centrodenortedesantander_cases_non_state_actor.tsv
# Saved metrics for Region: centrodenortedesantander (non_state_actor) to centrodenortedesantander_cases_metrics.tsv
#
# Processing Region: occidenteantioqueño (non_state_actor) from file: occidenteantioqueño_cases_non_state_actor.tsv
# Saved metrics for Region: occidenteantioqueño (non_state_actor) to occidenteantioqueño_cases_metrics.tsv
#
# Processing Region: valledesanjuan (non_state_actor) from file: valledesanjuan_cases_non_state_actor.tsv
# Saved metrics for Region: valledesanjuan (non_state_actor) to valledesanjuan_cases_metrics.tsv
#
# Processing Region: sumapaz (non_state_actor) from file: sumapaz_cases_non_state_actor.tsv
# Saved metrics for Region: sumapaz (non_state_actor) to sumapaz_cases_metrics.tsv
#
# Processing Region: nordesteantioqueño (non_state_actor) from file: nordesteantioqueño_cases_non_state_actor.tsv
# Saved metrics for Region: nordesteantioqueño (non_state_actor) to nordesteantioqueño_cases_metrics.tsv
#
# Processing Region: surdelvalle (non_state_actor) from file: surdelvalle_cases_non_state_actor.tsv
# Saved metrics for Region: surdelvalle (non_state_actor) to surdelvalle_cases_metrics.tsv
#
# Processing Region: nortedelvalle (non_state_actor) from file: nortedelvalle_cases_non_state_actor.tsv
# Saved metrics for Region: nortedelvalle (non_state_actor) to nortedelvalle_cases_metrics.tsv
#
# Processing Region: provinciadevelez (non_state_actor) from file: provinciadevelez_cases_non_state_actor.tsv
# Saved metrics for Region: provinciadevelez (non_state_actor) to provinciadevelez_cases_metrics.tsv
#
# Processing Region: centrodelhuila (non_state_actor) from file: centrodelhuila_cases_non_state_actor.tsv
# Saved metrics for Region: centrodelhuila (non_state_actor) to centrodelhuila_cases_metrics.tsv
#
# Processing Region: altoputumayo (non_state_actor) from file: altoputumayo_cases_non_state_actor.tsv
# Saved metrics for Region: altoputumayo (non_state_actor) to altoputumayo_cases_metrics.tsv
#
# Processing Region: areametropolitanadebogota (non_state_actor) from file: areametropolitanadebogota_cases_non_state_actor.tsv
# Saved metrics for Region: areametropolitanadebogota (non_state_actor) to areametropolitanadebogota_cases_metrics.tsv
#
# Processing Region: nortedelcauca (non_state_actor) from file: nortedelcauca_cases_non_state_actor.tsv
# Saved metrics for Region: nortedelcauca (non_state_actor) to nortedelcauca_cases_metrics.tsv
#
# Processing Region: nortedenariño (non_state_actor) from file: nortedenariño_cases_non_state_actor.tsv
# Saved metrics for Region: nortedenariño (non_state_actor) to nortedenariño_cases_metrics.tsv
#
# Processing Region: nortedeltolima (non_state_actor) from file: nortedeltolima_cases_non_state_actor.tsv
# Saved metrics for Region: nortedeltolima (non_state_actor) to nortedeltolima_cases_metrics.tsv
#
# Processing Region: lamojana (non_state_actor) from file: lamojana_cases_non_state_actor.tsv
# Saved metrics for Region: lamojana (non_state_actor) to lamojana_cases_metrics.tsv
#
# Processing Region: serraniadelosyariguies (non_state_actor) from file: serraniadelosyariguies_cases_non_state_actor.tsv
# Saved metrics for Region: serraniadelosyariguies (non_state_actor) to serraniadelosyariguies_cases_metrics.tsv
#
# Processing Region: archipielagodesanandres,providenciaysantacatalina (non_state_actor) from file: archipielagodesanandres,providenciaysantacatalina_cases_non_state_actor.tsv
# Saved metrics for Region: archipielagodesanandres,providenciaysantacatalina (non_state_actor) to archipielagodesanandres,providenciaysantacatalina_cases_metrics.tsv
#
# Processing Region: altillanura (non_state_actor) from file: altillanura_cases_non_state_actor.tsv
# Saved metrics for Region: altillanura (non_state_actor) to altillanura_cases_metrics.tsv
#
# Processing Region: surdecesar (non_state_actor) from file: surdecesar_cases_non_state_actor.tsv
# Saved metrics for Region: surdecesar (non_state_actor) to surdecesar_cases_metrics.tsv
#
# Processing Region: suroccidentedecundinamarca (non_state_actor) from file: suroccidentedecundinamarca_cases_non_state_actor.tsv
# Saved metrics for Region: suroccidentedecundinamarca (non_state_actor) to suroccidentedecundinamarca_cases_metrics.tsv
#
# Processing Region: noroccidentedecundinamarca (non_state_actor) from file: noroccidentedecundinamarca_cases_non_state_actor.tsv
# Saved metrics for Region: noroccidentedecundinamarca (non_state_actor) to noroccidentedecundinamarca_cases_metrics.tsv
#
# Processing Region: montesdemaria (non_state_actor) from file: montesdemaria_cases_non_state_actor.tsv
# Saved metrics for Region: montesdemaria (non_state_actor) to montesdemaria_cases_metrics.tsv
#
# Processing Region: areametropolitanadecucuta (non_state_actor) from file: areametropolitanadecucuta_cases_non_state_actor.tsv
# Saved metrics for Region: areametropolitanadecucuta (non_state_actor) to areametropolitanadecucuta_cases_metrics.tsv
#
# Processing Region: occidentedenariño (non_state_actor) from file: occidentedenariño_cases_non_state_actor.tsv
# Saved metrics for Region: occidentedenariño (non_state_actor) to occidentedenariño_cases_metrics.tsv
#
# Processing Region: centrodenariño (non_state_actor) from file: centrodenariño_cases_non_state_actor.tsv
# Saved metrics for Region: centrodenariño (non_state_actor) to centrodenariño_cases_metrics.tsv
#
# Processing Region: provinciadesoto (non_state_actor) from file: provinciadesoto_cases_non_state_actor.tsv
# Saved metrics for Region: provinciadesoto (non_state_actor) to provinciadesoto_cases_metrics.tsv
#
# Processing Region: surdeltolima (non_state_actor) from file: surdeltolima_cases_non_state_actor.tsv
# Saved metrics for Region: surdeltolima (non_state_actor) to surdeltolima_cases_metrics.tsv
#
# Processing Region: piedemontellanero (non_state_actor) from file: piedemontellanero_cases_non_state_actor.tsv
# Saved metrics for Region: piedemontellanero (non_state_actor) to piedemontellanero_cases_metrics.tsv
#
# Processing Region: surdenariño (non_state_actor) from file: surdenariño_cases_non_state_actor.tsv
# Saved metrics for Region: surdenariño (non_state_actor) to surdenariño_cases_metrics.tsv
#
# Processing Region: nortedeatlantico (non_state_actor) from file: nortedeatlantico_cases_non_state_actor.tsv
# Saved metrics for Region: nortedeatlantico (non_state_actor) to nortedeatlantico_cases_metrics.tsv
#
# Processing Region: litoralpacifico (non_state_actor) from file: litoralpacifico_cases_non_state_actor.tsv
# Saved metrics for Region: litoralpacifico (non_state_actor) to litoralpacifico_cases_metrics.tsv
#
# Processing Region: centrooccidentedenariño (non_state_actor) from file: centrooccidentedenariño_cases_non_state_actor.tsv
# Saved metrics for Region: centrooccidentedenariño (non_state_actor) to centrooccidentedenariño_cases_metrics.tsv
#
# Processing Region: catatumbo (non_state_actor) from file: catatumbo_cases_non_state_actor.tsv
# Saved metrics for Region: catatumbo (non_state_actor) to catatumbo_cases_metrics.tsv
#
# Processing Region: surdebolivar (non_state_actor) from file: surdebolivar_cases_non_state_actor.tsv
# Saved metrics for Region: surdebolivar (non_state_actor) to surdebolivar_cases_metrics.tsv
#
# Processing Region: valledeaburra (non_state_actor) from file: valledeaburra_cases_non_state_actor.tsv
# Saved metrics for Region: valledeaburra (non_state_actor) to valledeaburra_cases_metrics.tsv
#
# Processing Region: florenciayareadeinfluencia (non_state_actor) from file: florenciayareadeinfluencia_cases_non_state_actor.tsv
# Saved metrics for Region: florenciayareadeinfluencia (non_state_actor) to florenciayareadeinfluencia_cases_metrics.tsv
#
# Processing Region: caguan (non_state_actor) from file: caguan_cases_non_state_actor.tsv
# Saved metrics for Region: caguan (non_state_actor) to caguan_cases_metrics.tsv
#
# Processing Region: bajocaucaantioqueño (non_state_actor) from file: bajocaucaantioqueño_cases_non_state_actor.tsv
# Saved metrics for Region: bajocaucaantioqueño (non_state_actor) to bajocaucaantioqueño_cases_metrics.tsv
#
# Processing Region: orientedeboyaca (non_state_actor) from file: orientedeboyaca_cases_non_state_actor.tsv
# Saved metrics for Region: orientedeboyaca (non_state_actor) to orientedeboyaca_cases_metrics.tsv
#
# Processing Region: altiplanocundiboyacense (non_state_actor) from file: altiplanocundiboyacense_cases_non_state_actor.tsv
# Saved metrics for Region: altiplanocundiboyacense (non_state_actor) to altiplanocundiboyacense_cases_metrics.tsv
#
# Processing Region: serraniadelperija (non_state_actor) from file: serraniadelperija_cases_non_state_actor.tsv
# Saved metrics for Region: serraniadelperija (non_state_actor) to serraniadelperija_cases_metrics.tsv
#
# Processing Region: nortedecordoba (non_state_actor) from file: nortedecordoba_cases_non_state_actor.tsv
# Saved metrics for Region: nortedecordoba (non_state_actor) to nortedecordoba_cases_metrics.tsv
#
# Processing Region: provinciadeguanenta (non_state_actor) from file: provinciadeguanenta_cases_non_state_actor.tsv
# Saved metrics for Region: provinciadeguanenta (non_state_actor) to provinciadeguanenta_cases_metrics.tsv
#
# Processing Region: centroorientedeatlantico (non_state_actor) from file: centroorientedeatlantico_cases_non_state_actor.tsv
# Saved metrics for Region: centroorientedeatlantico (non_state_actor) to centroorientedeatlantico_cases_metrics.tsv
#
# Processing Region: llanosorientales (non_state_actor) from file: llanosorientales_cases_non_state_actor.tsv
# Saved metrics for Region: llanosorientales (non_state_actor) to llanosorientales_cases_metrics.tsv
#
# Processing Region: provinciacomunera (non_state_actor) from file: provinciacomunera_cases_non_state_actor.tsv
# Saved metrics for Region: provinciacomunera (non_state_actor) to provinciacomunera_cases_metrics.tsv
#
# Processing Region: ejecafetero (non_state_actor) from file: ejecafetero_cases_non_state_actor.tsv
# Saved metrics for Region: ejecafetero (non_state_actor) to ejecafetero_cases_metrics.tsv
#
# Processing Region: andenpacificosur (non_state_actor) from file: andenpacificosur_cases_non_state_actor.tsv
# Saved metrics for Region: andenpacificosur (non_state_actor) to andenpacificosur_cases_metrics.tsv
#
# Processing Region: uraba (non_state_actor) from file: uraba_cases_non_state_actor.tsv
# Saved metrics for Region: uraba (non_state_actor) to uraba_cases_metrics.tsv
#
# Processing Region: suroesteantioqueño (non_state_actor) from file: suroesteantioqueño_cases_non_state_actor.tsv
# Saved metrics for Region: suroesteantioqueño (non_state_actor) to suroesteantioqueño_cases_metrics.tsv
#
# Processing Region: cienagagrandedesantamarta (non_state_actor) from file: cienagagrandedesantamarta_cases_non_state_actor.tsv
# Saved metrics for Region: cienagagrandedesantamarta (non_state_actor) to cienagagrandedesantamarta_cases_metrics.tsv
#
# Processing Region: ariariguayabero (non_state_actor) from file: ariariguayabero_cases_non_state_actor.tsv
# Saved metrics for Region: ariariguayabero (non_state_actor) to ariariguayabero_cases_metrics.tsv
#
# Processing Region: magdalenamedioantioqueño (non_state_actor) from file: magdalenamedioantioqueño_cases_non_state_actor.tsv
# Saved metrics for Region: magdalenamedioantioqueño (non_state_actor) to magdalenamedioantioqueño_cases_metrics.tsv
#
# Processing Region: sarare (non_state_actor) from file: sarare_cases_non_state_actor.tsv
# Saved metrics for Region: sarare (non_state_actor) to sarare_cases_metrics.tsv
#
# Processing Region: sierranevadadesantamarta (non_state_actor) from file: sierranevadadesantamarta_cases_non_state_actor.tsv
# Saved metrics for Region: sierranevadadesantamarta (non_state_actor) to sierranevadadesantamarta_cases_metrics.tsv
#
# Processing Region: orienteantioqueño (non_state_actor) from file: orienteantioqueño_cases_non_state_actor.tsv
# Saved metrics for Region: orienteantioqueño (non_state_actor) to orienteantioqueño_cases_metrics.tsv
#
# Processing Region: medioputumayo (non_state_actor) from file: medioputumayo_cases_non_state_actor.tsv
# Saved metrics for Region: medioputumayo (non_state_actor) to medioputumayo_cases_metrics.tsv
#
# Processing Region: bajoputumayo (non_state_actor) from file: bajoputumayo_cases_non_state_actor.tsv
# Saved metrics for Region: bajoputumayo (non_state_actor) to bajoputumayo_cases_metrics.tsv
#
# --- Processing Region Level for Actor Type: unknown_actor_type ---
# Ensured output directory exists: /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Results/intensity & escalation/cases/region/unknown_actor_type
# Error: Input data directory not found for Region (unknown_actor_type): /Users/diegohernandez/Documents/GitHub/VS_VI_Source_Code/Scripts/../Data/processed/cases/regions/unknown_actor_type. Skipping this actor type.
#
# Region-level metrics calculation and saving complete for all actor types.
#
# --- Overall Intensity and Escalation Calculation Process Finished ---
